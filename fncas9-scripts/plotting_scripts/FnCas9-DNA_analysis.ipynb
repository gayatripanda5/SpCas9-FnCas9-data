# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)

# %%
import pandas as pd
#/storage/gayatrip/gamd-amber-example/NII-work-2022/fn_native_gamd
#2,12,22,

headers_list1=['Frames','bp-pos','bps','Shear','Stretch','Stagger','Buckle','Propeller','Opening']
root_dir='/storage3/gayatrip/'
na_fn=open(root_dir+ 'EMX1-Fn_native_rep/fnnat_nodt/BP.nastruct_nodt-500ns_500frames.dat','r')

### For fnCas9_native system
lines=na_fn.readlines()
bp_20=[]
bp_19=[]
bp_18=[]
bp_17=[]
bp_16=[]
bp_15=[]
bp_14=[]
bp_13=[]
bp_12=[]
bp_11=[]
#while (i < len(lines))
for i in range(1,len(lines),20):
    bp_20.append(lines[i].strip().split())

for i in range(2,len(lines),20):
    bp_19.append(lines[i].strip().split())

for i in range(3,len(lines),20):
    bp_18.append(lines[i].strip().split())

for i in range(4,len(lines),20):
    bp_17.append(lines[i].strip().split())

for i in range(5,len(lines),20):
    bp_16.append(lines[i].strip().split())

for i in range(6,len(lines),20):
    bp_15.append(lines[i].strip().split())

for i in range(7,len(lines),20):
    bp_14.append(lines[i].strip().split())

for i in range(8,len(lines),20):
    bp_13.append(lines[i].strip().split())

for i in range(9,len(lines),20):
    bp_12.append(lines[i].strip().split())

for i in range(10,len(lines),20):
    bp_11.append(lines[i].strip().split())

# %%
shear_20=[]
str_20=[]
sta_20=[]
buc_20=[]
pro_20=[]
ope_20=[]
maj_20=[]
min_20=[]
for i in range(len(bp_20)-1):
    shear_20.append(float(bp_20[i][3]))
    str_20.append(float(bp_20[i][4]))
    sta_20.append(float(bp_20[i][5]))
    buc_20.append(float(bp_20[i][6]))
    pro_20.append(float(bp_20[i][7]))
    ope_20.append(float(bp_20[i][8]))
    maj_20.append(float(bp_20[i][11]))
    min_20.append(float(bp_20[i][12]))
    
shear_19=[]
str_19=[]
sta_19=[]
buc_19=[]
pro_19=[]
ope_19=[]
maj_19=[]
min_19=[]
for i in range(len(bp_19)-1):
    shear_19.append(float(bp_19[i][3]))
    str_19.append(float(bp_19[i][4]))
    sta_19.append(float(bp_19[i][5]))
    buc_19.append(float(bp_19[i][6]))
    pro_19.append(float(bp_19[i][7]))
    ope_19.append(float(bp_19[i][8]))
    maj_19.append(float(bp_19[i][11]))
    min_19.append(float(bp_19[i][12]))

shear_18=[]
str_18=[]
sta_18=[]
buc_18=[]
pro_18=[]
ope_18=[]
maj_18=[]
min_18=[]
for i in range(len(bp_18)-1):
    shear_18.append(float(bp_18[i][3]))
    str_18.append(float(bp_18[i][4]))
    sta_18.append(float(bp_18[i][5]))
    buc_18.append(float(bp_18[i][6]))
    pro_18.append(float(bp_18[i][7]))
    ope_18.append(float(bp_18[i][8]))
    maj_18.append(float(bp_18[i][11]))
    min_18.append(float(bp_18[i][12]))
    
shear_17=[]
str_17=[]
sta_17=[]
buc_17=[]
pro_17=[]
ope_17=[]
maj_17=[]
min_17=[]
for i in range(len(bp_17)-1):
    shear_17.append(float(bp_17[i][3]))
    str_17.append(float(bp_17[i][4]))
    sta_17.append(float(bp_17[i][5]))
    buc_17.append(float(bp_17[i][6]))
    pro_17.append(float(bp_17[i][7]))
    ope_17.append(float(bp_17[i][8]))
    maj_17.append(float(bp_17[i][11]))
    min_17.append(float(bp_17[i][12]))

shear_16=[]
str_16=[]
sta_16=[]
buc_16=[]
pro_16=[]
ope_16=[]
maj_16=[]
min_16=[]
for i in range(len(bp_16)-1):
    shear_16.append(float(bp_16[i][3]))
    str_16.append(float(bp_16[i][4]))
    sta_16.append(float(bp_16[i][5]))
    buc_16.append(float(bp_16[i][6]))
    pro_16.append(float(bp_16[i][7]))
    ope_16.append(float(bp_16[i][8]))
    maj_16.append(float(bp_16[i][11]))
    min_16.append(float(bp_16[i][12]))
    

    
fn_df_20=pd.DataFrame(list(zip(shear_20,str_20,sta_20,buc_20,pro_20,ope_20,maj_20,min_20)),columns=['fn_20_shear','fn_20_stretch','fn_20_stagger','fn_20_buckle','fn_20_propeller','fn_20_opening','fn_20_major','fn_20_minor'])
fn_df_19=pd.DataFrame(list(zip(shear_19,str_19,sta_19,buc_19,pro_19,ope_19,maj_19,min_19)),columns=['fn_19_shear','fn_19_stretch','fn_19_stagger','fn_19_buckle','fn_19_propeller','fn_19_opening','fn_19_major','fn_19_minor'])
fn_df_18=pd.DataFrame(list(zip(shear_18,str_18,sta_18,buc_18,pro_18,ope_18,maj_18,min_18)),columns=['fn_18_shear','fn_18_stretch','fn_18_stagger','fn_18_buckle','fn_18_propeller','fn_18_opening','fn_18_major','fn_18_minor'])
fn_df_17=pd.DataFrame(list(zip(shear_17,str_17,sta_17,buc_17,pro_17,ope_17,maj_17,min_17)),columns=['fn_17_shear','fn_17_stretch','fn_17_stagger','fn_17_buckle','fn_17_propeller','fn_17_opening','fn_17_major','fn_17_minor'])
fn_df_16=pd.DataFrame(list(zip(shear_16,str_16,sta_16,buc_16,pro_16,ope_16,maj_16,min_16)),columns=['fn_16_shear','fn_16_stretch','fn_16_stagger','fn_16_buckle','fn_16_propeller','fn_16_opening','fn_16_major','fn_16_minor'])
    
    
    
maj_15=[]
min_15=[]
maj_14=[]
min_14=[]
maj_13=[]
min_13=[]
maj_12=[]
min_12=[]
maj_11=[]
min_11=[]

for i in range(len(bp_15)-1):
    maj_15.append(float(bp_15[i][11]))
    min_15.append(float(bp_15[i][12]))
for i in range(len(bp_14)-1):
    maj_14.append(float(bp_14[i][11]))
    min_14.append(float(bp_14[i][12]))
for i in range(len(bp_13)-1):
    maj_13.append(float(bp_13[i][11]))
    min_13.append(float(bp_13[i][12]))
for i in range(len(bp_12)-1):
    maj_12.append(float(bp_12[i][11]))
    min_12.append(float(bp_12[i][12]))
for i in range(len(bp_11)-1):
    maj_11.append(float(bp_11[i][11]))
    min_11.append(float(bp_11[i][12]))
major=[]
minor=[]
fn_maj=pd.DataFrame(list(zip(maj_20,maj_19,maj_18,maj_17,maj_16,maj_15,maj_14,maj_13,maj_12,maj_11)),columns=['bp20','bp19','bp18','bp17','bp16','bp15','bp14','bp13','bp12','bp11'] )
fn_min=pd.DataFrame(list(zip(min_20,min_19,min_18,min_17,min_16,min_15,min_14,min_13,min_12,min_11)),columns=['bp20','bp19','bp18','bp17','bp16','bp15','bp14','bp13','bp12','bp11'] )
min_std=list(fn_min.std())
min_avg=list(fn_min.mean())
maj_std=list(fn_maj.std())
maj_avg=list(fn_maj.mean())
maj_bps=list(range(20,11,-1))
min_bps=list(range(20,11,-1))
#df_maj.mean()
fn_min_groove=pd.DataFrame(list(zip(min_bps,min_avg,min_std)),columns=["fn_bps","fn_mean","fn_std"])
fn_maj_groove=pd.DataFrame(list(zip(maj_bps,maj_avg,maj_std)),columns=["fn_bps","fn_mean","fn_std"])
fn_min_groove.head()
print(maj_std,maj_avg,maj_bps)
print(fn_min_groove.head(),fn_maj_groove.head())
#minor.append(min_20,min_19,min_18,min_17,min_16,min_15,min_14,min_13,min_12,min_11)
# Out:
# [0.0, 0.46330206541792207, 0.5021936713516882, 2.1453452447033015, 0.4759728634387984, 0.5978197720074908, 1.5737176959490895, 0.8170076489079746, 0.6044943471232272, 0.8124545233352641] [0.0, 18.756625726514528, 19.01716933938679, 19.296578657573153, 18.833328290565813, 19.433424168483374, 19.300752627052542, 18.77759385187704, 18.68633033660673, 19.078334790695813] [20, 19, 18, 17, 16, 15, 14, 13, 12]
#    fn_bps    fn_mean    fn_std
# 0      20  13.126448  0.254925
# 1      19  13.139816  0.303349
# 2      18  13.310383  0.200621
# 3      17  12.885848  1.402319
# 4      16  13.383177  0.194949    fn_bps    fn_mean    fn_std
# 0      20   0.000000  0.000000
# 1      19  18.756626  0.463302
# 2      18  19.017169  0.502194
# 3      17  19.296579  2.145345
# 4      16  18.833328  0.475973

# %%
# fn_df_20.to_csv('Fn_NA_csvs/fn_nat_bp20_prop.csv', index=False)
# fn_df_19.to_csv('Fn_NA_csvs/fn_nat_bp19_prop.csv', index=False)
# fn_df_18.to_csv('Fn_NA_csvs/fn_nat_bp18_prop.csv', index=False)
# fn_df_17.to_csv('Fn_NA_csvs/fn_nat_bp17_prop.csv', index=False)
# fn_df_16.to_csv('Fn_NA_csvs/fn_nat_bp16_prop.csv', index=False)
# fn_df_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fn_20_shear      1000 non-null   float64
#  1   fn_20_stretch    1000 non-null   float64
#  2   fn_20_stagger    1000 non-null   float64
#  3   fn_20_buckle     1000 non-null   float64
#  4   fn_20_propeller  1000 non-null   float64
#  5   fn_20_opening    1000 non-null   float64
#  6   fn_20_major      1000 non-null   float64
#  7   fn_20_minor      1000 non-null   float64
# dtypes: float64(8)
# memory usage: 62.6 KB

# %%
fn_nat_bps=pd.concat([fn_df_20,fn_df_19,fn_df_18,fn_df_17], axis=1)
fn_nat_bps.head()
fn_nat_bps.to_csv('fn_nat_all_nodt.csv', index=False)

# %%
fnmm20_bp20=pd.read_csv(root_dir+'EMX1-Fn_mm20/repeat/pyemma_fnmm20/3dna/bp_20_fnmm20.csv',names=headers_list1)
fnmm20_bp19=pd.read_csv(root_dir+'EMX1-Fn_mm20/repeat/pyemma_fnmm20/3dna/bp_19_fnmm20.csv',names=headers_list1)
fnmm20_bp18=pd.read_csv(root_dir+'EMX1-Fn_mm20/repeat/pyemma_fnmm20/3dna/bp_18_fnmm20.csv',names=headers_list1)
fnmm20_bp17=pd.read_csv(root_dir+'EMX1-Fn_mm20/repeat/pyemma_fnmm20/3dna/bp_17_fnmm20.csv',names=headers_list1)
fnmm20_bp16=pd.read_csv(root_dir+'EMX1-Fn_mm20/repeat/pyemma_fnmm20/3dna/bp_16_fnmm20.csv',names=headers_list1)

# %%
fnmm20_bp20=fnmm20_bp20.sort_values('Frames').reset_index()
fnmm20_bp19=fnmm20_bp19.sort_values('Frames').reset_index()
fnmm20_bp18=fnmm20_bp18.sort_values('Frames').reset_index()
fnmm20_bp17=fnmm20_bp17.sort_values('Frames').reset_index()
fnmm20_bp20.head()
# Out:
#    index  Frames  bp-pos  bps  Shear  Stretch  Stagger  Buckle  Propeller  \
# 0   1843       1       1  U-C   0.03    -1.71    -0.95    9.14     -26.28
# 1    685      10       1  U-C  -1.13    -1.75    -0.85  -12.41     -34.23
# 2    847      11       1  U-C  -0.59    -1.68    -1.17  -16.80     -20.45
# 3   1015      12       1  U-C  -0.47    -1.61    -0.84    1.05     -38.72
# 4   1176      13       1  U-C  -1.32    -1.70    -0.66  -12.76     -37.15
#
#    Opening
# 0    15.14
# 1    14.72
# 2     6.86
# 3    16.35
# 4    10.65

# %%
fnmm20_bp20.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
fnmm20_bp19.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
fnmm20_bp18.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
fnmm20_bp17.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
#list1=['Shear','Stretch','Stagger','Buckle','Propeller','Opening']
list1=['fn_mm20_shear_20','fn_mm20_stretch_20','fn_mm20_stagger_20','fn_mm20_buckle_20','fn_mm20_propeller_20','fn_mm20_opening_20']
list2=['fn_mm20_shear_19','fn_mm20_stretch_19','fn_mm20_stagger_19','fn_mm20_buckle_19','fn_mm20_propeller_19','fn_mm20_opening_19']
list3=['fn_mm20_shear_18','fn_mm20_stretch_18','fn_mm20_stagger_18','fn_mm20_buckle_18','fn_mm20_propeller_18','fn_mm20_opening_18']
list4=['fn_mm20_shear_17','fn_mm20_stretch_17','fn_mm20_stagger_17','fn_mm20_buckle_17','fn_mm20_propeller_17','fn_mm20_opening_17']
fnmm20_bp20.columns=list1
fnmm20_bp19.columns=list2
fnmm20_bp18.columns=list3
fnmm20_bp17.columns=list4
fn_mmmm20_all_bps=pd.concat([fnmm20_bp20,fnmm20_bp19,fnmm20_bp18,fnmm20_bp17], axis=1)
fn_mmmm20_all_bps.to_csv('fn_mm20_all_bps.csv', index=False)

# %%
fn16_19_bp20=pd.read_csv('/storage3/gayatrip/EMX1_Fn_mm16_19/pyemma_fnmm16_19/3dna/bp_20_fnmm16_19.csv',names=headers_list1)
fn16_19_bp19=pd.read_csv('/storage3/gayatrip/EMX1_Fn_mm16_19/pyemma_fnmm16_19/3dna/bp_19_fnmm16_19.csv',names=headers_list1)
fn16_19_bp18=pd.read_csv('/storage3/gayatrip/EMX1_Fn_mm16_19/pyemma_fnmm16_19/3dna/bp_18_fnmm16_19.csv',names=headers_list1)
fn16_19_bp17=pd.read_csv('/storage3/gayatrip/EMX1_Fn_mm16_19/pyemma_fnmm16_19/3dna/bp_17_fnmm16_19.csv',names=headers_list1)
fn16_19_bp20=fn16_19_bp20.sort_values('Frames').reset_index()
fn16_19_bp19=fn16_19_bp19.sort_values('Frames').reset_index()
fn16_19_bp18=fn16_19_bp18.sort_values('Frames').reset_index()
fn16_19_bp17=fn16_19_bp17.sort_values('Frames').reset_index()
fn16_19_bp20.head()
# Out:
#    index  Frames  bp-pos  bps  Shear  Stretch  Stagger  Buckle  Propeller  \
# 0  11096       1       1  G-C  -0.56    -0.09    -0.67  -33.32     -16.11
# 1   1107      10       1  G-C  -0.40    -0.02    -0.86  -34.47     -19.87
# 2   2218      11       1  G-C  -0.82    -0.24    -0.75  -22.97     -19.75
# 3   3328      12       1  G-C  -0.58    -0.10    -0.62  -21.09      -2.28
# 4   4435      13       1  G-C  -0.85    -0.05    -0.80  -25.53      -9.24
#
#    Opening
# 0    -1.79
# 1    -3.28
# 2     3.56
# 3    -7.73
# 4     3.44

# %%
fn16_19_bp20.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
fn16_19_bp19.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
fn16_19_bp18.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
fn16_19_bp17.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
list1=['fn_16_19_shear_20','fn_16_19_stretch_20','fn_16_19_stagger_20','fn_16_19_buckle_20','fn_16_19_propeller_20','fn_16_19_opening_20']
list2=['fn_16_19_shear_19','fn_16_19_stretch_19','fn_16_19_stagger_19','fn_16_19_buckle_19','fn_16_19_propeller_19','fn_16_19_opening_19']
list3=['fn_16_19_shear_18','fn_16_19_stretch_18','fn_16_19_stagger_18','fn_16_19_buckle_18','fn_16_19_propeller_18','fn_16_19_opening_18']
list4=['fn_16_19_shear_17','fn_16_19_stretch_17','fn_16_19_stagger_17','fn_16_19_buckle_17','fn_16_19_propeller_17','fn_16_19_opening_17']
fn16_19_bp20.columns=list1
fn16_19_bp19.columns=list2
fn16_19_bp18.columns=list3
fn16_19_bp17.columns=list4
fn_mm16_19_all_bps=pd.concat([fn16_19_bp20,fn16_19_bp19,fn16_19_bp18,fn16_19_bp17], axis=1)
fn_mm16_19_all_bps.to_csv('fn_16_19_all_bps.csv', index=False)

# %%
fn17_20_bp20=pd.read_csv(root_dir+'EMX1-Fn_mm17-20/pyemma_fnmm17-20/3dna/bp_20_fnmm17-20.csv', names=headers_list1)
fn17_20_bp19=pd.read_csv(root_dir+'EMX1-Fn_mm17-20/pyemma_fnmm17-20/3dna/bp_19_fnmm17-20.csv', names=headers_list1)
fn17_20_bp18=pd.read_csv(root_dir+'EMX1-Fn_mm17-20/pyemma_fnmm17-20/3dna/bp_18_fnmm17-20.csv', names=headers_list1)
fn17_20_bp17=pd.read_csv(root_dir+'EMX1-Fn_mm17-20/pyemma_fnmm17-20/3dna/bp_17_fnmm17-20.csv', names=headers_list1)


#bp        Shear    Stretch   Stagger    Buckle  Propeller  Opening
fn17_20_bp20=fn17_20_bp20.sort_values('Frames').reset_index()
fn17_20_bp19=fn17_20_bp19.sort_values('Frames').reset_index()
fn17_20_bp18=fn17_20_bp18.sort_values('Frames').reset_index()
fn17_20_bp17=fn17_20_bp17.sort_values('Frames').reset_index()

fn17_20_bp17.head()
# Out:
#    index  Frames  bp-pos  bps  Shear  Stretch  Stagger  Buckle  Propeller  \
# 0    779       1       4  G-C   0.02    -0.09     0.07   11.91      -5.67
# 1   1927      10       2  G-C  -0.58     0.04     0.60   31.55       3.62
# 2    314      11       4  G-C  -0.42    -0.21     0.40   24.03      -6.36
# 3    334      12       4  G-C  -0.35    -0.16     0.13    6.03     -10.18
# 4    356      13       4  G-C   0.42     0.03    -0.15   17.61     -18.90
#
#    Opening
# 0    -8.00
# 1     3.55
# 2    -3.67
# 3    -4.52
# 4   -11.61

# %%
fn17_20_bp20.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
fn17_20_bp19.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
fn17_20_bp18.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
fn17_20_bp17.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
list1=['fn_mm17-20_shear_20','fn_mm17-20_stretch_20','fn_mm17-20_stagger_20','fn_mm17-20_buckle_20','fn_mm17-20_propeller_20','fn_mm17-20_opening_20']
list2=['fn_mm17-20_shear_19','fn_mm17-20_stretch_19','fn_mm17-20_stagger_19','fn_mm17-20_buckle_19','fn_mm17-20_propeller_19','fn_mm17-20_opening_19']
list3=['fn_mm17-20_shear_18','fn_mm17-20_stretch_18','fn_mm17-20_stagger_18','fn_mm17-20_buckle_18','fn_mm17-20_propeller_18','fn_mm17-20_opening_18']
list4=['fn_mm17-20_shear_17','fn_mm17-20_stretch_17','fn_mm17-20_stagger_17','fn_mm17-20_buckle_17','fn_mm17-20_propeller_17','fn_mm17-20_opening_17']
fn17_20_bp20.columns=list1
fn17_20_bp19.columns=list2
fn17_20_bp18.columns=list3
fn17_20_bp17.columns=list4
fn_mm17_20_all_bps=pd.concat([fn17_20_bp20,fn17_20_bp19,fn17_20_bp18,fn17_20_bp17], axis=1)
fn_mm17_20_all_bps.to_csv('fn_mm17-20_all_bps.csv', index=False)

# %%
fnmm20_bp20
# Out:
#       fn_mm20_shear_20  fn_mm20_stretch_20  fn_mm20_stagger_20  \
# 0                 0.03               -1.71               -0.95
# 1                -1.13               -1.75               -0.85
# 2                -0.59               -1.68               -1.17
# 3                -0.47               -1.61               -0.84
# 4                -1.32               -1.70               -0.66
# ...                ...                 ...                 ...
# 2249             -2.45                1.90                1.01
# 2250             -1.69                2.43               -0.16
# 2251             -1.77                2.35               -0.52
# 2252             -1.99                2.21                0.42
# 2253             -1.17                2.62               -0.28
#
#       fn_mm20_buckle_20  fn_mm20_propeller_20  fn_mm20_opening_20
# 0                  9.14                -26.28               15.14
# 1                -12.41                -34.23               14.72
# ...

# %%
print(fn17_20_bp19.columns)


fn_bp_20_she=pd.DataFrame(list(zip(list(fn_df_20['fn_20_shear']),list(fnmm20_bp20['fn_mm20_shear_20']),list(fn16_19_bp20['fn_16_19_shear_20']),list(fn17_20_bp20['fn_mm17-20_shear_20']))))
fn_bp_19_she=pd.DataFrame(list(zip(list(fn_df_19['fn_19_shear']),list(fnmm20_bp19['fn_mm20_shear_19']),list(fn16_19_bp19['fn_16_19_shear_19']),list(fn17_20_bp19['fn_mm17-20_shear_19']))))
fn_bp_18_she=pd.DataFrame(list(zip(list(fn_df_18['fn_18_shear']),list(fnmm20_bp18['fn_mm20_shear_18']),list(fn16_19_bp18['fn_16_19_shear_18']),list(fn17_20_bp18['fn_mm17-20_shear_18']))))
fn_bp_17_she=pd.DataFrame(list(zip(list(fn_df_17['fn_17_shear']),list(fnmm20_bp17['fn_mm20_shear_17']),list(fn16_19_bp17['fn_16_19_shear_17']),list(fn17_20_bp17['fn_mm17-20_shear_17']))))
#fn_bp_16_she=pd.DataFrame(list(zip(list(fn_df_16['fn_16_shear']),list(fnmm20_df_16['fnmm20_16_shear'],list(fn17_20_bp16['fnmm17-20_16_shear']))))

fn_bp_20_sta=pd.DataFrame(list(zip(list(fn_df_20['fn_20_stagger']),list(fnmm20_bp20['fn_mm20_stagger_20']),list(fn16_19_bp20['fn_16_19_stagger_20']),list(fn17_20_bp20['fn_mm17-20_stagger_20']))))
fn_bp_19_sta=pd.DataFrame(list(zip(list(fn_df_19['fn_19_stagger']),list(fnmm20_bp19['fn_mm20_stagger_19']),list(fn16_19_bp19['fn_16_19_stagger_19']),list(fn17_20_bp19['fn_mm17-20_stagger_19']))))
fn_bp_18_sta=pd.DataFrame(list(zip(list(fn_df_18['fn_18_stagger']),list(fnmm20_bp18['fn_mm20_stagger_18']),list(fn16_19_bp18['fn_16_19_stagger_18']),list(fn17_20_bp18['fn_mm17-20_stagger_18']))))
fn_bp_17_sta=pd.DataFrame(list(zip(list(fn_df_17['fn_17_stagger']),list(fnmm20_bp17['fn_mm20_stagger_17']),list(fn16_19_bp17['fn_16_19_stagger_17']),list(fn17_20_bp17['fn_mm17-20_stagger_17']))))
#fn_bp_16_sta=pd.DataFrame(list(zip(list(fn_df_16['fn_16_stagger']),list(fnmm20_df_16['fnmm20_16_stagger'],list(fn17_20_bp16['fnmm17-20_16_stagger']))))

fn_bp_20_str=pd.DataFrame(list(zip(list(fn_df_20['fn_20_stretch']),list(fnmm20_bp20['fn_mm20_stretch_20']),list(fn16_19_bp20['fn_16_19_stretch_20']),list(fn17_20_bp20['fn_mm17-20_stretch_20']))))
fn_bp_19_str=pd.DataFrame(list(zip(list(fn_df_19['fn_19_stretch']),list(fnmm20_bp19['fn_mm20_stretch_19']),list(fn16_19_bp19['fn_16_19_stretch_19']),list(fn17_20_bp19['fn_mm17-20_stretch_19']))))
fn_bp_18_str=pd.DataFrame(list(zip(list(fn_df_18['fn_18_stretch']),list(fnmm20_bp18['fn_mm20_stretch_18']),list(fn16_19_bp18['fn_16_19_stretch_18']),list(fn17_20_bp18['fn_mm17-20_stretch_18']))))
fn_bp_17_str=pd.DataFrame(list(zip(list(fn_df_17['fn_17_stretch']),list(fnmm20_bp17['fn_mm20_stretch_17']),list(fn16_19_bp17['fn_16_19_stretch_17']),list(fn17_20_bp17['fn_mm17-20_stretch_17']))))
#fn_bp_16_str=pd.DataFrame(list(zip(list(fn_df_16['fn_16_stretch']),list(fnmm20_df_16['fnmm20_16_stretch'],list(fn17_20_bp16['fnmm17-20_16_stretch']))))

fn_bp_20_buc=pd.DataFrame(list(zip(list(fn_df_20['fn_20_buckle']),list(fnmm20_bp20['fn_mm20_buckle_20']),list(fn16_19_bp20['fn_16_19_buckle_20']),list(fn17_20_bp20['fn_mm17-20_buckle_20']))))
fn_bp_19_buc=pd.DataFrame(list(zip(list(fn_df_19['fn_19_buckle']),list(fnmm20_bp19['fn_mm20_buckle_19']),list(fn16_19_bp19['fn_16_19_buckle_19']),list(fn17_20_bp19['fn_mm17-20_buckle_19']))))
fn_bp_18_buc=pd.DataFrame(list(zip(list(fn_df_18['fn_18_buckle']),list(fnmm20_bp18['fn_mm20_buckle_18']),list(fn16_19_bp18['fn_16_19_buckle_18']),list(fn17_20_bp18['fn_mm17-20_buckle_18']))))
fn_bp_17_buc=pd.DataFrame(list(zip(list(fn_df_17['fn_17_buckle']),list(fnmm20_bp17['fn_mm20_buckle_17']),list(fn16_19_bp17['fn_16_19_buckle_17']),list(fn17_20_bp17['fn_mm17-20_buckle_17']))))
#fn_bp_16_buc=pd.DataFrame(list(zip(list(fn_df_16['fn_16_buckle']),list(fnmm20_df_16['fnmm20_16_buckle'],list(fn17_20_bp16['fnmm17-20_16_buckle']))))

fn_bp_20_pro=pd.DataFrame(list(zip(list(fn_df_20['fn_20_propeller']),list(fnmm20_bp20['fn_mm20_propeller_20']),list(fn16_19_bp20['fn_16_19_propeller_20']),list(fn17_20_bp20['fn_mm17-20_propeller_20']))))
fn_bp_19_pro=pd.DataFrame(list(zip(list(fn_df_19['fn_19_propeller']),list(fnmm20_bp19['fn_mm20_propeller_19']),list(fn16_19_bp19['fn_16_19_propeller_19']),list(fn17_20_bp19['fn_mm17-20_propeller_19']))))
fn_bp_18_pro=pd.DataFrame(list(zip(list(fn_df_18['fn_18_propeller']),list(fnmm20_bp18['fn_mm20_propeller_18']),list(fn16_19_bp18['fn_16_19_propeller_18']),list(fn17_20_bp18['fn_mm17-20_propeller_18']))))
fn_bp_17_pro=pd.DataFrame(list(zip(list(fn_df_17['fn_17_propeller']),list(fnmm20_bp17['fn_mm20_propeller_17']),list(fn16_19_bp17['fn_16_19_propeller_17']),list(fn17_20_bp17['fn_mm17-20_propeller_17']))))
#fn_bp_16_pro=pd.DataFrame(list(zip(list(fn_df_16['fn_16_propeller']),list(fnmm20_df_16['fnmm20_16_propeller'],list(fn17_20_bp16['fnmm17-20_16_propeller']))))

fn_bp_20_ope=pd.DataFrame(list(zip(list(fn_df_20['fn_20_opening']),list(fnmm20_bp20['fn_mm20_opening_20']),list(fn16_19_bp20['fn_16_19_opening_20']),list(fn17_20_bp20['fn_mm17-20_opening_20']))))
fn_bp_19_ope=pd.DataFrame(list(zip(list(fn_df_19['fn_19_opening']),list(fnmm20_bp19['fn_mm20_opening_19']),list(fn16_19_bp19['fn_16_19_opening_19']),list(fn17_20_bp19['fn_mm17-20_opening_19']))))
fn_bp_18_ope=pd.DataFrame(list(zip(list(fn_df_18['fn_18_opening']),list(fnmm20_bp18['fn_mm20_opening_18']),list(fn16_19_bp18['fn_16_19_opening_18']),list(fn17_20_bp18['fn_mm17-20_opening_18']))))
fn_bp_17_ope=pd.DataFrame(list(zip(list(fn_df_17['fn_17_opening']),list(fnmm20_bp17['fn_mm20_opening_17']),list(fn16_19_bp17['fn_16_19_opening_17']),list(fn17_20_bp17['fn_mm17-20_opening_17']))))
#fn_bp_16_ope=pd.DataFrame(list(zip(list(fn_df_16['fn_16_opening']),list(fnmm20_df_16['fnmm20_16_opening'],list(fn17_20_bp16['fnmm17-20_16_opening']))))
# Out:
# Index(['fn_mm17-20_shear_19', 'fn_mm17-20_stretch_19', 'fn_mm17-20_stagger_19',
#        'fn_mm17-20_buckle_19', 'fn_mm17-20_propeller_19',
#        'fn_mm17-20_opening_19'],
#       dtype='object')

# %%
fn_bp_20_she.columns=['fn_nat_shear','fn_mm20_shear','fn_mm16_19_shear','fn_mm17-20_shear']
fn_bp_19_she.columns=['fn_nat_shear','fn_mm20_shear','fn_mm16_19_shear','fn_mm17-20_shear']
fn_bp_18_she.columns=['fn_nat_shear','fn_mm20_shear','fn_mm16_19_shear','fn_mm17-20_shear']
fn_bp_17_she.columns=['fn_nat_shear','fn_mm20_shear','fn_mm16_19_shear','fn_mm17-20_shear']

fn_bp_20_sta.columns=['fn_nat_stagger','fn_mm20_stagger','fn_mm16_19_stagger','fn_mm17-20_stagger']
fn_bp_19_sta.columns=['fn_nat_stagger','fn_mm20_stagger','fn_mm16_19_stagger','fn_mm17-20_stagger']
fn_bp_18_sta.columns=['fn_nat_stagger','fn_mm20_stagger','fn_mm16_19_stagger','fn_mm17-20_stagger']
fn_bp_17_sta.columns=['fn_nat_stagger','fn_mm20_stagger','fn_mm16_19_stagger','fn_mm17-20_stagger']

fn_bp_20_str.columns=['fn_nat_stretch','fn_mm20_stretch','fn_mm16_19_stretch','fn_mm17-20_stretch']
fn_bp_19_str.columns=['fn_nat_stretch','fn_mm20_stretch','fn_mm16_19_stretch','fn_mm17-20_stretch']
fn_bp_18_str.columns=['fn_nat_stretch','fn_mm20_stretch','fn_mm16_19_stretch','fn_mm17-20_stretch']
fn_bp_17_str.columns=['fn_nat_stretch','fn_mm20_stretch','fn_mm16_19_stretch','fn_mm17-20_stretch']

fn_bp_20_ope.columns=['fn_nat_opening','fn_mm20_opening','fn_mm16_19_opening','fn_mm17-20_opening']
fn_bp_19_ope.columns=['fn_nat_opening','fn_mm20_opening','fn_mm16_19_opening','fn_mm17-20_opening']
fn_bp_18_ope.columns=['fn_nat_opening','fn_mm20_opening','fn_mm16_19_opening','fn_mm17-20_opening']
fn_bp_17_ope.columns=['fn_nat_opening','fn_mm20_opening','fn_mm16_19_opening','fn_mm17-20_opening']

fn_bp_20_pro.columns=['fn_nat_propeller','fn_mm20_propeller','fn_mm16_19_propeller','fn_mm17-20_propeller']
fn_bp_19_pro.columns=['fn_nat_propeller','fn_mm20_propeller','fn_mm16_19_propeller','fn_mm17-20_propeller']
fn_bp_18_pro.columns=['fn_nat_propeller','fn_mm20_propeller','fn_mm16_19_propeller','fn_mm17-20_propeller']
fn_bp_17_pro.columns=['fn_nat_propeller','fn_mm20_propeller','fn_mm16_19_propeller','fn_mm17-20_propeller']

fn_bp_20_buc.columns=['fn_nat_buckle','fn_mm20_buckle','fn_mm16_19_buckle','fn_mm17-20_buckle']
fn_bp_19_buc.columns=['fn_nat_buckle','fn_mm20_buckle','fn_mm16_19_buckle','fn_mm17-20_buckle']
fn_bp_18_buc.columns=['fn_nat_buckle','fn_mm20_buckle','fn_mm16_19_buckle','fn_mm17-20_buckle']
fn_bp_17_buc.columns=['fn_nat_buckle','fn_mm20_buckle','fn_mm16_19_buckle','fn_mm17-20_buckle']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
plt.figure(figsize=(14.5,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[fn_bp_20_she['fn_nat_shear'],fn_bp_20_she['fn_mm20_shear'],fn_bp_20_she['fn_mm16_19_shear'],fn_bp_20_she['fn_mm17-20_shear']], scale="width", palette="viridis",linewidth=0.5)
ax1.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax1.set_ylabel('FnCas9 shear for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[fn_bp_19_she['fn_nat_shear'],fn_bp_19_she['fn_mm20_shear'],fn_bp_19_she['fn_mm16_19_shear'],fn_bp_19_she['fn_mm17-20_shear']], scale="width", palette="viridis",linewidth=0.5)
ax2.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax2.set_ylabel('FnCas9 shear for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[fn_bp_18_she['fn_nat_shear'],fn_bp_18_she['fn_mm20_shear'],fn_bp_18_she['fn_mm16_19_shear'],fn_bp_18_she['fn_mm17-20_shear']], scale="width", palette="viridis",linewidth=0.5)
ax3.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax3.set_ylabel('FnCas9 shear for bp18', fontsize=14)

plt.subplot(2,2,4)
#ax4=sns.violinplot(data=[fn_bp_17_she['fn_nat_shear'],fn_bp_17_she['fn_mm20_shear'],fn_bp_17_she['fn_mm16_19_shear'],fn_bp_17_she['fn_mm17-20_shear']], scale="width", palette="viridis",linewidth=0.5)
ax4=sns.violinplot(data=[fn_bp_17_she['fn_nat_shear'],fn_bp_17_she['fn_mm20_shear'],fn_bp_17_she['fn_mm16_19_shear'],fn_bp_17_she['fn_mm17-20_shear']], scale="width", palette="viridis",linewidth=0.5)
ax4.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax4.set_ylabel('FnCas9 shear for bp17', fontsize=14)

#plt.savefig('figures/FnCas9_all_shear.svg')
plt.show()

# %%
plt.figure(figsize=(14.5,7))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[fn_bp_20_pro['fn_nat_propeller'],fn_bp_20_pro['fn_mm20_propeller'],fn_bp_20_pro['fn_mm16_19_propeller'],fn_bp_20_pro['fn_mm17-20_propeller']], scale="width", palette="viridis",linewidth=0.5)
#ax1.set_xticklabels(['Fn_nat_bp20','Fn_mm20_bp20','Fn_mm16_19_bp20','Fn_mm17-20_bp20'])
ax1.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax1.set_ylabel('FnCas9 propeller for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[fn_bp_19_pro['fn_nat_propeller'],fn_bp_19_pro['fn_mm20_propeller'],fn_bp_19_pro['fn_mm16_19_propeller'],fn_bp_19_pro['fn_mm17-20_propeller']], scale="width", palette="viridis",linewidth=0.5)
#ax2.set_xticklabels(['Fn_nat_bp19','Fn_mm20_bp19','Fn_mm16_19_bp19','Fn_mm17-20_bp19'])
ax2.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax2.set_ylabel('FnCas9 propeller for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[fn_bp_18_pro['fn_nat_propeller'],fn_bp_18_pro['fn_mm20_propeller'],fn_bp_18_pro['fn_mm16_19_propeller'],fn_bp_18_pro['fn_mm17-20_propeller']], scale="width", palette="viridis",linewidth=0.5)
#ax3.set_xticklabels(['Fn_nat_bp18','Fn_mm20_bp18','Fn_mm16_19_bp18','Fn_mm17-20_bp18'])
ax3.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax3.set_ylabel('FnCas9 propeller for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[fn_bp_17_pro['fn_nat_propeller'],fn_bp_17_pro['fn_mm20_propeller'],fn_bp_17_pro['fn_mm16_19_propeller'],fn_bp_17_pro['fn_mm17-20_propeller']], scale="width", palette="viridis",linewidth=0.5)
#ax4.set_xticklabels(['Fn_nat_bp17','Fn_mm20_bp17','Fn_mm16_19_bp17','Fn_mm17-20_bp17'])
ax4.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax4.set_ylabel('FnCas9 propeller for bp17', fontsize=14)

#plt.savefig('figures/FnCas9_all_propeller.svg')
plt.show()

# %%
plt.figure(figsize=(14.5,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[fn_bp_20_sta['fn_nat_stagger'],fn_bp_20_sta['fn_mm20_stagger'],fn_bp_20_sta['fn_mm16_19_stagger'],fn_bp_20_sta['fn_mm17-20_stagger']], scale="width", palette="viridis",linewidth=0.5)
#ax1.set_xticklabels(['Fn_nat_bp20','Fn_mm20_bp20','Fn_mm16_19_bp20','Fn_mm17-20_bp20'])
ax1.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax1.set_ylabel('FnCas9 stagger for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[fn_bp_19_sta['fn_nat_stagger'],fn_bp_19_sta['fn_mm20_stagger'],fn_bp_19_sta['fn_mm16_19_stagger'],fn_bp_19_sta['fn_mm17-20_stagger']], scale="width", palette="viridis",linewidth=0.5)
#ax2.set_xticklabels(['Fn_nat_bp19','Fn_mm20_bp19','Fn_mm16_19_bp19','Fn_mm17-20_bp19'])
ax2.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax2.set_ylabel('FnCas9 stagger for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[fn_bp_18_sta['fn_nat_stagger'],fn_bp_18_sta['fn_mm20_stagger'],fn_bp_18_sta['fn_mm16_19_stagger'],fn_bp_18_sta['fn_mm17-20_stagger']], scale="width", palette="viridis",linewidth=0.5)
#ax3.set_xticklabels(['Fn_nat_bp18','Fn_mm20_bp18','Fn_mm16_19_bp18','Fn_mm17-20_bp18'])
ax3.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax3.set_ylabel('FnCas9 stagger for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[fn_bp_17_sta['fn_nat_stagger'],fn_bp_17_sta['fn_mm20_stagger'],fn_bp_17_sta['fn_mm16_19_stagger'],fn_bp_17_sta['fn_mm17-20_stagger']], scale="width", palette="viridis",linewidth=0.5)
#ax4.set_xticklabels(['Fn_nat_bp17','Fn_mm20_bp17','Fn_mm16_19_bp17','Fn_mm17-20_bp17'])
ax4.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax4.set_ylabel('FnCas9 stagger for bp17', fontsize=14)

#plt.savefig('figures/FnCas9_all_stagger.svg')
plt.show()

# %%
plt.figure(figsize=(14.5,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[fn_bp_20_buc['fn_nat_buckle'],fn_bp_20_buc['fn_mm20_buckle'],fn_bp_20_buc['fn_mm16_19_buckle'],fn_bp_20_buc['fn_mm17-20_buckle']], scale="width", palette="viridis",linewidth=0.5)
#ax1.set_xticklabels(['Fn_nat_bp20','Fn_mm20_bp20','Fn_mm16_19_bp20','Fn_mm17-20_bp20'])
ax1.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax1.set_ylabel('FnCas9 buckle for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[fn_bp_19_buc['fn_nat_buckle'],fn_bp_19_buc['fn_mm20_buckle'],fn_bp_19_buc['fn_mm16_19_buckle'],fn_bp_19_buc['fn_mm17-20_buckle']], scale="width", palette="viridis",linewidth=0.5)
#ax2.set_xticklabels(['Fn_nat_bp19','Fn_mm20_bp19','Fn_mm16_19_bp19','Fn_mm17-20_bp19'])
ax2.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax2.set_ylabel('FnCas9 buckle for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[fn_bp_18_buc['fn_nat_buckle'],fn_bp_18_buc['fn_mm20_buckle'],fn_bp_18_buc['fn_mm16_19_buckle'],fn_bp_18_buc['fn_mm17-20_buckle']], scale="width", palette="viridis",linewidth=0.5)
#ax3.set_xticklabels(['Fn_nat_bp18','Fn_mm20_bp18','Fn_mm16_19_bp18','Fn_mm17-20_bp18'])
ax3.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax3.set_ylabel('FnCas9 buckle for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[fn_bp_17_buc['fn_nat_buckle'],fn_bp_17_buc['fn_mm20_buckle'],fn_bp_17_buc['fn_mm16_19_buckle'],fn_bp_17_buc['fn_mm17-20_buckle']], scale="width", palette="viridis",linewidth=0.5)
#ax4.set_xticklabels(['Fn_nat_bp17','Fn_mm20_bp17','Fn_mm16_19_bp17','Fn_mm17-20_bp17'])
ax4.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax4.set_ylabel('FnCas9 buckle for bp17', fontsize=14)

#plt.savefig('figures/FnCas9_all_buckle.svg')
plt.show()

# %%
plt.figure(figsize=(14.5,7))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[fn_bp_20_ope['fn_nat_opening'],fn_bp_20_ope['fn_mm20_opening'],fn_bp_20_ope['fn_mm16_19_opening'],fn_bp_20_ope['fn_mm17-20_opening']], scale="width", palette="viridis",linewidth=0.5)
#ax1.set_xticklabels(['Fn_nat_bp20','Fn_mm20_bp20','Fn_mm16_19_bp20','Fn_mm17-20_bp20'])
ax1.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax1.set_ylabel('FnCas9 opening for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[fn_bp_19_ope['fn_nat_opening'],fn_bp_19_ope['fn_mm20_opening'],fn_bp_19_ope['fn_mm16_19_opening'],fn_bp_19_ope['fn_mm17-20_opening']], scale="width", palette="viridis",linewidth=0.5)
#ax2.set_xticklabels(['Fn_nat_bp19','Fn_mm20_bp19','Fn_mm16_19_bp19','Fn_mm17-20_bp19'])
ax2.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax2.set_ylabel('FnCas9 opening for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[fn_bp_18_ope['fn_nat_opening'],fn_bp_18_ope['fn_mm20_opening'],fn_bp_18_ope['fn_mm16_19_opening'],fn_bp_18_ope['fn_mm17-20_opening']], scale="width", palette="viridis",linewidth=0.5)
#ax3.set_xticklabels(['Fn_nat_bp18','Fn_mm20_bp18','Fn_mm16_19_bp18','Fn_mm17-20_bp18'])
ax3.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax3.set_ylabel('FnCas9 opening for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[fn_bp_17_ope['fn_nat_opening'],fn_bp_17_ope['fn_mm20_opening'],fn_bp_17_ope['fn_mm16_19_opening'],fn_bp_17_ope['fn_mm17-20_opening']], scale="width", palette="viridis",linewidth=0.5)
#ax4.set_xticklabels(['Fn_nat_bp17','Fn_mm20_bp17','Fn_mm16_19_bp17','Fn_mm17-20_bp17'])
ax4.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax4.set_ylabel('FnCas9 opening for bp17', fontsize=14)

#plt.savefig('figures/FnCas9_all_opening.svg')
plt.show()

# %%
plt.figure(figsize=(14.5,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[fn_bp_20_str['fn_nat_stretch'],fn_bp_20_str['fn_mm20_stretch'],fn_bp_20_str['fn_mm16_19_stretch'],fn_bp_20_str['fn_mm17-20_stretch']], scale="width", palette="viridis",linewidth=0.5)
#ax1.set_xticklabels(['Fn_nat_bp20','Fn_mm20_bp20','Fn_mm16_19_bp20','Fn_mm17-20_bp20'])
ax1.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax1.set_ylabel('FnCas9 stretch for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[fn_bp_19_str['fn_nat_stretch'],fn_bp_19_str['fn_mm20_stretch'],fn_bp_19_str['fn_mm16_19_stretch'],fn_bp_19_str['fn_mm17-20_stretch']], scale="width", palette="viridis",linewidth=0.5)
#ax2.set_xticklabels(['Fn_nat_bp19','Fn_mm20_bp19','Fn_mm16_19_bp19','Fn_mm17-20_bp19'])
ax2.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax2.set_ylabel('FnCas9 stretch for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[fn_bp_18_str['fn_nat_stretch'],fn_bp_18_str['fn_mm20_stretch'],fn_bp_18_str['fn_mm16_19_stretch'],fn_bp_18_str['fn_mm17-20_stretch']], scale="width", palette="viridis",linewidth=0.5)
#ax3.set_xticklabels(['Fn_nat_bp18','Fn_mm20_bp18','Fn_mm16_19_bp18','Fn_mm17-20_bp18'])
ax3.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax3.set_ylabel('FnCas9 stretch for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[fn_bp_17_str['fn_nat_stretch'],fn_bp_17_str['fn_mm20_stretch'],fn_bp_17_str['fn_mm16_19_stretch'],fn_bp_17_str['fn_mm17-20_stretch']], scale="width", palette="viridis",linewidth=0.5)
#ax4.set_xticklabels(['Fn_nat_bp17','Fn_mm20_bp17','Fn_mm16_19_bp17','Fn_mm17-20_bp17'])
ax4.set_xticklabels(['Fn_nat','Fn_mm20','Fn_mm16_19','Fn_mm17-20'], fontsize=14)
ax4.set_ylabel('FnCas9 stretch for bp17', fontsize=14)

#plt.savefig('figures/FnCas9_all_stretch.svg')
plt.show()
