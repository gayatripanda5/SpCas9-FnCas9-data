# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)

# %%
import pandas as pd
#/storage/gayatrip/gamd-amber-example/NII-work-2022/sp_native_gamd
#2,14,22,

headers_list1=['Frames','bp-pos','bps','Shear','Stretch','Stagger','Buckle','Propeller','Opening']
root_dir='/storage3/gayatrip/'
na_sp=open('/storage3/gayatrip/EMX1-Sp_native_rep/spnat_nodt_out/BP.nastruct_nodt-500ns_500frames.dat','r')
#na_sp16_19=open(root_dir+'EMX1_sp_mm16_19/BP.5b2o_mm16_19_nastruct_250ns_1000frames.dat')



# sp17_20_bp20=pd.read_csv(root_dir+'sp_mm17-20/500_pdbs/sp_mm17-20_bp_20.txt', names=headers_list)
# sp17_20_bp19=pd.read_csv(root_dir+'sp_mm17-20/500_pdbs/sp_mm17-20_bp_19.txt', names=headers_list)
# sp17_20_bp18=pd.read_csv(root_dir+'sp_mm17-20/500_pdbs/sp_mm17-20_bp_18.txt', names=headers_list)
# sp17_20_bp17=pd.read_csv(root_dir+'sp_mm17-20/500_pdbs/sp_mm17-20_bp_17.txt', names=headers_list)
#na_spmm17_20=open(root_dir+ 'sp_mm17-20/BP.nastruct_500ns_500frames_sp_mm17-20.dat','r')

### For spCas9_native system
lines=na_sp.readlines()
bp_20=[]
bp_19=[]
bp_18=[]
bp_17=[]
bp_16=[]
bp_15=[]
bp_14=[]
bp_13=[]
bp_12=[]
bp_11=[]
#while (i < len(lines))
for i in range(1,len(lines),14):
    bp_20.append(lines[i].strip().split())

for i in range(2,len(lines),14):
    bp_19.append(lines[i].strip().split())

for i in range(3,len(lines),14):
    bp_18.append(lines[i].strip().split())

for i in range(4,len(lines),14):
    bp_17.append(lines[i].strip().split())

for i in range(5,len(lines),14):
    bp_16.append(lines[i].strip().split())

for i in range(6,len(lines),14):
    bp_15.append(lines[i].strip().split())

for i in range(7,len(lines),14):
    bp_14.append(lines[i].strip().split())

for i in range(8,len(lines),14):
    bp_13.append(lines[i].strip().split())

for i in range(9,len(lines),14):
    bp_12.append(lines[i].strip().split())

for i in range(10,len(lines),14):
    bp_11.append(lines[i].strip().split())
# Out:
# Error.  nthreads cannot be larger than environment variable "NUMEXPR_MAX_THREADS" (64)

# %%
shear_20=[]
str_20=[]
sta_20=[]
buc_20=[]
pro_20=[]
ope_20=[]
maj_20=[]
min_20=[]
for i in range(len(bp_20)-1):
    shear_20.append(float(bp_20[i][3]))
    str_20.append(float(bp_20[i][4]))
    sta_20.append(float(bp_20[i][5]))
    buc_20.append(float(bp_20[i][6]))
    pro_20.append(float(bp_20[i][7]))
    ope_20.append(float(bp_20[i][8]))
    maj_20.append(float(bp_20[i][11]))
    min_20.append(float(bp_20[i][12]))
    
shear_19=[]
str_19=[]
sta_19=[]
buc_19=[]
pro_19=[]
ope_19=[]
maj_19=[]
min_19=[]
for i in range(len(bp_19)-1):
    shear_19.append(float(bp_19[i][3]))
    str_19.append(float(bp_19[i][4]))
    sta_19.append(float(bp_19[i][5]))
    buc_19.append(float(bp_19[i][6]))
    pro_19.append(float(bp_19[i][7]))
    ope_19.append(float(bp_19[i][8]))
    maj_19.append(float(bp_19[i][11]))
    min_19.append(float(bp_19[i][12]))

shear_18=[]
str_18=[]
sta_18=[]
buc_18=[]
pro_18=[]
ope_18=[]
maj_18=[]
min_18=[]
for i in range(len(bp_18)-1):
    shear_18.append(float(bp_18[i][3]))
    str_18.append(float(bp_18[i][4]))
    sta_18.append(float(bp_18[i][5]))
    buc_18.append(float(bp_18[i][6]))
    pro_18.append(float(bp_18[i][7]))
    ope_18.append(float(bp_18[i][8]))
    maj_18.append(float(bp_18[i][11]))
    min_18.append(float(bp_18[i][12]))
    
shear_17=[]
str_17=[]
sta_17=[]
buc_17=[]
pro_17=[]
ope_17=[]
maj_17=[]
min_17=[]
for i in range(len(bp_17)-1):
    shear_17.append(float(bp_17[i][3]))
    str_17.append(float(bp_17[i][4]))
    sta_17.append(float(bp_17[i][5]))
    buc_17.append(float(bp_17[i][6]))
    pro_17.append(float(bp_17[i][7]))
    ope_17.append(float(bp_17[i][8]))
    maj_17.append(float(bp_17[i][11]))
    min_17.append(float(bp_17[i][12]))

shear_16=[]
str_16=[]
sta_16=[]
buc_16=[]
pro_16=[]
ope_16=[]
maj_16=[]
min_16=[]
for i in range(len(bp_16)-1):
    shear_16.append(float(bp_16[i][3]))
    str_16.append(float(bp_16[i][4]))
    sta_16.append(float(bp_16[i][5]))
    buc_16.append(float(bp_16[i][6]))
    pro_16.append(float(bp_16[i][7]))
    ope_16.append(float(bp_16[i][8]))
    maj_16.append(float(bp_16[i][11]))
    min_16.append(float(bp_16[i][12]))
    

    
sp_df_20=pd.DataFrame(list(zip(shear_20,str_20,sta_20,buc_20,pro_20,ope_20,maj_20,min_20)),columns=['sp_20_shear','sp_20_stretch','sp_20_stagger','sp_20_buckle','sp_20_propeller','sp_20_opening','sp_20_major','sp_20_minor'])
sp_df_19=pd.DataFrame(list(zip(shear_19,str_19,sta_19,buc_19,pro_19,ope_19,maj_19,min_19)),columns=['sp_19_shear','sp_19_stretch','sp_19_stagger','sp_19_buckle','sp_19_propeller','sp_19_opening','sp_19_major','sp_19_minor'])
sp_df_18=pd.DataFrame(list(zip(shear_18,str_18,sta_18,buc_18,pro_18,ope_18,maj_18,min_18)),columns=['sp_18_shear','sp_18_stretch','sp_18_stagger','sp_18_buckle','sp_18_propeller','sp_18_opening','sp_18_major','sp_18_minor'])
sp_df_17=pd.DataFrame(list(zip(shear_17,str_17,sta_17,buc_17,pro_17,ope_17,maj_17,min_17)),columns=['sp_17_shear','sp_17_stretch','sp_17_stagger','sp_17_buckle','sp_17_propeller','sp_17_opening','sp_17_major','sp_17_minor'])
sp_df_16=pd.DataFrame(list(zip(shear_16,str_16,sta_16,buc_16,pro_16,ope_16,maj_16,min_16)),columns=['sp_16_shear','sp_16_stretch','sp_16_stagger','sp_16_buckle','sp_16_propeller','sp_16_opening','sp_16_major','sp_16_minor'])
    
    
    
maj_15=[]
min_15=[]
maj_14=[]
min_14=[]
maj_13=[]
min_13=[]
maj_12=[]
min_12=[]
maj_11=[]
min_11=[]

for i in range(len(bp_15)-1):
    maj_15.append(float(bp_15[i][11]))
    min_15.append(float(bp_15[i][12]))
for i in range(len(bp_14)-1):
    maj_14.append(float(bp_14[i][11]))
    min_14.append(float(bp_14[i][12]))
for i in range(len(bp_13)-1):
    maj_13.append(float(bp_13[i][11]))
    min_13.append(float(bp_13[i][12]))
for i in range(len(bp_12)-1):
    maj_12.append(float(bp_12[i][11]))
    min_12.append(float(bp_12[i][12]))
for i in range(len(bp_11)-1):
    maj_11.append(float(bp_11[i][11]))
    min_11.append(float(bp_11[i][12]))
major=[]
minor=[]
sp_maj=pd.DataFrame(list(zip(maj_20,maj_19,maj_18,maj_17,maj_16,maj_15,maj_14,maj_13,maj_12,maj_11)),columns=['bp20','bp19','bp18','bp17','bp16','bp15','bp14','bp13','bp12','bp11'] )
sp_min=pd.DataFrame(list(zip(min_20,min_19,min_18,min_17,min_16,min_15,min_14,min_13,min_12,min_11)),columns=['bp20','bp19','bp18','bp17','bp16','bp15','bp14','bp13','bp12','bp11'] )
min_std=list(sp_min.std())
min_avg=list(sp_min.mean())
maj_std=list(sp_maj.std())
maj_avg=list(sp_maj.mean())
maj_bps=list(range(20,11,-1))
min_bps=list(range(20,11,-1))
#df_maj.mean()
sp_min_groove=pd.DataFrame(list(zip(min_bps,min_avg,min_std)),columns=["sp_bps","sp_mean","sp_std"])
sp_maj_groove=pd.DataFrame(list(zip(maj_bps,maj_avg,maj_std)),columns=["sp_bps","sp_mean","sp_std"])
sp_min_groove.head()
print(maj_std,maj_avg,maj_bps)
print(sp_min_groove.head(),sp_maj_groove.head())
#minor.append(min_20,min_19,min_18,min_17,min_16,min_15,min_14,min_13,min_12,min_11)
# Out:
# [0.0, 9.077957850348916, 0.8571712457514256, 9.305752161032423, 8.302371905713317, 5.752057666304045, 9.499840016348147, 3.803783857130379, 0.9016311762779066, 2.2592297098687464] [0.0, 8.933436387118629, 18.386985238508608, 11.498373229446761, 12.555955717643073, 16.514373807456966, 8.69746861171688, 20.248424394994814, 18.179734447714424, 18.884923740763483] [20, 19, 18, 17, 16, 15, 14, 13, 12]
#    sp_bps    sp_mean    sp_std
# 0      20   8.232823  6.039174
# 1      19   5.246206  5.358288
# 2      18  12.381318  0.486299
# 3      17   7.566638  6.138793
# 4      16   8.997339  5.943260    sp_bps    sp_mean    sp_std
# 0      20   0.000000  0.000000
# 1      19   8.933436  9.077958
# 2      18  18.386985  0.857171
# 3      17  11.498373  9.305752
# 4      16  12.555956  8.302372

# %%
# !mkdir Sp_NA_csvs
# Out:
# mkdir: cannot create directory ‘Sp_NA_csvs’: File exists

# %%
sp_df_20.to_csv('Sp_NA_csvs/Sp_nat_bp20_prop.csv', index=False)
sp_df_19.to_csv('Sp_NA_csvs/Sp_nat_bp19_prop.csv', index=False)
sp_df_18.to_csv('Sp_NA_csvs/Sp_nat_bp18_prop.csv', index=False)
sp_df_17.to_csv('Sp_NA_csvs/Sp_nat_bp17_prop.csv', index=False)
sp_df_16.to_csv('Sp_NA_csvs/Sp_nat_bp16_prop.csv', index=False)
sp_df_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sp_20_shear      944 non-null    float64
#  1   sp_20_stretch    944 non-null    float64
#  2   sp_20_stagger    944 non-null    float64
#  3   sp_20_buckle     944 non-null    float64
#  4   sp_20_propeller  944 non-null    float64
#  5   sp_20_opening    944 non-null    float64
#  6   sp_20_major      944 non-null    float64
#  7   sp_20_minor      944 non-null    float64
# dtypes: float64(8)
# memory usage: 59.1 KB

# %%
sp_nat_bps=pd.concat([sp_df_20,sp_df_19,sp_df_18,sp_df_17], axis=1)
sp_nat_bps.head()
sp_nat_bps.to_csv('Sp_NA_csvs/sp_nat_all.csv', index=False)

# %%
spmm20_bp20=pd.read_csv(root_dir+'EMX1-Sp_mm20_rep/3dna_frames/bp_20_spmm20.csv',names=headers_list1)
spmm20_bp19=pd.read_csv(root_dir+'EMX1-Sp_mm20_rep/3dna_frames/bp_19_spmm20.csv',names=headers_list1)
spmm20_bp18=pd.read_csv(root_dir+'EMX1-Sp_mm20_rep/3dna_frames/bp_18_spmm20.csv',names=headers_list1)
spmm20_bp17=pd.read_csv(root_dir+'EMX1-Sp_mm20_rep/3dna_frames/bp_17_spmm20.csv',names=headers_list1)
spmm20_bp16=pd.read_csv(root_dir+'EMX1-Sp_mm20_rep/3dna_frames/bp_16_spmm20.csv',names=headers_list1)

# %%
spmm20_bp20=spmm20_bp20.sort_values('Frames').reset_index()
spmm20_bp19=spmm20_bp19.sort_values('Frames').reset_index()
spmm20_bp18=spmm20_bp18.sort_values('Frames').reset_index()
spmm20_bp17=spmm20_bp17.sort_values('Frames').reset_index()
spmm20_bp20.head()
# Out:
#    index  Frames  bp-pos  bps  Shear  Stretch  Stagger  Buckle  Propeller  \
# 0      0    3048       1  U-C  -9.31     4.19    -0.28  -49.06       9.69
# 1      1    3052       1  U-C  -8.62     4.62    -1.55  -29.20      35.87
# 2      2    3058       1  U-C  -7.99     3.80     0.06  -28.76      47.50
# 3      3    3060       1  U-C  -8.02     4.69     0.51  -27.75      35.87
# 4      4    3084       1  U-T  -8.71     5.50     2.16  -24.75      -0.86
#
#    Opening
# 0    -5.20
# 1   -20.32
# 2    -4.65
# 3    22.35
# 4   -61.05

# %%
spmm20_bp20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      22 non-null     int64
#  1   Frames     22 non-null     int64
#  2   bp-pos     22 non-null     int64
#  3   bps        22 non-null     object
#  4   Shear      22 non-null     float64
#  5   Stretch    22 non-null     float64
#  6   Stagger    22 non-null     float64
#  7   Buckle     22 non-null     float64
#  8   Propeller  22 non-null     float64
#  9   Opening    22 non-null     float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 1.8+ KB

# %%
spmm20_bp20.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
spmm20_bp19.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
spmm20_bp18.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
spmm20_bp17.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
#list1=['Shear','Stretch','Stagger','Buckle','Propeller','Opening']
list1=['sp_mm20_shear_20','sp_mm20_stretch_20','sp_mm20_stagger_20','sp_mm20_buckle_20','sp_mm20_propeller_20','sp_mm20_opening_20']
list2=['sp_mm20_shear_19','sp_mm20_stretch_19','sp_mm20_stagger_19','sp_mm20_buckle_19','sp_mm20_propeller_19','sp_mm20_opening_19']
list3=['sp_mm20_shear_18','sp_mm20_stretch_18','sp_mm20_stagger_18','sp_mm20_buckle_18','sp_mm20_propeller_18','sp_mm20_opening_18']
list4=['sp_mm20_shear_17','sp_mm20_stretch_17','sp_mm20_stagger_17','sp_mm20_buckle_17','sp_mm20_propeller_17','sp_mm20_opening_17']
spmm20_bp20.columns=list1
spmm20_bp19.columns=list2
spmm20_bp18.columns=list3
spmm20_bp17.columns=list4
sp_mmmm20_all_bps=pd.concat([spmm20_bp20,spmm20_bp19,spmm20_bp18,spmm20_bp17], axis=1)
sp_mmmm20_all_bps.to_csv('Sp_NA_csvs/sp_mm20_all_bps.csv', index=False)

# %%
li_5=sp_mmmm20_all_bps.columns
sp_mmmm20_all_bps.head()
# Out:
#    sp_mm20_shear_20  sp_mm20_stretch_20  sp_mm20_stagger_20  \
# 0             -9.31                4.19               -0.28
# 1             -8.62                4.62               -1.55
# 2             -7.99                3.80                0.06
# 3             -8.02                4.69                0.51
# 4             -8.71                5.50                2.16
#
#    sp_mm20_buckle_20  sp_mm20_propeller_20  sp_mm20_opening_20  \
# 0             -49.06                  9.69               -5.20
# 1             -29.20                 35.87              -20.32
# 2             -28.76                 47.50               -4.65
# 3             -27.75                 35.87               22.35
# 4             -24.75                 -0.86              -61.05
#
#    sp_mm20_shear_19  sp_mm20_stretch_19  sp_mm20_stagger_19  \
# 0             -2.49                2.91                1.24
# 1             -2.54                2.79                0.59
# ...

# %%
sp_mmmm20_all_bps.shape
# Out:
# (558, 24)

# %%
len(li_5)
df5=pd.DataFrame()
df5=sp_mmmm20_all_bps
sp_mmmm20_all_bps=df5.fillna(0)
sp_mmmm20_all_bps.head()
# Out:
#    sp_mm20_shear_20  sp_mm20_stretch_20  sp_mm20_stagger_20  \
# 0             -9.31                4.19               -0.28
# 1             -8.62                4.62               -1.55
# 2             -7.99                3.80                0.06
# 3             -8.02                4.69                0.51
# 4             -8.71                5.50                2.16
#
#    sp_mm20_buckle_20  sp_mm20_propeller_20  sp_mm20_opening_20  \
# 0             -49.06                  9.69               -5.20
# 1             -29.20                 35.87              -20.32
# 2             -28.76                 47.50               -4.65
# 3             -27.75                 35.87               22.35
# 4             -24.75                 -0.86              -61.05
#
#    sp_mm20_shear_19  sp_mm20_stretch_19  sp_mm20_stagger_19  \
# 0             -2.49                2.91                1.24
# 1             -2.54                2.79                0.59
# ...

# %%
sp16_19_bp20=pd.read_csv('/storage3/gayatrip/EMX1-Sp_mm16_19_rep/3dna_frames/bp_20_spmm16_19.csv',names=headers_list1)
sp16_19_bp19=pd.read_csv('/storage3/gayatrip/EMX1-Sp_mm16_19_rep/3dna_frames/bp_19_spmm16_19.csv',names=headers_list1)
sp16_19_bp18=pd.read_csv('/storage3/gayatrip/EMX1-Sp_mm16_19_rep/3dna_frames/bp_18_spmm16_19.csv',names=headers_list1)
sp16_19_bp17=pd.read_csv('/storage3/gayatrip/EMX1-Sp_mm16_19_rep/3dna_frames/bp_17_spmm16_19.csv',names=headers_list1)
sp16_19_bp20=sp16_19_bp20.sort_values('Frames').reset_index()
sp16_19_bp19=sp16_19_bp19.sort_values('Frames').reset_index()
sp16_19_bp18=sp16_19_bp18.sort_values('Frames').reset_index()
sp16_19_bp17=sp16_19_bp17.sort_values('Frames').reset_index()
sp16_19_bp20.head()
# Out:
#    index  Frames  bp-pos  bps  Shear  Stretch  Stagger  Buckle  Propeller  \
# 0      0    3002       1  G-T  -1.62    -0.46    -1.16    7.60      38.98
# 1      1    3008       1  G-T  -1.86    -0.26    -0.91    8.89      54.59
# 2      2    3010       1  G-T  -1.79    -0.50    -1.13    7.25      47.27
# 3      3    3016       1  G-T  -2.34    -0.21    -1.12    6.25      39.45
# 4      4    3022       1  G-T  -1.92    -0.46    -1.73    4.90      54.77
#
#    Opening
# 0   -27.09
# 1   -36.15
# 2   -16.46
# 3   -16.52
# 4   -24.53

# %%
sp16_19_bp20.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
sp16_19_bp19.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
sp16_19_bp18.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
sp16_19_bp17.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
list1=['sp_16_19_shear_20','sp_16_19_stretch_20','sp_16_19_stagger_20','sp_16_19_buckle_20','sp_16_19_propeller_20','sp_16_19_opening_20']
list2=['sp_16_19_shear_19','sp_16_19_stretch_19','sp_16_19_stagger_19','sp_16_19_buckle_19','sp_16_19_propeller_19','sp_16_19_opening_19']
list3=['sp_16_19_shear_18','sp_16_19_stretch_18','sp_16_19_stagger_18','sp_16_19_buckle_18','sp_16_19_propeller_18','sp_16_19_opening_18']
list4=['sp_16_19_shear_17','sp_16_19_stretch_17','sp_16_19_stagger_17','sp_16_19_buckle_17','sp_16_19_propeller_17','sp_16_19_opening_17']
sp16_19_bp20.columns=list1
sp16_19_bp19.columns=list2
sp16_19_bp18.columns=list3
sp16_19_bp17.columns=list4
sp_mm16_19_all_bps=pd.concat([sp16_19_bp20,sp16_19_bp19,sp16_19_bp18,sp16_19_bp17], axis=1)
sp_mm16_19_all_bps.to_csv('Sp_NA_csvs/sp_16_19_all_bps.csv', index=False)

# %%
sp17_20_bp20=pd.read_csv(root_dir+'EMX1-Sp_mm17-20_rep/3dna_frames/bp_20_spmm17-20.csv', names=headers_list1)
sp17_20_bp19=pd.read_csv(root_dir+'EMX1-Sp_mm17-20_rep/3dna_frames/bp_19_spmm17-20.csv', names=headers_list1)
sp17_20_bp18=pd.read_csv(root_dir+'EMX1-Sp_mm17-20_rep/3dna_frames/bp_18_spmm17-20.csv', names=headers_list1)
sp17_20_bp17=pd.read_csv(root_dir+'EMX1-Sp_mm17-20_rep/3dna_frames/bp_17_spmm17-20.csv', names=headers_list1)


#bp        Shear    Stretch   Stagger    Buckle  Propeller  Opening
sp17_20_bp20=sp17_20_bp20.sort_values('Frames').reset_index()
sp17_20_bp19=sp17_20_bp19.sort_values('Frames').reset_index()
sp17_20_bp18=sp17_20_bp18.sort_values('Frames').reset_index()
sp17_20_bp17=sp17_20_bp17.sort_values('Frames').reset_index()

sp17_20_bp17.head()
# Out:
#    index  Frames  bp-pos  bps  Shear  Stretch  Stagger  Buckle  Propeller  \
# 0      5    3100       4  G-C  -0.03    -0.13    -0.05    3.34     -15.51
# 1      0    3176       3  G-C  -0.75    -0.23     0.73    0.50     -12.42
# 2      1    3212       3  G-C   0.09     0.01    -0.13   10.65      19.98
# 3      8    3212       2  G-C  -0.71    -0.27    -1.38  -28.68      -9.72
# 4      6    3626       4  G-C  -0.42     0.73     0.07   44.76      19.66
#
#    Opening
# 0    -2.05
# 1    -0.69
# 2    -4.95
# 3     4.46
# 4   -45.37

# %%
sp17_20_bp20.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
sp17_20_bp19.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
sp17_20_bp18.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
sp17_20_bp17.drop(['index','Frames','bp-pos','bps'], axis=1, inplace=True)
list1=['sp_mm17-20_shear_20','sp_mm17-20_stretch_20','sp_mm17-20_stagger_20','sp_mm17-20_buckle_20','sp_mm17-20_propeller_20','sp_mm17-20_opening_20']
list2=['sp_mm17-20_shear_19','sp_mm17-20_stretch_19','sp_mm17-20_stagger_19','sp_mm17-20_buckle_19','sp_mm17-20_propeller_19','sp_mm17-20_opening_19']
list3=['sp_mm17-20_shear_18','sp_mm17-20_stretch_18','sp_mm17-20_stagger_18','sp_mm17-20_buckle_18','sp_mm17-20_propeller_18','sp_mm17-20_opening_18']
list4=['sp_mm17-20_shear_17','sp_mm17-20_stretch_17','sp_mm17-20_stagger_17','sp_mm17-20_buckle_17','sp_mm17-20_propeller_17','sp_mm17-20_opening_17']
sp17_20_bp20.columns=list1
sp17_20_bp19.columns=list2
sp17_20_bp18.columns=list3
sp17_20_bp17.columns=list4
sp_mm17_20_all_bps=pd.concat([sp17_20_bp20,sp17_20_bp19,sp17_20_bp18,sp17_20_bp17], axis=1)
sp_mm17_20_all_bps.to_csv('Sp_NA_csvs/sp_mm17-20_all_bps.csv', index=False)

# %%
spmm20_bp17
# Out:
#      sp_mm20_shear_17  sp_mm20_stretch_17  sp_mm20_stagger_17  \
# 0                0.72               -0.15               -2.41
# 1                0.71                0.23               -2.44
# 2                0.03               -0.01               -0.18
# 3               -0.43               -0.02               -0.94
# 4               -0.22               -0.12               -0.49
# ..                ...                 ...                 ...
# 205              0.02                0.05               -0.26
# 206             -0.09                0.01               -0.09
# 207              0.30                0.13                0.20
# 208             -0.40                0.18                0.31
# 209             -0.32                0.21               -0.25
#
#      sp_mm20_buckle_17  sp_mm20_propeller_17  sp_mm20_opening_17
# 0               -21.84                -28.58              -11.97
# 1               -23.45                -14.65               -3.42
# ...

# %%
sp17_20_bp17.head()
sp_df_17['sp_17_shear']
#spmm20_bp17['sp_mm20_shear_17']
#sp16_19_bp17['sp_16_19_shear_17']
#sp17_20_bp17['sp_mm17-20_shear_17']
sp_bp_17_she=pd.DataFrame(list(zip(list(sp_df_17['sp_17_shear']),list(spmm20_bp17['sp_mm20_shear_17']),list(sp16_19_bp17['sp_16_19_shear_17']),list(sp17_20_bp17['sp_mm17-20_shear_17']))))
#sp_bp_17_she=pd.DataFrame(list(zip(list(sp_df_17['sp_17_shear']),list(sp16_19_bp17['sp_16_19_shear_17']),list(sp17_20_bp17['sp_mm17-20_shear_17']))))
sp_bp_17_she.head()
# Out:
#         0     1     2     3
# 0 -0.4333  0.72  2.12 -0.03
# 1 -0.1817  0.71  2.10 -0.75
# 2  0.2144  0.03  1.78  0.09
# 3 -0.3056 -0.43  2.38 -0.71
# 4 -0.6259 -0.22  1.96 -0.42

# %%
print(sp17_20_bp19.columns)

sp_bp_20_she=pd.DataFrame(list(zip(list(sp_df_20['sp_20_shear']),list(spmm20_bp20['sp_mm20_shear_20']),list(sp16_19_bp20['sp_16_19_shear_20']),list(sp17_20_bp20['sp_mm17-20_shear_20']))))
sp_bp_19_she=pd.DataFrame(list(zip(list(sp_df_19['sp_19_shear']),list(spmm20_bp19['sp_mm20_shear_19']),list(sp16_19_bp19['sp_16_19_shear_19']),list(sp17_20_bp19['sp_mm17-20_shear_19']))))
sp_bp_18_she=pd.DataFrame(list(zip(list(sp_df_18['sp_18_shear']),list(spmm20_bp18['sp_mm20_shear_18']),list(sp16_19_bp18['sp_16_19_shear_18']),list(sp17_20_bp18['sp_mm17-20_shear_18']))))
sp_bp_17_she=pd.DataFrame(list(zip(list(sp_df_17['sp_17_shear']),list(spmm20_bp17['sp_mm20_shear_17']),list(sp16_19_bp17['sp_16_19_shear_17']),list(sp17_20_bp17['sp_mm17-20_shear_17']))))
#sp_bp_16_she=pd.DataFrame(list(zip(list(sp_df_16['sp_16_shear']),list(spmm20_df_16['spmm20_16_shear'],list(sp17_20_bp16['spmm17-20_16_shear']))))

sp_bp_20_sta=pd.DataFrame(list(zip(list(sp_df_20['sp_20_stagger']),list(spmm20_bp20['sp_mm20_stagger_20']),list(sp16_19_bp20['sp_16_19_stagger_20']),list(sp17_20_bp20['sp_mm17-20_stagger_20']))))
sp_bp_19_sta=pd.DataFrame(list(zip(list(sp_df_19['sp_19_stagger']),list(spmm20_bp19['sp_mm20_stagger_19']),list(sp16_19_bp19['sp_16_19_stagger_19']),list(sp17_20_bp19['sp_mm17-20_stagger_19']))))
sp_bp_18_sta=pd.DataFrame(list(zip(list(sp_df_18['sp_18_stagger']),list(spmm20_bp18['sp_mm20_stagger_18']),list(sp16_19_bp18['sp_16_19_stagger_18']),list(sp17_20_bp18['sp_mm17-20_stagger_18']))))
sp_bp_17_sta=pd.DataFrame(list(zip(list(sp_df_17['sp_17_stagger']),list(spmm20_bp17['sp_mm20_stagger_17']),list(sp16_19_bp17['sp_16_19_stagger_17']),list(sp17_20_bp17['sp_mm17-20_stagger_17']))))
#sp_bp_16_sta=pd.DataFrame(list(zip(list(sp_df_16['sp_16_stagger']),list(spmm20_df_16['spmm20_16_stagger'],list(sp17_20_bp16['spmm17-20_16_stagger']))))

sp_bp_20_str=pd.DataFrame(list(zip(list(sp_df_20['sp_20_stretch']),list(spmm20_bp20['sp_mm20_stretch_20']),list(sp16_19_bp20['sp_16_19_stretch_20']),list(sp17_20_bp20['sp_mm17-20_stretch_20']))))
sp_bp_19_str=pd.DataFrame(list(zip(list(sp_df_19['sp_19_stretch']),list(spmm20_bp19['sp_mm20_stretch_19']),list(sp16_19_bp19['sp_16_19_stretch_19']),list(sp17_20_bp19['sp_mm17-20_stretch_19']))))
sp_bp_18_str=pd.DataFrame(list(zip(list(sp_df_18['sp_18_stretch']),list(spmm20_bp18['sp_mm20_stretch_18']),list(sp16_19_bp18['sp_16_19_stretch_18']),list(sp17_20_bp18['sp_mm17-20_stretch_18']))))
sp_bp_17_str=pd.DataFrame(list(zip(list(sp_df_17['sp_17_stretch']),list(spmm20_bp17['sp_mm20_stretch_17']),list(sp16_19_bp17['sp_16_19_stretch_17']),list(sp17_20_bp17['sp_mm17-20_stretch_17']))))
#sp_bp_16_str=pd.DataFrame(list(zip(list(sp_df_16['sp_16_stretch']),list(spmm20_df_16['spmm20_16_stretch'],list(sp17_20_bp16['spmm17-20_16_stretch']))))

sp_bp_20_buc=pd.DataFrame(list(zip(list(sp_df_20['sp_20_buckle']),list(spmm20_bp20['sp_mm20_buckle_20']),list(sp16_19_bp20['sp_16_19_buckle_20']),list(sp17_20_bp20['sp_mm17-20_buckle_20']))))
sp_bp_19_buc=pd.DataFrame(list(zip(list(sp_df_19['sp_19_buckle']),list(spmm20_bp19['sp_mm20_buckle_19']),list(sp16_19_bp19['sp_16_19_buckle_19']),list(sp17_20_bp19['sp_mm17-20_buckle_19']))))
sp_bp_18_buc=pd.DataFrame(list(zip(list(sp_df_18['sp_18_buckle']),list(spmm20_bp18['sp_mm20_buckle_18']),list(sp16_19_bp18['sp_16_19_buckle_18']),list(sp17_20_bp18['sp_mm17-20_buckle_18']))))
sp_bp_17_buc=pd.DataFrame(list(zip(list(sp_df_17['sp_17_buckle']),list(spmm20_bp17['sp_mm20_buckle_17']),list(sp16_19_bp17['sp_16_19_buckle_17']),list(sp17_20_bp17['sp_mm17-20_buckle_17']))))
#sp_bp_16_buc=pd.DataFrame(list(zip(list(sp_df_16['sp_16_buckle']),list(spmm20_df_16['spmm20_16_buckle'],list(sp17_20_bp16['spmm17-20_16_buckle']))))

sp_bp_20_pro=pd.DataFrame(list(zip(list(sp_df_20['sp_20_propeller']),list(spmm20_bp20['sp_mm20_propeller_20']),list(sp16_19_bp20['sp_16_19_propeller_20']),list(sp17_20_bp20['sp_mm17-20_propeller_20']))))
sp_bp_19_pro=pd.DataFrame(list(zip(list(sp_df_19['sp_19_propeller']),list(spmm20_bp19['sp_mm20_propeller_19']),list(sp16_19_bp19['sp_16_19_propeller_19']),list(sp17_20_bp19['sp_mm17-20_propeller_19']))))
sp_bp_18_pro=pd.DataFrame(list(zip(list(sp_df_18['sp_18_propeller']),list(spmm20_bp18['sp_mm20_propeller_18']),list(sp16_19_bp18['sp_16_19_propeller_18']),list(sp17_20_bp18['sp_mm17-20_propeller_18']))))
sp_bp_17_pro=pd.DataFrame(list(zip(list(sp_df_17['sp_17_propeller']),list(spmm20_bp17['sp_mm20_propeller_17']),list(sp16_19_bp17['sp_16_19_propeller_17']),list(sp17_20_bp17['sp_mm17-20_propeller_17']))))
#sp_bp_16_pro=pd.DataFrame(list(zip(list(sp_df_16['sp_16_propeller']),list(spmm20_df_16['spmm20_16_propeller'],list(sp17_20_bp16['spmm17-20_16_propeller']))))

sp_bp_20_ope=pd.DataFrame(list(zip(list(sp_df_20['sp_20_opening']),list(spmm20_bp20['sp_mm20_opening_20']),list(sp16_19_bp20['sp_16_19_opening_20']),list(sp17_20_bp20['sp_mm17-20_opening_20']))))
sp_bp_19_ope=pd.DataFrame(list(zip(list(sp_df_19['sp_19_opening']),list(spmm20_bp19['sp_mm20_opening_19']),list(sp16_19_bp19['sp_16_19_opening_19']),list(sp17_20_bp19['sp_mm17-20_opening_19']))))
sp_bp_18_ope=pd.DataFrame(list(zip(list(sp_df_18['sp_18_opening']),list(spmm20_bp18['sp_mm20_opening_18']),list(sp16_19_bp18['sp_16_19_opening_18']),list(sp17_20_bp18['sp_mm17-20_opening_18']))))
sp_bp_17_ope=pd.DataFrame(list(zip(list(sp_df_17['sp_17_opening']),list(spmm20_bp17['sp_mm20_opening_17']),list(sp16_19_bp17['sp_16_19_opening_17']),list(sp17_20_bp17['sp_mm17-20_opening_17']))))
#sp_bp_16_ope=pd.DataFrame(list(zip(list(sp_df_16['sp_16_opening']),list(spmm20_df_16['spmm20_16_opening'],list(sp17_20_bp16['spmm17-20_16_opening']))))
# Out:
# Index(['sp_mm17-20_shear_19', 'sp_mm17-20_stretch_19', 'sp_mm17-20_stagger_19',
#        'sp_mm17-20_buckle_19', 'sp_mm17-20_propeller_19',
#        'sp_mm17-20_opening_19'],
#       dtype='object')

# %%
sp_bp_17_she
# Out:
#          0     1     2     3
# 0  -0.4333  0.72  2.12 -0.03
# 1  -0.1817  0.71  2.10 -0.75
# 2   0.2144  0.03  1.78  0.09
# 3  -0.3056 -0.43  2.38 -0.71
# 4  -0.6259 -0.22  1.96 -0.42
# 5  -0.4640  0.19  2.62 -0.03
# 6  -1.0166 -0.02  1.86  0.06
# 7  -0.0049  0.22  2.64 -0.61
# 8  -0.2584  0.33  1.60  0.16
# 9  -0.1935  0.59  2.06 -0.90
# 10 -0.1194  0.09  1.66 -0.92

# %%
sp_bp_20_she.columns=['sp_nat_shear','sp_mm20_shear','sp_mm16_19_shear','sp_mm17-20_shear']
sp_bp_19_she.columns=['sp_nat_shear','sp_mm20_shear','sp_mm16_19_shear','sp_mm17-20_shear']
sp_bp_18_she.columns=['sp_nat_shear','sp_mm20_shear','sp_mm16_19_shear','sp_mm17-20_shear']
sp_bp_17_she.columns=['sp_nat_shear','sp_mm20_shear','sp_mm16_19_shear','sp_mm17-20_shear']

sp_bp_20_sta.columns=['sp_nat_stagger','sp_mm20_stagger','sp_mm16_19_stagger','sp_mm17-20_stagger']
sp_bp_19_sta.columns=['sp_nat_stagger','sp_mm20_stagger','sp_mm16_19_stagger','sp_mm17-20_stagger']
sp_bp_18_sta.columns=['sp_nat_stagger','sp_mm20_stagger','sp_mm16_19_stagger','sp_mm17-20_stagger']
sp_bp_17_sta.columns=['sp_nat_stagger','sp_mm20_stagger','sp_mm16_19_stagger','sp_mm17-20_stagger']

sp_bp_20_str.columns=['sp_nat_stretch','sp_mm20_stretch','sp_mm16_19_stretch','sp_mm17-20_stretch']
sp_bp_19_str.columns=['sp_nat_stretch','sp_mm20_stretch','sp_mm16_19_stretch','sp_mm17-20_stretch']
sp_bp_18_str.columns=['sp_nat_stretch','sp_mm20_stretch','sp_mm16_19_stretch','sp_mm17-20_stretch']
sp_bp_17_str.columns=['sp_nat_stretch','sp_mm20_stretch','sp_mm16_19_stretch','sp_mm17-20_stretch']

sp_bp_20_ope.columns=['sp_nat_opening','sp_mm20_opening','sp_mm16_19_opening','sp_mm17-20_opening']
sp_bp_19_ope.columns=['sp_nat_opening','sp_mm20_opening','sp_mm16_19_opening','sp_mm17-20_opening']
sp_bp_18_ope.columns=['sp_nat_opening','sp_mm20_opening','sp_mm16_19_opening','sp_mm17-20_opening']
sp_bp_17_ope.columns=['sp_nat_opening','sp_mm20_opening','sp_mm16_19_opening','sp_mm17-20_opening']

sp_bp_20_pro.columns=['sp_nat_propeller','sp_mm20_propeller','sp_mm16_19_propeller','sp_mm17-20_propeller']
sp_bp_19_pro.columns=['sp_nat_propeller','sp_mm20_propeller','sp_mm16_19_propeller','sp_mm17-20_propeller']
sp_bp_18_pro.columns=['sp_nat_propeller','sp_mm20_propeller','sp_mm16_19_propeller','sp_mm17-20_propeller']
sp_bp_17_pro.columns=['sp_nat_propeller','sp_mm20_propeller','sp_mm16_19_propeller','sp_mm17-20_propeller']

sp_bp_20_buc.columns=['sp_nat_buckle','sp_mm20_buckle','sp_mm16_19_buckle','sp_mm17-20_buckle']
sp_bp_19_buc.columns=['sp_nat_buckle','sp_mm20_buckle','sp_mm16_19_buckle','sp_mm17-20_buckle']
sp_bp_18_buc.columns=['sp_nat_buckle','sp_mm20_buckle','sp_mm16_19_buckle','sp_mm17-20_buckle']
sp_bp_17_buc.columns=['sp_nat_buckle','sp_mm20_buckle','sp_mm16_19_buckle','sp_mm17-20_buckle']

# %%
# !mkdir figures/spcas9_violin-plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
plt.figure(figsize=(14.5,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_she['sp_nat_shear'],sp_bp_20_she['sp_mm20_shear'],sp_bp_20_she['sp_mm16_19_shear'],sp_bp_20_she['sp_mm17-20_shear']], scale="width", palette="plasma",linewidth=0.5)
ax1.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax1.set_ylabel('spCas9 shear for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_she['sp_nat_shear'],sp_bp_19_she['sp_mm20_shear'],sp_bp_19_she['sp_mm16_19_shear'],sp_bp_19_she['sp_mm17-20_shear']], scale="width", palette="plasma",linewidth=0.5)
ax2.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax2.set_ylabel('spCas9 shear for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_she['sp_nat_shear'],sp_bp_18_she['sp_mm20_shear'],sp_bp_18_she['sp_mm16_19_shear'],sp_bp_18_she['sp_mm17-20_shear']], scale="width", palette="plasma",linewidth=0.5)
ax3.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax3.set_ylabel('spCas9 shear for bp18', fontsize=14)

plt.subplot(2,2,4)
#ax4=sns.violinplot(data=[sp_bp_17_she['sp_nat_shear'],sp_bp_17_she['sp_mm20_shear'],sp_bp_17_she['sp_mm16_19_shear'],sp_bp_17_she['sp_mm17-20_shear']], scale="width", palette="plasma",linewidth=0.5)
ax4=sns.violinplot(data=[sp_bp_17_she['sp_nat_shear'],sp_bp_17_she['sp_mm20_shear'],sp_bp_17_she['sp_mm16_19_shear'],sp_bp_17_she['sp_mm17-20_shear']], scale="width", palette="plasma",linewidth=0.5)
ax4.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax4.set_ylabel('spCas9 shear for bp17', fontsize=14)



ax = plt.gca()
ax1.spines['left'].set_linewidth(1.0)
ax1.spines['bottom'].set_linewidth(1.0)
ax1.spines['top'].set_linewidth(1.0)
ax1.spines['right'].set_linewidth(1.0)

ax2.spines['left'].set_linewidth(1.0)
ax2.spines['bottom'].set_linewidth(1.0)
ax2.spines['top'].set_linewidth(1.0)
ax2.spines['right'].set_linewidth(1.0)

ax3.spines['left'].set_linewidth(1.0)
ax3.spines['bottom'].set_linewidth(1.0)
ax3.spines['top'].set_linewidth(1.0)
ax3.spines['right'].set_linewidth(1.0)

ax4.spines['left'].set_linewidth(1.0)
ax4.spines['bottom'].set_linewidth(1.0)
ax4.spines['top'].set_linewidth(1.0)
ax4.spines['right'].set_linewidth(1.0)


plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
#plt.savefig('figures/SpCas9_all_hybrid_pca.svg')
plt.savefig('figures/spcas9_violin-plots/spCas9_all_shear.svg')
plt.gcf().set_size_inches(14.5, 6)
plt.show()

# %%
plt.figure(figsize=(14.5,7))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_pro['sp_nat_propeller'],sp_bp_20_pro['sp_mm20_propeller'],sp_bp_20_pro['sp_mm16_19_propeller'],sp_bp_20_pro['sp_mm17-20_propeller']], scale="width", palette="plasma",linewidth=0.5)
#ax1.set_xticklabels(['sp_nat_bp20','sp_mm20_bp20','sp_mm16_19_bp20','sp_mm17-20_bp20'])
ax1.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax1.set_ylabel('spCas9 propeller for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_pro['sp_nat_propeller'],sp_bp_19_pro['sp_mm20_propeller'],sp_bp_19_pro['sp_mm16_19_propeller'],sp_bp_19_pro['sp_mm17-20_propeller']], scale="width", palette="plasma",linewidth=0.5)
#ax2.set_xticklabels(['sp_nat_bp19','sp_mm20_bp19','sp_mm16_19_bp19','sp_mm17-20_bp19'])
ax2.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax2.set_ylabel('spCas9 propeller for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_pro['sp_nat_propeller'],sp_bp_18_pro['sp_mm20_propeller'],sp_bp_18_pro['sp_mm16_19_propeller'],sp_bp_18_pro['sp_mm17-20_propeller']], scale="width", palette="plasma",linewidth=0.5)
#ax3.set_xticklabels(['sp_nat_bp18','sp_mm20_bp18','sp_mm16_19_bp18','sp_mm17-20_bp18'])
ax3.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax3.set_ylabel('spCas9 propeller for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_pro['sp_nat_propeller'],sp_bp_17_pro['sp_mm20_propeller'],sp_bp_17_pro['sp_mm16_19_propeller'],sp_bp_17_pro['sp_mm17-20_propeller']], scale="width", palette="plasma",linewidth=0.5)
#ax4.set_xticklabels(['sp_nat_bp17','sp_mm20_bp17','sp_mm16_19_bp17','sp_mm17-20_bp17'])
ax4.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax4.set_ylabel('spCas9 propeller for bp17', fontsize=14)

ax = plt.gca()
ax1.spines['left'].set_linewidth(1.0)
ax1.spines['bottom'].set_linewidth(1.0)
ax1.spines['top'].set_linewidth(1.0)
ax1.spines['right'].set_linewidth(1.0)

ax2.spines['left'].set_linewidth(1.0)
ax2.spines['bottom'].set_linewidth(1.0)
ax2.spines['top'].set_linewidth(1.0)
ax2.spines['right'].set_linewidth(1.0)

ax3.spines['left'].set_linewidth(1.0)
ax3.spines['bottom'].set_linewidth(1.0)
ax3.spines['top'].set_linewidth(1.0)
ax3.spines['right'].set_linewidth(1.0)

ax4.spines['left'].set_linewidth(1.0)
ax4.spines['bottom'].set_linewidth(1.0)
ax4.spines['top'].set_linewidth(1.0)
ax4.spines['right'].set_linewidth(1.0)


plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
#plt.savefig('figures/SpCas9_all_hybrid_pca.svg')
plt.savefig('figures/spcas9_violin-plots/spCas9_all_propeller.svg')
plt.gcf().set_size_inches(14.5, 6)
plt.show()

# %%
plt.figure(figsize=(14.5,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_sta['sp_nat_stagger'],sp_bp_20_sta['sp_mm20_stagger'],sp_bp_20_sta['sp_mm16_19_stagger'],sp_bp_20_sta['sp_mm17-20_stagger']], scale="width", palette="plasma",linewidth=0.5)
#ax1.set_xticklabels(['sp_nat_bp20','sp_mm20_bp20','sp_mm16_19_bp20','sp_mm17-20_bp20'])
ax1.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax1.set_ylabel('spCas9 stagger for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_sta['sp_nat_stagger'],sp_bp_19_sta['sp_mm20_stagger'],sp_bp_19_sta['sp_mm16_19_stagger'],sp_bp_19_sta['sp_mm17-20_stagger']], scale="width", palette="plasma",linewidth=0.5)
#ax2.set_xticklabels(['sp_nat_bp19','sp_mm20_bp19','sp_mm16_19_bp19','sp_mm17-20_bp19'])
ax2.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax2.set_ylabel('spCas9 stagger for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_sta['sp_nat_stagger'],sp_bp_18_sta['sp_mm20_stagger'],sp_bp_18_sta['sp_mm16_19_stagger'],sp_bp_18_sta['sp_mm17-20_stagger']], scale="width", palette="plasma",linewidth=0.5)
#ax3.set_xticklabels(['sp_nat_bp18','sp_mm20_bp18','sp_mm16_19_bp18','sp_mm17-20_bp18'])
ax3.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax3.set_ylabel('spCas9 stagger for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_sta['sp_nat_stagger'],sp_bp_17_sta['sp_mm20_stagger'],sp_bp_17_sta['sp_mm16_19_stagger'],sp_bp_17_sta['sp_mm17-20_stagger']], scale="width", palette="plasma",linewidth=0.5)
#ax4.set_xticklabels(['sp_nat_bp17','sp_mm20_bp17','sp_mm16_19_bp17','sp_mm17-20_bp17'])
ax4.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax4.set_ylabel('spCas9 stagger for bp17', fontsize=14)

ax = plt.gca()
ax1.spines['left'].set_linewidth(1.0)
ax1.spines['bottom'].set_linewidth(1.0)
ax1.spines['top'].set_linewidth(1.0)
ax1.spines['right'].set_linewidth(1.0)

ax2.spines['left'].set_linewidth(1.0)
ax2.spines['bottom'].set_linewidth(1.0)
ax2.spines['top'].set_linewidth(1.0)
ax2.spines['right'].set_linewidth(1.0)

ax3.spines['left'].set_linewidth(1.0)
ax3.spines['bottom'].set_linewidth(1.0)
ax3.spines['top'].set_linewidth(1.0)
ax3.spines['right'].set_linewidth(1.0)

ax4.spines['left'].set_linewidth(1.0)
ax4.spines['bottom'].set_linewidth(1.0)
ax4.spines['top'].set_linewidth(1.0)
ax4.spines['right'].set_linewidth(1.0)


plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
#plt.savefig('figures/SpCas9_all_hybrid_pca.svg')
plt.savefig('figures/spcas9_violin-plots/spCas9_all_stagger.svg')
plt.gcf().set_size_inches(14.5, 6)
plt.show()

# %%
plt.figure(figsize=(14.5,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_buc['sp_nat_buckle'],sp_bp_20_buc['sp_mm20_buckle'],sp_bp_20_buc['sp_mm16_19_buckle'],sp_bp_20_buc['sp_mm17-20_buckle']], scale="width", palette="plasma",linewidth=0.5)
#ax1.set_xticklabels(['sp_nat_bp20','sp_mm20_bp20','sp_mm16_19_bp20','sp_mm17-20_bp20'])
ax1.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax1.set_ylabel('spCas9 buckle for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_buc['sp_nat_buckle'],sp_bp_19_buc['sp_mm20_buckle'],sp_bp_19_buc['sp_mm16_19_buckle'],sp_bp_19_buc['sp_mm17-20_buckle']], scale="width", palette="plasma",linewidth=0.5)
#ax2.set_xticklabels(['sp_nat_bp19','sp_mm20_bp19','sp_mm16_19_bp19','sp_mm17-20_bp19'])
ax2.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax2.set_ylabel('spCas9 buckle for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_buc['sp_nat_buckle'],sp_bp_18_buc['sp_mm20_buckle'],sp_bp_18_buc['sp_mm16_19_buckle'],sp_bp_18_buc['sp_mm17-20_buckle']], scale="width", palette="plasma",linewidth=0.5)
#ax3.set_xticklabels(['sp_nat_bp18','sp_mm20_bp18','sp_mm16_19_bp18','sp_mm17-20_bp18'])
ax3.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax3.set_ylabel('spCas9 buckle for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_buc['sp_nat_buckle'],sp_bp_17_buc['sp_mm20_buckle'],sp_bp_17_buc['sp_mm16_19_buckle'],sp_bp_17_buc['sp_mm17-20_buckle']], scale="width", palette="plasma",linewidth=0.5)
#ax4.set_xticklabels(['sp_nat_bp17','sp_mm20_bp17','sp_mm16_19_bp17','sp_mm17-20_bp17'])
ax4.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax4.set_ylabel('spCas9 buckle for bp17', fontsize=14)

ax = plt.gca()
ax1.spines['left'].set_linewidth(1.0)
ax1.spines['bottom'].set_linewidth(1.0)
ax1.spines['top'].set_linewidth(1.0)
ax1.spines['right'].set_linewidth(1.0)

ax2.spines['left'].set_linewidth(1.0)
ax2.spines['bottom'].set_linewidth(1.0)
ax2.spines['top'].set_linewidth(1.0)
ax2.spines['right'].set_linewidth(1.0)

ax3.spines['left'].set_linewidth(1.0)
ax3.spines['bottom'].set_linewidth(1.0)
ax3.spines['top'].set_linewidth(1.0)
ax3.spines['right'].set_linewidth(1.0)

ax4.spines['left'].set_linewidth(1.0)
ax4.spines['bottom'].set_linewidth(1.0)
ax4.spines['top'].set_linewidth(1.0)
ax4.spines['right'].set_linewidth(1.0)


plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
#plt.savefig('figures/SpCas9_all_hybrid_pca.svg')
plt.savefig('figures/spcas9_violin-plots/spCas9_all_buckle.svg')
plt.gcf().set_size_inches(14.5, 6)
plt.show()

# %%
plt.figure(figsize=(14.5,7))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_ope['sp_nat_opening'],sp_bp_20_ope['sp_mm20_opening'],sp_bp_20_ope['sp_mm16_19_opening'],sp_bp_20_ope['sp_mm17-20_opening']], scale="width", palette="plasma",linewidth=0.5)
#ax1.set_xticklabels(['sp_nat_bp20','sp_mm20_bp20','sp_mm16_19_bp20','sp_mm17-20_bp20'])
ax1.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax1.set_ylabel('spCas9 opening for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_ope['sp_nat_opening'],sp_bp_19_ope['sp_mm20_opening'],sp_bp_19_ope['sp_mm16_19_opening'],sp_bp_19_ope['sp_mm17-20_opening']], scale="width", palette="plasma",linewidth=0.5)
#ax2.set_xticklabels(['sp_nat_bp19','sp_mm20_bp19','sp_mm16_19_bp19','sp_mm17-20_bp19'])
ax2.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax2.set_ylabel('spCas9 opening for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_ope['sp_nat_opening'],sp_bp_18_ope['sp_mm20_opening'],sp_bp_18_ope['sp_mm16_19_opening'],sp_bp_18_ope['sp_mm17-20_opening']], scale="width", palette="plasma",linewidth=0.5)
#ax3.set_xticklabels(['sp_nat_bp18','sp_mm20_bp18','sp_mm16_19_bp18','sp_mm17-20_bp18'])
ax3.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax3.set_ylabel('spCas9 opening for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_ope['sp_nat_opening'],sp_bp_17_ope['sp_mm20_opening'],sp_bp_17_ope['sp_mm16_19_opening'],sp_bp_17_ope['sp_mm17-20_opening']], scale="width", palette="plasma",linewidth=0.5)
#ax4.set_xticklabels(['sp_nat_bp17','sp_mm20_bp17','sp_mm16_19_bp17','sp_mm17-20_bp17'])
ax4.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax4.set_ylabel('spCas9 opening for bp17', fontsize=14)

ax = plt.gca()
ax1.spines['left'].set_linewidth(1.0)
ax1.spines['bottom'].set_linewidth(1.0)
ax1.spines['top'].set_linewidth(1.0)
ax1.spines['right'].set_linewidth(1.0)

ax2.spines['left'].set_linewidth(1.0)
ax2.spines['bottom'].set_linewidth(1.0)
ax2.spines['top'].set_linewidth(1.0)
ax2.spines['right'].set_linewidth(1.0)

ax3.spines['left'].set_linewidth(1.0)
ax3.spines['bottom'].set_linewidth(1.0)
ax3.spines['top'].set_linewidth(1.0)
ax3.spines['right'].set_linewidth(1.0)

ax4.spines['left'].set_linewidth(1.0)
ax4.spines['bottom'].set_linewidth(1.0)
ax4.spines['top'].set_linewidth(1.0)
ax4.spines['right'].set_linewidth(1.0)


plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
#plt.savefig('figures/SpCas9_all_hybrid_pca.svg')
plt.savefig('figures/spcas9_violin-plots/spCas9_all_opening.svg')
plt.gcf().set_size_inches(14.5, 6)
plt.show()

# %%
plt.figure(figsize=(14.5,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_str['sp_nat_stretch'],sp_bp_20_str['sp_mm20_stretch'],sp_bp_20_str['sp_mm16_19_stretch'],sp_bp_20_str['sp_mm17-20_stretch']], scale="width", palette="plasma",linewidth=0.5)
#ax1.set_xticklabels(['sp_nat_bp20','sp_mm20_bp20','sp_mm16_19_bp20','sp_mm17-20_bp20'])
ax1.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax1.set_ylabel('spCas9 stretch for bp20', fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_str['sp_nat_stretch'],sp_bp_19_str['sp_mm20_stretch'],sp_bp_19_str['sp_mm16_19_stretch'],sp_bp_19_str['sp_mm17-20_stretch']], scale="width", palette="plasma",linewidth=0.5)
#ax2.set_xticklabels(['sp_nat_bp19','sp_mm20_bp19','sp_mm16_19_bp19','sp_mm17-20_bp19'])
ax2.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax2.set_ylabel('spCas9 stretch for bp19', fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_str['sp_nat_stretch'],sp_bp_18_str['sp_mm20_stretch'],sp_bp_18_str['sp_mm16_19_stretch'],sp_bp_18_str['sp_mm17-20_stretch']], scale="width", palette="plasma",linewidth=0.5)
#ax3.set_xticklabels(['sp_nat_bp18','sp_mm20_bp18','sp_mm16_19_bp18','sp_mm17-20_bp18'])
ax3.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax3.set_ylabel('spCas9 stretch for bp18', fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_str['sp_nat_stretch'],sp_bp_17_str['sp_mm20_stretch'],sp_bp_17_str['sp_mm16_19_stretch'],sp_bp_17_str['sp_mm17-20_stretch']], scale="width", palette="plasma",linewidth=0.5)
#ax4.set_xticklabels(['sp_nat_bp17','sp_mm20_bp17','sp_mm16_19_bp17','sp_mm17-20_bp17'])
ax4.set_xticklabels(['sp_nat','sp_mm20','sp_mm16_19','sp_mm17-20'], fontsize=14)
ax4.set_ylabel('spCas9 stretch for bp17', fontsize=14)

ax = plt.gca()
ax1.spines['left'].set_linewidth(1.0)
ax1.spines['bottom'].set_linewidth(1.0)
ax1.spines['top'].set_linewidth(1.0)
ax1.spines['right'].set_linewidth(1.0)

ax2.spines['left'].set_linewidth(1.0)
ax2.spines['bottom'].set_linewidth(1.0)
ax2.spines['top'].set_linewidth(1.0)
ax2.spines['right'].set_linewidth(1.0)

ax3.spines['left'].set_linewidth(1.0)
ax3.spines['bottom'].set_linewidth(1.0)
ax3.spines['top'].set_linewidth(1.0)
ax3.spines['right'].set_linewidth(1.0)

ax4.spines['left'].set_linewidth(1.0)
ax4.spines['bottom'].set_linewidth(1.0)
ax4.spines['top'].set_linewidth(1.0)
ax4.spines['right'].set_linewidth(1.0)


plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
#plt.savefig('figures/SpCas9_all_hybrid_pca.svg')
plt.savefig('figures/spcas9_violin-plots/spCas9_all_stretch.svg')
plt.gcf().set_size_inches(14.5, 6)
plt.show()
