# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
plt.rc('xtick',labelsize=11)
plt.rc('ytick',labelsize=11)
#/storage/gayatrip/gamd-amber-example/NII-work-2022/sp_native_gamd
#2,12,22,

headers_list=['Frame','bp','Shear','Stretch','Stagger','Buckle','Propeller','Opening']
headers_list1=['Frame','Nuc','bp','Shear','Stretch','Stagger','Buckle','Propeller','Opening']
root_dir='/storage/gayatrip/gamd-amber-example/NII-work-2022/'
na_sp=open(root_dir+ 'sp_native_gamd/BP.nastruct_500ns_500frames.dat','r')
na_spmm20=open(root_dir+ 'sp_mm20/analysis_250ns/BP.nastruct_500ns_500frames.dat','r')

sp16_19_bp20=pd.read_csv(root_dir+'sp_mm_16-19_final/500_pdbs/bp_20.txt',names=headers_list1)
sp16_19_bp19=pd.read_csv(root_dir+'sp_mm_16-19_final/500_pdbs/bp_19.txt',names=headers_list1)
sp16_19_bp18=pd.read_csv(root_dir+'sp_mm_16-19_final/500_pdbs/bp_18.txt',names=headers_list1)
sp16_19_bp17=pd.read_csv(root_dir+'sp_mm_16-19_final/500_pdbs/bp_17.txt',names=headers_list1)
sp16_19_bp16=pd.read_csv(root_dir+'sp_mm_16-19_final/500_pdbs/bp_16.txt',names=headers_list1)

sp17_20_bp20=pd.read_csv(root_dir+'sp_mm17-20/500_pdbs/bp_20.csv', names=headers_list1)
sp17_20_bp19=pd.read_csv(root_dir+'sp_mm17-20/500_pdbs/bp_19.csv', names=headers_list1)
sp17_20_bp18=pd.read_csv(root_dir+'sp_mm17-20/500_pdbs/bp_18.csv', names=headers_list1)
sp17_20_bp17=pd.read_csv(root_dir+'sp_mm17-20/500_pdbs/bp_17.csv', names=headers_list1)
#na_spmm17_20=open(root_dir+ 'sp_mm17-20/BP.nastruct_500ns_500frames_sp_mm17-20.dat','r')

### For SpCas9_native system
lines=na_sp.readlines()
bp_20=[]
bp_19=[]
bp_18=[]
bp_17=[]
bp_16=[]
bp_15=[]
bp_14=[]
bp_13=[]
bp_12=[]
bp_11=[]
#while (i < len(lines))
for i in range(1,len(lines),20):
    bp_20.append(lines[i].strip().split())

for i in range(2,len(lines),20):
    bp_19.append(lines[i].strip().split())

for i in range(3,len(lines),20):
    bp_18.append(lines[i].strip().split())

for i in range(4,len(lines),20):
    bp_17.append(lines[i].strip().split())

for i in range(5,len(lines),20):
    bp_16.append(lines[i].strip().split())

for i in range(6,len(lines),20):
    bp_15.append(lines[i].strip().split())

for i in range(7,len(lines),20):
    bp_14.append(lines[i].strip().split())

for i in range(8,len(lines),20):
    bp_13.append(lines[i].strip().split())

for i in range(9,len(lines),20):
    bp_12.append(lines[i].strip().split())

for i in range(10,len(lines),20):
    bp_11.append(lines[i].strip().split())
    
print(len(bp_16))
# Out:
# 500

# %%
shear_20=[]
str_20=[]
sta_20=[]
buc_20=[]
pro_20=[]
ope_20=[]
maj_20=[]
min_20=[]
for i in range(len(bp_20)):
    shear_20.append(float(bp_20[i][3]))
    str_20.append(float(bp_20[i][4]))
    sta_20.append(float(bp_20[i][5]))
    buc_20.append(float(bp_20[i][6]))
    pro_20.append(float(bp_20[i][7]))
    ope_20.append(float(bp_20[i][8]))
    maj_20.append(float(bp_20[i][11]))
    min_20.append(float(bp_20[i][12]))
    
shear_19=[]
str_19=[]
sta_19=[]
buc_19=[]
pro_19=[]
ope_19=[]
maj_19=[]
min_19=[]
for i in range(len(bp_19)):
    shear_19.append(float(bp_19[i][3]))
    str_19.append(float(bp_19[i][4]))
    sta_19.append(float(bp_19[i][5]))
    buc_19.append(float(bp_19[i][6]))
    pro_19.append(float(bp_19[i][7]))
    ope_19.append(float(bp_19[i][8]))
    maj_19.append(float(bp_19[i][11]))
    min_19.append(float(bp_19[i][12]))

shear_18=[]
str_18=[]
sta_18=[]
buc_18=[]
pro_18=[]
ope_18=[]
maj_18=[]
min_18=[]
for i in range(len(bp_18)):
    shear_18.append(float(bp_18[i][3]))
    str_18.append(float(bp_18[i][4]))
    sta_18.append(float(bp_18[i][5]))
    buc_18.append(float(bp_18[i][6]))
    pro_18.append(float(bp_18[i][7]))
    ope_18.append(float(bp_18[i][8]))
    maj_18.append(float(bp_18[i][11]))
    min_18.append(float(bp_18[i][12]))
    
shear_17=[]
str_17=[]
sta_17=[]
buc_17=[]
pro_17=[]
ope_17=[]
maj_17=[]
min_17=[]
for i in range(len(bp_17)):
    shear_17.append(float(bp_17[i][3]))
    str_17.append(float(bp_17[i][4]))
    sta_17.append(float(bp_17[i][5]))
    buc_17.append(float(bp_17[i][6]))
    pro_17.append(float(bp_17[i][7]))
    ope_17.append(float(bp_17[i][8]))
    maj_17.append(float(bp_17[i][11]))
    min_17.append(float(bp_17[i][12]))

shear_16=[]
str_16=[]
sta_16=[]
buc_16=[]
pro_16=[]
ope_16=[]
maj_16=[]
min_16=[]
for i in range(len(bp_16)):
    shear_16.append(float(bp_16[i][3]))
    str_16.append(float(bp_16[i][4]))
    sta_16.append(float(bp_16[i][5]))
    buc_16.append(float(bp_16[i][6]))
    pro_16.append(float(bp_16[i][7]))
    ope_16.append(float(bp_16[i][8]))
    maj_16.append(float(bp_16[i][11]))
    min_16.append(float(bp_16[i][12]))
    

    
sp_df_20=pd.DataFrame(list(zip(shear_20,str_20,sta_20,buc_20,pro_20,ope_20,maj_20,min_20)),columns=['sp_20_shear','sp_20_stretch','sp_20_stagger','sp_20_buckle','sp_20_propeller','sp_20_opening','sp_20_major','sp_20_minor'])
sp_df_19=pd.DataFrame(list(zip(shear_19,str_19,sta_19,buc_19,pro_19,ope_19,maj_19,min_19)),columns=['sp_19_shear','sp_19_stretch','sp_19_stagger','sp_19_buckle','sp_19_propeller','sp_19_opening','sp_19_major','sp_19_minor'])
sp_df_18=pd.DataFrame(list(zip(shear_18,str_18,sta_18,buc_18,pro_18,ope_18,maj_18,min_18)),columns=['sp_18_shear','sp_18_stretch','sp_18_stagger','sp_18_buckle','sp_18_propeller','sp_18_opening','sp_18_major','sp_18_minor'])
sp_df_17=pd.DataFrame(list(zip(shear_17,str_17,sta_17,buc_17,pro_17,ope_17,maj_17,min_17)),columns=['sp_17_shear','sp_17_stretch','sp_17_stagger','sp_17_buckle','sp_17_propeller','sp_17_opening','sp_17_major','sp_17_minor'])
sp_df_16=pd.DataFrame(list(zip(shear_16,str_16,sta_16,buc_16,pro_16,ope_16,maj_16,min_16)),columns=['sp_16_shear','sp_16_stretch','sp_16_stagger','sp_16_buckle','sp_16_propeller','sp_16_opening','sp_16_major','sp_16_minor'])
    
    
    
maj_15=[]
min_15=[]
maj_14=[]
min_14=[]
maj_13=[]
min_13=[]
maj_12=[]
min_12=[]
maj_11=[]
min_11=[]

for i in range(len(bp_15)-1):
    maj_15.append(float(bp_15[i][11]))
    min_15.append(float(bp_15[i][12]))
for i in range(len(bp_14)-1):
    maj_14.append(float(bp_14[i][11]))
    min_14.append(float(bp_14[i][12]))
for i in range(len(bp_13)-1):
    maj_13.append(float(bp_13[i][11]))
    min_13.append(float(bp_13[i][12]))
for i in range(len(bp_12)-1):
    maj_12.append(float(bp_12[i][11]))
    min_12.append(float(bp_12[i][12]))
for i in range(len(bp_11)-1):
    maj_11.append(float(bp_11[i][11]))
    min_11.append(float(bp_11[i][12]))
major=[]
minor=[]
sp_maj=pd.DataFrame(list(zip(maj_20,maj_19,maj_18,maj_17,maj_16,maj_15,maj_14,maj_13,maj_12,maj_11)),columns=['bp20','bp19','bp18','bp17','bp16','bp15','bp14','bp13','bp12','bp11'] )
sp_min=pd.DataFrame(list(zip(min_20,min_19,min_18,min_17,min_16,min_15,min_14,min_13,min_12,min_11)),columns=['bp20','bp19','bp18','bp17','bp16','bp15','bp14','bp13','bp12','bp11'] )
min_std=list(sp_min.std())
min_avg=list(sp_min.mean())
maj_std=list(sp_maj.std())
maj_avg=list(sp_maj.mean())
maj_bps=list(range(20,11,-1))
min_bps=list(range(20,11,-1))
#df_maj.mean()
sp_min_groove=pd.DataFrame(list(zip(min_bps,min_avg,min_std)),columns=["Sp_bps","Sp_mean","Sp_std"])
sp_maj_groove=pd.DataFrame(list(zip(maj_bps,maj_avg,maj_std)),columns=["Sp_bps","Sp_mean","Sp_std"])
sp_min_groove.head()
print(maj_std,maj_avg,maj_bps)
print(sp_min_groove.head(),sp_maj_groove.head())
#minor.append(min_20,min_19,min_18,min_17,min_16,min_15,min_14,min_13,min_12,min_11)
# Out:
# [0.0, 0.5578518831711848, 0.4389156079610105, 0.9908995572164367, 0.46332561479954204, 0.37153860170523606, 0.9440303724990475, 0.47037518094795794, 0.46822342118280197, 0.4328458866767071] [0.0, 18.9953376753507, 19.342432464929857, 19.38146933867736, 19.538492785571144, 18.675044689378755, 19.031416633266534, 19.45090340681363, 19.19646673346693, 18.97097915831663] [20, 19, 18, 17, 16, 15, 14, 13, 12]
#    Sp_bps    Sp_mean    Sp_std
# 0      20  13.019200  0.907851
# 1      19  12.716240  0.368837
# 2      18  13.117872  0.234278
# 3      17  12.961224  0.661034
# 4      16  12.912902  0.322669    Sp_bps    Sp_mean    Sp_std
# 0      20   0.000000  0.000000
# 1      19  18.995338  0.557852
# 2      18  19.342432  0.438916
# 3      17  19.381469  0.990900
# 4      16  19.538493  0.463326

# %%
# sp_df_20.to_csv('sp_nat_bp20_prop.csv', index=False)
# sp_df_19.to_csv('sp_nat_bp19_prop.csv', index=False)
# sp_df_18.to_csv('sp_nat_bp18_prop.csv', index=False)
# sp_df_17.to_csv('sp_nat_bp17_prop.csv', index=False)
# sp_df_16.to_csv('sp_nat_bp16_prop.csv', index=False)
sp_df_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sp_20_shear      500 non-null    float64
#  1   sp_20_stretch    500 non-null    float64
#  2   sp_20_stagger    500 non-null    float64
#  3   sp_20_buckle     500 non-null    float64
#  4   sp_20_propeller  500 non-null    float64
#  5   sp_20_opening    500 non-null    float64
#  6   sp_20_major      500 non-null    float64
#  7   sp_20_minor      500 non-null    float64
# dtypes: float64(8)
# memory usage: 31.4 KB

# %%
sp_nat_bps=pd.concat([sp_df_20,sp_df_19,sp_df_18,sp_df_17], axis=1)
sp_nat_bps.head()
sp_nat_bps.to_csv('sp_nat_all.csv', index=False)

# %%
### For SpCas9_mm20 system
lines=na_spmm20.readlines()
bp_20=[]
bp_19=[]
bp_18=[]
bp_17=[]
bp_16=[]
bp_15=[]
bp_14=[]
bp_13=[]
bp_12=[]
bp_11=[]
#while (i < len(lines))
for i in range(1,len(lines),20):
    bp_20.append(lines[i].strip().split())

for i in range(2,len(lines),20):
    bp_19.append(lines[i].strip().split())

for i in range(3,len(lines),20):
    bp_18.append(lines[i].strip().split())

for i in range(4,len(lines),20):
    bp_17.append(lines[i].strip().split())

for i in range(5,len(lines),20):
    bp_16.append(lines[i].strip().split())

for i in range(6,len(lines),20):
    bp_15.append(lines[i].strip().split())

for i in range(7,len(lines),20):
    bp_14.append(lines[i].strip().split())

for i in range(8,len(lines),20):
    bp_13.append(lines[i].strip().split())

for i in range(9,len(lines),20):
    bp_12.append(lines[i].strip().split())

for i in range(10,len(lines),20):
    bp_11.append(lines[i].strip().split())
    
print(len(bp_16))  

shear_20=[]
str_20=[]
sta_20=[]
buc_20=[]
pro_20=[]
ope_20=[]
maj_20=[]
min_20=[]
for i in range(len(bp_20)):
    shear_20.append(float(bp_20[i][3]))
    str_20.append(float(bp_20[i][4]))
    sta_20.append(float(bp_20[i][5]))
    buc_20.append(float(bp_20[i][6]))
    pro_20.append(float(bp_20[i][7]))
    ope_20.append(float(bp_20[i][8]))
    maj_20.append(float(bp_20[i][11]))
    min_20.append(float(bp_20[i][12]))
    
shear_19=[]
str_19=[]
sta_19=[]
buc_19=[]
pro_19=[]
ope_19=[]
maj_19=[]
min_19=[]
for i in range(len(bp_19)):
    shear_19.append(float(bp_19[i][3]))
    str_19.append(float(bp_19[i][4]))
    sta_19.append(float(bp_19[i][5]))
    buc_19.append(float(bp_19[i][6]))
    pro_19.append(float(bp_19[i][7]))
    ope_19.append(float(bp_19[i][8]))
    maj_19.append(float(bp_19[i][11]))
    min_19.append(float(bp_19[i][12]))

shear_18=[]
str_18=[]
sta_18=[]
buc_18=[]
pro_18=[]
ope_18=[]
maj_18=[]
min_18=[]
for i in range(len(bp_18)):
    shear_18.append(float(bp_18[i][3]))
    str_18.append(float(bp_18[i][4]))
    sta_18.append(float(bp_18[i][5]))
    buc_18.append(float(bp_18[i][6]))
    pro_18.append(float(bp_18[i][7]))
    ope_18.append(float(bp_18[i][8]))
    maj_18.append(float(bp_18[i][11]))
    min_18.append(float(bp_18[i][12]))
    
shear_17=[]
str_17=[]
sta_17=[]
buc_17=[]
pro_17=[]
ope_17=[]
maj_17=[]
min_17=[]
for i in range(len(bp_17)):
    shear_17.append(float(bp_17[i][3]))
    str_17.append(float(bp_17[i][4]))
    sta_17.append(float(bp_17[i][5]))
    buc_17.append(float(bp_17[i][6]))
    pro_17.append(float(bp_17[i][7]))
    ope_17.append(float(bp_17[i][8]))
    maj_17.append(float(bp_17[i][11]))
    min_17.append(float(bp_17[i][12]))

shear_16=[]
str_16=[]
sta_16=[]
buc_16=[]
pro_16=[]
ope_16=[]
maj_16=[]
min_16=[]
for i in range(len(bp_16)):
    shear_16.append(float(bp_16[i][3]))
    str_16.append(float(bp_16[i][4]))
    sta_16.append(float(bp_16[i][5]))
    buc_16.append(float(bp_16[i][6]))
    pro_16.append(float(bp_16[i][7]))
    ope_16.append(float(bp_16[i][8]))
    maj_16.append(float(bp_16[i][11]))
    min_16.append(float(bp_16[i][12]))

    
spmm20_df_20=pd.DataFrame(list(zip(shear_20,str_20,sta_20,buc_20,pro_20,ope_20,maj_20,min_20)),columns=['spmm20_20_shear','spmm20_20_stretch','spmm20_20_stagger','spmm20_20_buckle','spmm20_20_propeller','spmm20_20_opening','spmm20_20_major','spmm20_20_minor'])
spmm20_df_19=pd.DataFrame(list(zip(shear_19,str_19,sta_19,buc_19,pro_19,ope_19,maj_19,min_19)),columns=['spmm20_19_shear','spmm20_19_stretch','spmm20_19_stagger','spmm20_19_buckle','spmm20_19_propeller','spmm20_19_opening','spmm20_19_major','spmm20_19_minor'])
spmm20_df_18=pd.DataFrame(list(zip(shear_18,str_18,sta_18,buc_18,pro_18,ope_18,maj_18,min_18)),columns=['spmm20_18_shear','spmm20_18_stretch','spmm20_18_stagger','spmm20_18_buckle','spmm20_18_propeller','spmm20_18_opening','spmm20_18_major','spmm20_18_minor'])
spmm20_df_17=pd.DataFrame(list(zip(shear_17,str_17,sta_17,buc_17,pro_17,ope_17,maj_17,min_17)),columns=['spmm20_17_shear','spmm20_17_stretch','spmm20_17_stagger','spmm20_17_buckle','spmm20_17_propeller','spmm20_17_opening','spmm20_17_major','spmm20_17_minor'])
spmm20_df_16=pd.DataFrame(list(zip(shear_16,str_16,sta_16,buc_16,pro_16,ope_16,maj_16,min_16)),columns=['spmm20_16_shear','spmm20_16_stretch','spmm20_16_stagger','spmm20_16_buckle','spmm20_16_propeller','spmm20_16_opening','spmm20_16_major','spmm20_16_minor'])

maj_15=[]
min_15=[]
maj_14=[]
min_14=[]
maj_13=[]
min_13=[]
maj_12=[]
min_12=[]
maj_11=[]
min_11=[]

for i in range(len(bp_15)-1):
    maj_15.append(float(bp_15[i][11]))
    min_15.append(float(bp_15[i][12]))
for i in range(len(bp_14)-1):
    maj_14.append(float(bp_14[i][11]))
    min_14.append(float(bp_14[i][12]))
for i in range(len(bp_13)-1):
    maj_13.append(float(bp_13[i][11]))
    min_13.append(float(bp_13[i][12]))
for i in range(len(bp_12)-1):
    maj_12.append(float(bp_12[i][11]))
    min_12.append(float(bp_12[i][12]))
for i in range(len(bp_11)-1):
    maj_11.append(float(bp_11[i][11]))
    min_11.append(float(bp_11[i][12]))
major=[]
minor=[]
spmm20_maj=pd.DataFrame(list(zip(maj_20,maj_19,maj_18,maj_17,maj_16,maj_15,maj_14,maj_13,maj_12,maj_11)),columns=['bp20','bp19','bp18','bp17','bp16','bp15','bp14','bp13','bp12','bp11'] )
spmm20_min=pd.DataFrame(list(zip(min_20,min_19,min_18,min_17,min_16,min_15,min_14,min_13,min_12,min_11)),columns=['bp20','bp19','bp18','bp17','bp16','bp15','bp14','bp13','bp12','bp11'] )
min_std=list(spmm20_min.std())
min_avg=list(spmm20_min.mean())
maj_std=list(spmm20_maj.std())
maj_avg=list(spmm20_maj.mean())
maj_bps=list(range(20,11,-1))
min_bps=list(range(20,11,-1))
#df_maj.mean()
spmm20_min_groove=pd.DataFrame(list(zip(min_bps,min_avg,min_std)),columns=["Spmm20_bps","Spmm20_mean","Spmm20_std"])
spmm20_maj_groove=pd.DataFrame(list(zip(maj_bps,maj_avg,maj_std)),columns=["Spmm20_bps","Spmm20_mean","Spmm20_std"])
spmm20_min_groove.head()
print(maj_std,maj_avg,maj_bps)
print(sp_min_groove.head(),sp_maj_groove.head())
#minor.append(min_20,min_19,min_18,min_17,min_16,min_15,min_14,min_13,min_12,min_11)
# Out:
# 499
# [0.0, 1.080803993178161, 0.3850719103562693, 0.3155004230325703, 0.3452718755723072, 0.6024220303310452, 0.47191355879360475, 0.9642380458527037, 0.5349573497635063, 0.5593701467513803] [0.0, 18.860967068273094, 18.885748795180724, 18.432702811244983, 18.7931718875502, 18.707424698795183, 19.19468955823293, 19.33338795180723, 19.316460040160642, 19.380161847389555] [20, 19, 18, 17, 16, 15, 14, 13, 12]
#    Sp_bps    Sp_mean    Sp_std
# 0      20  13.019200  0.907851
# 1      19  12.716240  0.368837
# 2      18  13.117872  0.234278
# 3      17  12.961224  0.661034
# 4      16  12.912902  0.322669    Sp_bps    Sp_mean    Sp_std
# 0      20   0.000000  0.000000
# 1      19  18.995338  0.557852
# 2      18  19.342432  0.438916
# 3      17  19.381469  0.990900
# 4      16  19.538493  0.463326

# %%
# spmm20_df_20.to_csv('sp_mm20_bp20_prop.csv', index=False)
# spmm20_df_19.to_csv('sp_mm20_bp19_prop.csv', index=False)
# spmm20_df_18.to_csv('sp_mm20_bp18_prop.csv', index=False)
# spmm20_df_17.to_csv('sp_mm20_bp17_prop.csv', index=False)
# spmm20_df_16.to_csv('sp_mm20_bp16_prop.csv', index=False)
spmm20_df_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   spmm20_20_shear      499 non-null    float64
#  1   spmm20_20_stretch    499 non-null    float64
#  2   spmm20_20_stagger    499 non-null    float64
#  3   spmm20_20_buckle     499 non-null    float64
#  4   spmm20_20_propeller  499 non-null    float64
#  5   spmm20_20_opening    499 non-null    float64
#  6   spmm20_20_major      499 non-null    float64
#  7   spmm20_20_minor      499 non-null    float64
# dtypes: float64(8)
# memory usage: 31.3 KB

# %%
sp_mm20_bps=pd.concat([spmm20_df_20,spmm20_df_19,spmm20_df_18,spmm20_df_17], axis=1)
sp_mm20_bps.head()
sp_mm20_bps.to_csv('sp_mm20_all_bps.csv', index=False)

# %%
sp16_19_bp20=sp16_19_bp20.sort_values('Frame').reset_index()
sp16_19_bp19=sp16_19_bp19.sort_values('Frame').reset_index()
sp16_19_bp18=sp16_19_bp18.sort_values('Frame').reset_index()
sp16_19_bp17=sp16_19_bp17.sort_values('Frame').reset_index()

# %%
sp17_20_bp20=sp17_20_bp20.sort_values('Frame').reset_index()
sp17_20_bp19=sp17_20_bp19.sort_values('Frame').reset_index()
sp17_20_bp18=sp17_20_bp18.sort_values('Frame').reset_index()
sp17_20_bp17=sp17_20_bp17.sort_values('Frame').reset_index()

# %%
#bp        Shear    Stretch   Stagger    Buckle  Propeller  Opening
#sp17_20_bp20(index_col=False)
#sp17_20_bp20=sp17_20_bp20.sort_values('Frame').reset_index()
#sp16_19_bp20.head()
sp17_20_bp20.head()
# Out:
#    index  Frame  Nuc   bp  Shear  Stretch  Stagger  Buckle  Propeller  Opening
# 0    150      2    1  U-C  -3.54     1.21     0.91  -51.58     -22.87    69.87
# 1      9     10    1  U-C  -3.33     1.48     0.74  -59.83     -22.15    85.37
# 2     31     13    1  U-C  -3.03     2.00     1.35  -54.78     -19.51    93.41
# 3     38     14    1  U-C  -3.06     1.46     0.09  -51.99       0.29    83.12
# 4     48     15    1  U-C  -2.90     1.58     0.53  -18.87     -17.15    81.54

# %%
print(sp17_20_bp19.columns)


sp_bp_20_she=pd.DataFrame(list(zip(list(sp_df_20['sp_20_shear']),list(spmm20_df_20['spmm20_20_shear']),list(sp16_19_bp20['Shear']),list(sp17_20_bp20['Shear']))))
sp_bp_19_she=pd.DataFrame(list(zip(list(sp_df_19['sp_19_shear']),list(spmm20_df_19['spmm20_19_shear']),list(sp16_19_bp19['Shear']),list(sp17_20_bp19['Shear']))))
sp_bp_18_she=pd.DataFrame(list(zip(list(sp_df_18['sp_18_shear']),list(spmm20_df_18['spmm20_18_shear']),list(sp16_19_bp18['Shear']),list(sp17_20_bp18['Shear']))))
sp_bp_17_she=pd.DataFrame(list(zip(list(sp_df_17['sp_17_shear']),list(spmm20_df_17['spmm20_17_shear']),list(sp16_19_bp17['Shear']),list(sp17_20_bp17['Shear']))))
#sp_bp_16_she=pd.DataFrame(list(zip(list(sp_df_16['sp_16_shear']),list(spmm20_df_16['spmm20_16_shear'],list(sp17_20_bp16['spmm17-20_16_shear']))))

sp_bp_20_sta=pd.DataFrame(list(zip(list(sp_df_20['sp_20_stagger']),list(spmm20_df_20['spmm20_20_stagger']),list(sp16_19_bp20['Stagger']),list(sp17_20_bp20['Stagger']))))
sp_bp_19_sta=pd.DataFrame(list(zip(list(sp_df_19['sp_19_stagger']),list(spmm20_df_19['spmm20_19_stagger']),list(sp16_19_bp19['Stagger']),list(sp17_20_bp19['Stagger']))))
sp_bp_18_sta=pd.DataFrame(list(zip(list(sp_df_18['sp_18_stagger']),list(spmm20_df_18['spmm20_18_stagger']),list(sp16_19_bp18['Stagger']),list(sp17_20_bp18['Stagger']))))
sp_bp_17_sta=pd.DataFrame(list(zip(list(sp_df_17['sp_17_stagger']),list(spmm20_df_17['spmm20_17_stagger']),list(sp16_19_bp17['Stagger']),list(sp17_20_bp17['Stagger']))))
#sp_bp_16_sta=pd.DataFrame(list(zip(list(sp_df_16['sp_16_stagger']),list(spmm20_df_16['spmm20_16_stagger'],list(sp17_20_bp16['spmm17-20_16_stagger']))))

sp_bp_20_str=pd.DataFrame(list(zip(list(sp_df_20['sp_20_stretch']),list(spmm20_df_20['spmm20_20_stretch']),list(sp16_19_bp20['Stretch']),list(sp17_20_bp20['Stretch']))))
sp_bp_19_str=pd.DataFrame(list(zip(list(sp_df_19['sp_19_stretch']),list(spmm20_df_19['spmm20_19_stretch']),list(sp16_19_bp19['Stretch']),list(sp17_20_bp19['Stretch']))))
sp_bp_18_str=pd.DataFrame(list(zip(list(sp_df_18['sp_18_stretch']),list(spmm20_df_18['spmm20_18_stretch']),list(sp16_19_bp18['Stretch']),list(sp17_20_bp18['Stretch']))))
sp_bp_17_str=pd.DataFrame(list(zip(list(sp_df_17['sp_17_stretch']),list(spmm20_df_17['spmm20_17_stretch']),list(sp16_19_bp17['Stretch']),list(sp17_20_bp17['Stretch']))))
#sp_bp_16_str=pd.DataFrame(list(zip(list(sp_df_16['sp_16_stretch']),list(spmm20_df_16['spmm20_16_stretch'],list(sp17_20_bp16['spmm17-20_16_stretch']))))

sp_bp_20_buc=pd.DataFrame(list(zip(list(sp_df_20['sp_20_buckle']),list(spmm20_df_20['spmm20_20_buckle']),list(sp16_19_bp20['Buckle']),list(sp17_20_bp20['Buckle']))))
sp_bp_19_buc=pd.DataFrame(list(zip(list(sp_df_19['sp_19_buckle']),list(spmm20_df_19['spmm20_19_buckle']),list(sp16_19_bp19['Buckle']),list(sp17_20_bp19['Buckle']))))
sp_bp_18_buc=pd.DataFrame(list(zip(list(sp_df_18['sp_18_buckle']),list(spmm20_df_18['spmm20_18_buckle']),list(sp16_19_bp18['Buckle']),list(sp17_20_bp18['Buckle']))))
sp_bp_17_buc=pd.DataFrame(list(zip(list(sp_df_17['sp_17_buckle']),list(spmm20_df_17['spmm20_17_buckle']),list(sp16_19_bp17['Buckle']),list(sp17_20_bp17['Buckle']))))
#sp_bp_16_buc=pd.DataFrame(list(zip(list(sp_df_16['sp_16_buckle']),list(spmm20_df_16['spmm20_16_buckle'],list(sp17_20_bp16['spmm17-20_16_buckle']))))

sp_bp_20_pro=pd.DataFrame(list(zip(list(sp_df_20['sp_20_propeller']),list(spmm20_df_20['spmm20_20_propeller']),list(sp16_19_bp20['Propeller']),list(sp17_20_bp20['Propeller']))))
sp_bp_19_pro=pd.DataFrame(list(zip(list(sp_df_19['sp_19_propeller']),list(spmm20_df_19['spmm20_19_propeller']),list(sp16_19_bp19['Propeller']),list(sp17_20_bp19['Propeller']))))
sp_bp_18_pro=pd.DataFrame(list(zip(list(sp_df_18['sp_18_propeller']),list(spmm20_df_18['spmm20_18_propeller']),list(sp16_19_bp18['Propeller']),list(sp17_20_bp18['Propeller']))))
sp_bp_17_pro=pd.DataFrame(list(zip(list(sp_df_17['sp_17_propeller']),list(spmm20_df_17['spmm20_17_propeller']),list(sp16_19_bp17['Propeller']),list(sp17_20_bp17['Propeller']))))
#sp_bp_16_pro=pd.DataFrame(list(zip(list(sp_df_16['sp_16_propeller']),list(spmm20_df_16['spmm20_16_propeller'],list(sp17_20_bp16['spmm17-20_16_propeller']))))

sp_bp_20_ope=pd.DataFrame(list(zip(list(sp_df_20['sp_20_opening']),list(spmm20_df_20['spmm20_20_opening']),list(sp16_19_bp20['Opening']),list(sp17_20_bp20['Opening']))))
sp_bp_19_ope=pd.DataFrame(list(zip(list(sp_df_19['sp_19_opening']),list(spmm20_df_19['spmm20_19_opening']),list(sp16_19_bp19['Opening']),list(sp17_20_bp19['Opening']))))
sp_bp_18_ope=pd.DataFrame(list(zip(list(sp_df_18['sp_18_opening']),list(spmm20_df_18['spmm20_18_opening']),list(sp16_19_bp18['Opening']),list(sp17_20_bp18['Opening']))))
sp_bp_17_ope=pd.DataFrame(list(zip(list(sp_df_17['sp_17_opening']),list(spmm20_df_17['spmm20_17_opening']),list(sp16_19_bp17['Opening']),list(sp17_20_bp17['Opening']))))
#sp_bp_16_ope=pd.DataFrame(list(zip(list(sp_df_16['sp_16_opening']),list(spmm20_df_16['spmm20_16_opening'],list(sp17_20_bp16['spmm17-20_16_opening']))))
# Out:
# Index(['index', 'Frame', 'Nuc', 'bp', 'Shear', 'Stretch', 'Stagger', 'Buckle',
#        'Propeller', 'Opening'],
#       dtype='object')

# %%
sp_bp_20_she.columns=['Sp_nat_shear','Sp_mm20_shear','Sp_mm16_19_shear','Sp_mm17-20_shear']
sp_bp_19_she.columns=['Sp_nat_shear','Sp_mm20_shear','Sp_mm16_19_shear','Sp_mm17-20_shear']
sp_bp_18_she.columns=['Sp_nat_shear','Sp_mm20_shear','Sp_mm16_19_shear','Sp_mm17-20_shear']
sp_bp_17_she.columns=['Sp_nat_shear','Sp_mm20_shear','Sp_mm16_19_shear','Sp_mm17-20_shear']

sp_bp_20_sta.columns=['Sp_nat_stagger','Sp_mm20_stagger','Sp_mm16_19_stagger','Sp_mm17-20_stagger']
sp_bp_19_sta.columns=['Sp_nat_stagger','Sp_mm20_stagger','Sp_mm16_19_stagger','Sp_mm17-20_stagger']
sp_bp_18_sta.columns=['Sp_nat_stagger','Sp_mm20_stagger','Sp_mm16_19_stagger','Sp_mm17-20_stagger']
sp_bp_17_sta.columns=['Sp_nat_stagger','Sp_mm20_stagger','Sp_mm16_19_stagger','Sp_mm17-20_stagger']

sp_bp_20_str.columns=['Sp_nat_stretch','Sp_mm20_stretch','Sp_mm16_19_stretch','Sp_mm17-20_stretch']
sp_bp_19_str.columns=['Sp_nat_stretch','Sp_mm20_stretch','Sp_mm16_19_stretch','Sp_mm17-20_stretch']
sp_bp_18_str.columns=['Sp_nat_stretch','Sp_mm20_stretch','Sp_mm16_19_stretch','Sp_mm17-20_stretch']
sp_bp_17_str.columns=['Sp_nat_stretch','Sp_mm20_stretch','Sp_mm16_19_stretch','Sp_mm17-20_stretch']

sp_bp_20_ope.columns=['Sp_nat_opening','Sp_mm20_opening','Sp_mm16_19_opening','Sp_mm17-20_opening']
sp_bp_19_ope.columns=['Sp_nat_opening','Sp_mm20_opening','Sp_mm16_19_opening','Sp_mm17-20_opening']
sp_bp_18_ope.columns=['Sp_nat_opening','Sp_mm20_opening','Sp_mm16_19_opening','Sp_mm17-20_opening']
sp_bp_17_ope.columns=['Sp_nat_opening','Sp_mm20_opening','Sp_mm16_19_opening','Sp_mm17-20_opening']

sp_bp_20_pro.columns=['Sp_nat_propeller','Sp_mm20_propeller','Sp_mm16_19_propeller','Sp_mm17-20_propeller']
sp_bp_19_pro.columns=['Sp_nat_propeller','Sp_mm20_propeller','Sp_mm16_19_propeller','Sp_mm17-20_propeller']
sp_bp_18_pro.columns=['Sp_nat_propeller','Sp_mm20_propeller','Sp_mm16_19_propeller','Sp_mm17-20_propeller']
sp_bp_17_pro.columns=['Sp_nat_propeller','Sp_mm20_propeller','Sp_mm16_19_propeller','Sp_mm17-20_propeller']

sp_bp_20_buc.columns=['Sp_nat_buckle','Sp_mm20_buckle','Sp_mm16_19_buckle','Sp_mm17-20_buckle']
sp_bp_19_buc.columns=['Sp_nat_buckle','Sp_mm20_buckle','Sp_mm16_19_buckle','Sp_mm17-20_buckle']
sp_bp_18_buc.columns=['Sp_nat_buckle','Sp_mm20_buckle','Sp_mm16_19_buckle','Sp_mm17-20_buckle']
sp_bp_17_buc.columns=['Sp_nat_buckle','Sp_mm20_buckle','Sp_mm16_19_buckle','Sp_mm17-20_buckle']

# %%
plt.figure(figsize=(14,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_she['Sp_nat_shear'],sp_bp_20_she['Sp_mm20_shear'],sp_bp_20_she['Sp_mm16_19_shear'],sp_bp_20_she['Sp_mm17-20_shear']], scale="width", palette="plasma",linewidth=0.5)
ax1.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=13.5)
ax1.set_ylabel('SpCas9 shear for bp20',fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_she['Sp_nat_shear'],sp_bp_19_she['Sp_mm20_shear'],sp_bp_19_she['Sp_mm16_19_shear'],sp_bp_19_she['Sp_mm17-20_shear']], scale="width", palette="plasma",linewidth=0.5)
ax2.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=13.5)
ax2.set_ylabel('SpCas9 shear for bp19',fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_she['Sp_nat_shear'],sp_bp_18_she['Sp_mm20_shear'],sp_bp_18_she['Sp_mm16_19_shear'],sp_bp_18_she['Sp_mm17-20_shear']], scale="width", palette="plasma",linewidth=0.5)
ax3.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=13.5)
ax3.set_ylabel('SpCas9 shear for bp18',fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_she['Sp_nat_shear'],sp_bp_17_she['Sp_mm20_shear'],sp_bp_17_she['Sp_mm16_19_shear'],sp_bp_17_she['Sp_mm17-20_shear']], scale="width", palette="plasma",linewidth=0.5)
ax4.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=13.5)
ax4.set_ylabel('SpCas9 shear for bp17',fontsize=14)

plt.savefig('figures/SpCas9_all_shear.svg')
# plt.rc('xtick',labelsize=14,rotation=45)
# plt.rc('ytick',labelsize=14)

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_pro['Sp_nat_propeller'],sp_bp_20_pro['Sp_mm20_propeller'],sp_bp_20_pro['Sp_mm16_19_propeller'],sp_bp_20_pro['Sp_mm17-20_propeller']], scale="width", palette="plasma",linewidth=0.5)
ax1.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax1.set_ylabel('SpCas9 propeller for bp20',fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_pro['Sp_nat_propeller'],sp_bp_19_pro['Sp_mm20_propeller'],sp_bp_19_pro['Sp_mm16_19_propeller'],sp_bp_19_pro['Sp_mm17-20_propeller']], scale="width", palette="plasma",linewidth=0.5)
ax2.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax2.set_ylabel('SpCas9 propeller for bp19',fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_pro['Sp_nat_propeller'],sp_bp_18_pro['Sp_mm20_propeller'],sp_bp_18_pro['Sp_mm16_19_propeller'],sp_bp_18_pro['Sp_mm17-20_propeller']], scale="width", palette="plasma",linewidth=0.5)
ax3.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax3.set_ylabel('SpCas9 propeller for bp18',fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_pro['Sp_nat_propeller'],sp_bp_17_pro['Sp_mm20_propeller'],sp_bp_17_pro['Sp_mm16_19_propeller'],sp_bp_17_pro['Sp_mm17-20_propeller']], scale="width", palette="plasma",linewidth=0.5)
ax4.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax4.set_ylabel('SpCas9 propeller for bp17',fontsize=14)

plt.savefig('figures/SpCas9_all_propeller.svg')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_ope['Sp_nat_opening'],sp_bp_20_ope['Sp_mm20_opening'],sp_bp_20_ope['Sp_mm16_19_opening'],sp_bp_20_ope['Sp_mm17-20_opening']], scale="width", palette="plasma",linewidth=0.5)
#ax1.set_xticklabels(['Sp_nat_bp20','Sp_mm20_bp20','Sp_mm16_19_bp20','Sp_mm17-20_bp20'])
ax1.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax1.set_ylabel('SpCas9 opening for bp20',fontsize=14)


plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_ope['Sp_nat_opening'],sp_bp_19_ope['Sp_mm20_opening'],sp_bp_19_ope['Sp_mm16_19_opening'],sp_bp_19_ope['Sp_mm17-20_opening']], scale="width", palette="plasma",linewidth=0.5)
#ax2.set_xticklabels(['Sp_nat_bp19','Sp_mm20_bp19','Sp_mm16_19_bp19','Sp_mm17-20_bp19'])
ax2.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax2.set_ylabel('SpCas9 opening for bp19',fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_ope['Sp_nat_opening'],sp_bp_18_ope['Sp_mm20_opening'],sp_bp_18_ope['Sp_mm16_19_opening'],sp_bp_18_ope['Sp_mm17-20_opening']], scale="width", palette="plasma",linewidth=0.5)
#ax3.set_xticklabels(['Sp_nat_bp18','Sp_mm20_bp18','Sp_mm16_19_bp18','Sp_mm17-20_bp18'])
ax3.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax3.set_ylabel('SpCas9 opening for bp18',fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_ope['Sp_nat_opening'],sp_bp_17_ope['Sp_mm20_opening'],sp_bp_17_ope['Sp_mm16_19_opening'],sp_bp_17_ope['Sp_mm17-20_opening']], scale="width", palette="plasma",linewidth=0.5)
#ax4.set_xticklabels(['Sp_nat_bp17','Sp_mm20_bp17','Sp_mm16_19_bp17','Sp_mm17-20_bp17'])
ax4.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax4.set_ylabel('SpCas9 opening for bp17',fontsize=14)

plt.savefig('figures/SpCas9_all_opening.svg')
plt.show()

# %%
#Spcas9 bp20, 19, 18, 17
# plt.subplots(nrows, ncols, plot no. )
plt.figure(figsize=(15,7))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_buc['Sp_nat_buckle'],sp_bp_20_buc['Sp_mm20_buckle'],sp_bp_20_buc['Sp_mm16_19_buckle'],sp_bp_20_buc['Sp_mm17-20_buckle']], scale="width", palette="plasma",linewidth=0.5)
#ax1.set_xticklabels(['Sp_nat_bp20','Sp_mm20_bp20','Sp_mm16_19_bp20','Sp_mm17-20_bp20'])
ax1.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax1.set_ylabel('SpCas9 Buckle for bp20',fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_buc['Sp_nat_buckle'],sp_bp_19_buc['Sp_mm20_buckle'],sp_bp_19_buc['Sp_mm16_19_buckle'],sp_bp_19_buc['Sp_mm17-20_buckle']], scale="width", palette="plasma",linewidth=0.5)
#ax2.set_xticklabels(['Sp_nat_bp19','Sp_mm20_bp19','Sp_mm16_19_bp19','Sp_mm17-20_bp19'])
ax2.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax2.set_ylabel('SpCas9 Buckle for bp19',fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_buc['Sp_nat_buckle'],sp_bp_18_buc['Sp_mm20_buckle'],sp_bp_18_buc['Sp_mm16_19_buckle'],sp_bp_18_buc['Sp_mm17-20_buckle']], scale="width", palette="plasma",linewidth=0.5)
#ax3.set_xticklabels(['Sp_nat_bp18','Sp_mm20_bp18','Sp_mm16_19_bp18','Sp_mm17-20_bp18'])
ax3.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax3.set_ylabel('SpCas9 Buckle for bp18',fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_buc['Sp_nat_buckle'],sp_bp_17_buc['Sp_mm20_buckle'],sp_bp_17_buc['Sp_mm16_19_buckle'],sp_bp_17_buc['Sp_mm17-20_buckle']], scale="width", palette="plasma",linewidth=0.5)
#ax4.set_xticklabels(['Sp_nat_bp17','Sp_mm20_bp17','Sp_mm16_19_bp17','Sp_mm17-20_bp17'])
ax4.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax4.set_ylabel('SpCas9 Buckle for bp17',fontsize=14)

plt.savefig('figures/SpCas9_all_buckle.svg')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_sta['Sp_nat_stagger'],sp_bp_20_sta['Sp_mm20_stagger'],sp_bp_20_sta['Sp_mm16_19_stagger'],sp_bp_20_sta['Sp_mm17-20_stagger']], scale="width", palette="plasma",linewidth=0.5)
#ax1.set_xticklabels(['Sp_nat_bp20','Sp_mm20_bp20','Sp_mm16_19_bp20','Sp_mm17-20_bp20'])
ax1.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax1.set_ylabel('SpCas9 stagger for bp20',fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_sta['Sp_nat_stagger'],sp_bp_19_sta['Sp_mm20_stagger'],sp_bp_19_sta['Sp_mm16_19_stagger'],sp_bp_19_sta['Sp_mm17-20_stagger']], scale="width", palette="plasma",linewidth=0.5)
#ax2.set_xticklabels(['Sp_nat_bp19','Sp_mm20_bp19','Sp_mm16_19_bp19','Sp_mm17-20_bp19'])
ax2.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax2.set_ylabel('SpCas9 stagger for bp19',fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_sta['Sp_nat_stagger'],sp_bp_18_sta['Sp_mm20_stagger'],sp_bp_18_sta['Sp_mm16_19_stagger'],sp_bp_18_sta['Sp_mm17-20_stagger']], scale="width", palette="plasma",linewidth=0.5)
#ax3.set_xticklabels(['Sp_nat_bp18','Sp_mm20_bp18','Sp_mm16_19_bp18','Sp_mm17-20_bp18'])
ax3.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax3.set_ylabel('SpCas9 stagger for bp18',fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_sta['Sp_nat_stagger'],sp_bp_17_sta['Sp_mm20_stagger'],sp_bp_17_sta['Sp_mm16_19_stagger'],sp_bp_17_sta['Sp_mm17-20_stagger']], scale="width", palette="plasma",linewidth=0.5)
#ax4.set_xticklabels(['Sp_nat_bp17','Sp_mm20_bp17','Sp_mm16_19_bp17','Sp_mm17-20_bp17'])
ax4.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax4.set_ylabel('SpCas9 stagger for bp17',fontsize=14)

plt.savefig('figures/SpCas9_all_stagger.svg')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
ax1=sns.violinplot(data=[sp_bp_20_str['Sp_nat_stretch'],sp_bp_20_str['Sp_mm20_stretch'],sp_bp_20_str['Sp_mm16_19_stretch'],sp_bp_20_str['Sp_mm17-20_stretch']], scale="width", palette="plasma",linewidth=0.5)
#ax1.set_xticklabels(['Sp_nat_bp20','Sp_mm20_bp20','Sp_mm16_19_bp19','Sp_mm17-20_bp20'])
ax1.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax1.set_ylabel('SpCas9 stretch for bp20',fontsize=14)

plt.subplot(2,2,2)
ax2=sns.violinplot(data=[sp_bp_19_str['Sp_nat_stretch'],sp_bp_19_str['Sp_mm20_stretch'],sp_bp_19_str['Sp_mm16_19_stretch'],sp_bp_19_str['Sp_mm17-20_stretch']], scale="width", palette="plasma",linewidth=0.5)
#ax2.set_xticklabels(['Sp_nat_bp19','Sp_mm20_bp19','Sp_mm16_19_bp19','Sp_mm17-20_bp19'])
ax2.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax2.set_ylabel('SpCas9 stretch for bp19',fontsize=14)

plt.subplot(2,2,3)
ax3=sns.violinplot(data=[sp_bp_18_str['Sp_nat_stretch'],sp_bp_18_str['Sp_mm20_stretch'],sp_bp_18_str['Sp_mm16_19_stretch'],sp_bp_18_str['Sp_mm17-20_stretch']], scale="width", palette="plasma",linewidth=0.5)
#ax3.set_xticklabels(['Sp_nat_bp18','Sp_mm20_bp18','Sp_mm16_19_bp18','Sp_mm17-20_bp18'])
ax3.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax3.set_ylabel('SpCas9 stretch for bp18',fontsize=14)

plt.subplot(2,2,4)
ax4=sns.violinplot(data=[sp_bp_17_str['Sp_nat_stretch'],sp_bp_17_str['Sp_mm20_stretch'],sp_bp_17_str['Sp_mm16_19_stretch'],sp_bp_17_str['Sp_mm17-20_stretch']], scale="width", palette="plasma",linewidth=0.5)
#ax4.set_xticklabels(['Sp_nat_bp17','Sp_mm20_bp17','Sp_mm16_19_bp17','Sp_mm17-20_bp17'])
ax4.set_xticklabels(['Sp_nat','Sp_mm20','Sp_mm16_19','Sp_mm17-20'],fontsize=14)
ax4.set_ylabel('SpCas9 stretch for bp17',fontsize=14)
plt.savefig('figures/SpCas9_all_stretch.svg')
plt.show()

# %%
#major groove width
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.grid(b=None)
sp_maj_groove.plot('Sp_bps','Sp_mean',yerr='Sp_std', ax=ax, label='Major_SpCas9')
spmm20_maj_groove.plot('Spmm20_bps','Spmm20_mean',yerr='Spmm20_std', ax=ax, label='Major_SpCas9')
spmm17_20_maj_groove.plot('Spmm17_20_bps','Spmm17_20_mean',yerr='Spmm17_20_std', ax=ax, label='Major_SpCas9')
# Out:
# /tmp/ipykernel_2460016/1511443059.py:4: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=None)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [71], in <cell line: 7>()
#       5 sp_maj_groove.plot('Sp_bps','Sp_mean',yerr='Sp_std', ax=ax, label='Major_SpCas9')
#       6 spmm20_maj_groove.plot('Spmm20_bps','Spmm20_mean',yerr='Spmm20_std', ax=ax, label='Major_SpCas9')
# ----> 7 spmm17_20_maj_groove.plot('Spmm17_20_bps','Spmm17_20_mean',yerr='Spmm17_20_std', ax=ax, label='Major_SpCas9')
#
# NameError: name 'spmm17_20_maj_groove' is not defined

# %%
fig, ax = plt.subplots()
plt.grid(b=None)

sp_min_groove.plot('Sp_bps','Sp_mean',yerr='Sp_std', ax=ax, label='Minor_SpCas9')
spmm20_min_groove.plot('Spmm20_bps','Spmm20_mean',yerr='Spmm20_std', ax=ax, label='Minor_SpCas9')
spmm17_20_min_groove.plot('Spmm17_20_bps','Spmm17_20_mean',yerr='Spmm17_20_std', ax=ax, label='Minor_SpCas9')
# Out:
# /tmp/ipykernel_2460016/2459505275.py:2: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=None)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [72], in <cell line: 6>()
#       4 sp_min_groove.plot('Sp_bps','Sp_mean',yerr='Sp_std', ax=ax, label='Minor_SpCas9')
#       5 spmm20_min_groove.plot('Spmm20_bps','Spmm20_mean',yerr='Spmm20_std', ax=ax, label='Minor_SpCas9')
# ----> 6 spmm17_20_min_groove.plot('Spmm17_20_bps','Spmm17_20_mean',yerr='Spmm17_20_std', ax=ax, label='Minor_SpCas9')
#
# NameError: name 'spmm17_20_min_groove' is not defined

# %%
print(sp_df_20.columns, spmm20_df_20.columns)
# Out:
# Index(['sp_20_shear', 'sp_20_stretch', 'sp_20_stagger', 'sp_20_buckle',
#        'sp_20_propeller', 'sp_20_opening', 'sp_20_major', 'sp_20_minor'],
#       dtype='object') Index(['spmm20_20_shear', 'spmm20_20_stretch', 'spmm20_20_stagger',
#        'spmm20_20_buckle', 'spmm20_20_propeller', 'spmm20_20_opening',
#        'spmm20_20_major', 'spmm20_20_minor'],
#       dtype='object')

# %%
sp16_19_bp20.head()
# Out:
#    index  Frame  Nuc   bp  Shear  Stretch  Stagger  Buckle  Propeller  Opening
# 0    110      1    1  G-C  -0.16    -0.04     0.79    2.83       1.76     3.19
# 1    220      2    1  G-C  -0.14    -0.11    -0.03   -1.01      -4.29     0.92
# 2    331      3    1  G-C   0.42    -0.07     0.13   -0.69     -10.42    -3.58
# 3    442      4    1  G-C  -0.35    -0.04     0.28   11.80      -6.70     4.87
# 4    455      5    1  G-C  -0.18    -0.23     0.76  -14.39     -14.11    -1.45

# %%
sp16_19_bp20.drop(['index','Frame','Nuc','bp'], axis=1, inplace=True)
sp16_19_bp19.drop(['index','Frame','Nuc','bp'], axis=1, inplace=True)
sp16_19_bp18.drop(['index','Frame','Nuc','bp'], axis=1, inplace=True)
sp16_19_bp17.drop(['index','Frame','Nuc','bp'], axis=1, inplace=True)
list1=['sp_mm16_19_shear_20','sp_mm16_19_stretch_20','sp_mm16_19_stagger_20','sp_mm16_19_buckle_20','sp_mm16_19_propeller_20','sp_mm16-19_opening_20']
list2=['sp_mm16_19_shear_19','sp_mm16_19_stretch_19','sp_mm16_19_stagger_19','sp_mm16_19_buckle_19','sp_mm16_19_propeller_19','sp_mm16-19_opening_19']
list3=['sp_mm16_19_shear_18','sp_mm16_19_stretch_18','sp_mm16_19_stagger_18','sp_mm16_19_buckle_18','sp_mm16_19_propeller_18','sp_mm16-19_opening_18']
list4=['sp_mm16_19_shear_17','sp_mm16_19_stretch_17','sp_mm16_19_stagger_17','sp_mm16_19_buckle_17','sp_mm16_19_propeller_17','sp_mm16-19_opening_17']
sp16_19_bp20.columns=list1
sp16_19_bp19.columns=list2
sp16_19_bp18.columns=list3
sp16_19_bp17.columns=list4
sp_mm16_19_all_bps=pd.concat([sp16_19_bp20,sp16_19_bp19,sp16_19_bp18,sp16_19_bp17], axis=1)
sp_mm16_19_all_bps.to_csv('sp_mm16_19_all_bps_all_bps.csv', index=False)

# %%
sp_mm16_19_all_bps.head()
# Out:
#    sp_mm16_19_shear_20  sp_mm16_19_stretch_20  sp_mm16_19_stagger_20  \
# 0                -0.16                  -0.04                   0.79
# 1                -0.14                  -0.11                  -0.03
# 2                 0.42                  -0.07                   0.13
# 3                -0.35                  -0.04                   0.28
# 4                -0.18                  -0.23                   0.76
#
#    sp_mm16_19_buckle_20  sp_mm16_19_propeller_20  sp_mm16-19_opening_20  \
# 0                  2.83                     1.76                   3.19
# 1                 -1.01                    -4.29                   0.92
# 2                 -0.69                   -10.42                  -3.58
# 3                 11.80                    -6.70                   4.87
# 4                -14.39                   -14.11                  -1.45
#
#    sp_mm16_19_shear_19  sp_mm16_19_stretch_19  sp_mm16_19_stagger_19  \
# 0                -0.13                   1.68                   0.34
# 1                 0.13                   1.55                   0.05
# 2                -0.20                   1.53                  -0.56
# 3                -0.37                   1.75                  -0.48
# 4                 0.85                   1.88                  -0.45
#
#    sp_mm16_19_buckle_19  ...  sp_mm16_19_stagger_18  sp_mm16_19_buckle_18  \
# 0                 23.85  ...                   1.62                 -7.92
# 1                 23.13  ...                  -0.37                -11.43
# 2                 14.35  ...                   1.40                -14.80
# 3                 37.04  ...                   1.36                -16.74
# 4                 10.57  ...                   0.82                 -9.88
#
#    sp_mm16_19_propeller_18  sp_mm16-19_opening_18  sp_mm16_19_shear_17  \
# 0                   -15.45                  -7.68                 7.08
# 1                    -5.20                  -5.93                 2.82
# 2                   -18.29                  -5.68                 2.50
# 3                    -1.97                  -7.17                 1.90
# 4                   -11.86                  -5.39                 3.00
#
#    sp_mm16_19_stretch_17  sp_mm16_19_stagger_17  sp_mm16_19_buckle_17  \
# 0                   2.74                   2.25                 -0.76
# 1                   0.75                   0.69                 -4.72
# 2                   1.68                   0.22                 10.03
# 3                   0.93                   0.26                -20.51
# 4                   0.25                   1.41                 -1.27
#
#    sp_mm16_19_propeller_17  sp_mm16-19_opening_17
# 0                     5.98                 -58.03
# 1                    18.78                 -52.72
# 2                    24.96                 -75.56
# 3                    26.13                 -70.35
# 4                    32.25                 -45.61
#
# [5 rows x 24 columns]

# %%
sp17_20_bp20.drop(['index','Frame','Nuc','bp'], axis=1, inplace=True)
sp17_20_bp19.drop(['index','Frame','Nuc','bp'], axis=1, inplace=True)
sp17_20_bp18.drop(['index','Frame','Nuc','bp'], axis=1, inplace=True)
sp17_20_bp17.drop(['index','Frame','Nuc','bp'], axis=1, inplace=True)
list1=['sp_mm17-20_shear_20','sp_mm17-20_stretch_20','sp_mm17-20_stagger_20','sp_mm17-20_buckle_20','sp_mm17-20_propeller_20','sp_mm16-19_opening_20']
list2=['sp_mm17-20_shear_19','sp_mm17-20_stretch_19','sp_mm17-20_stagger_19','sp_mm17-20_buckle_19','sp_mm17-20_propeller_19','sp_mm16-19_opening_19']
list3=['sp_mm17-20_shear_18','sp_mm17-20_stretch_18','sp_mm17-20_stagger_18','sp_mm17-20_buckle_18','sp_mm17-20_propeller_18','sp_mm16-19_opening_18']
list4=['sp_mm17-20_shear_17','sp_mm17-20_stretch_17','sp_mm17-20_stagger_17','sp_mm17-20_buckle_17','sp_mm17-20_propeller_17','sp_mm16-19_opening_17']
sp17_20_bp20.columns=list1
sp17_20_bp19.columns=list2
sp17_20_bp18.columns=list3
sp17_20_bp17.columns=list4
sp_mm17_20_all_bps=pd.concat([sp17_20_bp20,sp17_20_bp19,sp17_20_bp18,sp17_20_bp17], axis=1)
sp_mm17_20_all_bps.to_csv('sp_mm17-20_all_bps.csv', index=False)

# %%
sp_mm17_20_all_bps.head()
# Out:
#    sp_mm17-20_shear_20  sp_mm17-20_stretch_20  sp_mm17-20_stagger_20  \
# 0                -3.54                   1.21                   0.91
# 1                -3.33                   1.48                   0.74
# 2                -3.03                   2.00                   1.35
# 3                -3.06                   1.46                   0.09
# 4                -2.90                   1.58                   0.53
#
#    sp_mm17-20_buckle_20  sp_mm17-20_propeller_20  sp_mm16-19_opening_20  \
# 0                -51.58                   -22.87                  69.87
# 1                -59.83                   -22.15                  85.37
# 2                -54.78                   -19.51                  93.41
# 3                -51.99                     0.29                  83.12
# 4                -18.87                   -17.15                  81.54
#
#    sp_mm17-20_shear_19  sp_mm17-20_stretch_19  sp_mm17-20_stagger_19  \
# 0                -4.42                   4.33                   1.40
# 1                -2.85                   4.28                  -0.02
# 2                 4.63                   3.23                  -1.59
# 3                -4.08                   3.99                   1.28
# 4                 0.08                   1.34                   1.26
#
#    sp_mm17-20_buckle_19  ...  sp_mm17-20_stagger_18  sp_mm17-20_buckle_18  \
# 0                -26.31  ...                   0.33                -15.91
# 1                -21.53  ...                   1.36                -20.58
# 2                  4.10  ...                   1.43                -39.38
# 3                -31.71  ...                  -0.91                -10.09
# 4                -15.63  ...                  -1.06                -12.03
#
#    sp_mm17-20_propeller_18  sp_mm16-19_opening_18  sp_mm17-20_shear_17  \
# 0                    43.06                -101.39                 4.63
# 1                    40.90                 -41.04                 0.08
# 2                    33.80                 -52.66                 0.98
# 3                    29.52                 -88.31                -0.08
# 4                    32.31                -112.00                -4.17
#
#    sp_mm17-20_stretch_17  sp_mm17-20_stagger_17  sp_mm17-20_buckle_17  \
# 0                   3.23                  -1.59                  4.10
# 1                   1.34                   1.26                -15.63
# 2                   0.82                   2.33                -15.17
# 3                   1.52                   0.49                 -3.04
# 4                   3.72                  -1.86                -23.41
#
#    sp_mm17-20_propeller_17  sp_mm16-19_opening_17
# 0                    50.45                 -63.50
# 1                    60.02                  -8.63
# 2                    57.04                   7.68
# 3                    58.20                  -5.65
# 4                    -3.96                  46.43
#
# [5 rows x 24 columns]
