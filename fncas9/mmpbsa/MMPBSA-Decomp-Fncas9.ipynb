# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
from scipy import stats

# %%
def z_test_two_distributions(sample1, sample2, alternative='two-sided'):
    """
    Perform Z-test between two distributions.

    Parameters:
        sample1 (array-like): The first sample data (1D array or list-like).
        sample2 (array-like): The second sample data (1D array or list-like).
        alternative (str, optional): The alternative hypothesis. 
                                     Options: 'two-sided', 'less', or 'greater'.
                                     Default is 'two-sided'.

    Returns:
        z_statistic (float): The Z-statistic value.
        p_value (float): The p-value of the test.
    """
    sample1 = np.array(sample1)
    sample2 = np.array(sample2)

    mean1 = np.mean(sample1)
    mean2 = np.mean(sample2)
    std1 = np.std(sample1, ddof=1)
    std2 = np.std(sample2, ddof=1)
    n1 = len(sample1)
    n2 = len(sample2)

    # Calculate the Z-score
    z = (mean1 - mean2) / np.sqrt((std1**2 / n1) + (std2**2 / n2))

    # Calculate the p-value based on the alternative hypothesis
    if alternative == 'two-sided':
        p_value = 2 * (1 - stats.norm.cdf(np.abs(z)))
    elif alternative == 'less':
        p_value = stats.norm.cdf(z)
    elif alternative == 'greater':
        p_value = 1 - stats.norm.cdf(z)
    else:
        raise ValueError("Invalid alternative hypothesis. Use 'two-sided', 'less', or 'greater'.")

    return z, p_value



import numpy as np
from scipy import stats

def t_test_two_distributions(sample1, sample2, alternative='two-sided'):
    """
    Perform t-test between two distributions.

    Parameters:
        sample1 (array-like): The first sample data (1D array or list-like).
        sample2 (array-like): The second sample data (1D array or list-like).
        alternative (str, optional): The alternative hypothesis.
                                     Options: 'two-sided', 'less', or 'greater'.
                                     Default is 'two-sided'.

    Returns:
        t_statistic (float): The t-statistic value.
        p_value (float): The p-value of the test.
    """
    t_stat, p_val = stats.ttest_ind(sample1, sample2, alternative=alternative)
    return t_stat, p_val

# %%
# DElat energy values

#awk 'NR >= 1512' 5b2o_mm20_emx1_State-1_10000-11000_ruvc-hnh-hybrid.csv > Delta_5b2o_mm20_emx1_State-1_ruvc-hnh-hybrid.csv
del_rec0=pd.read_csv('Delta_5b2omm17-20_emx1_State-0_REC-hybrid.csv')
del_rec1=pd.read_csv('Delta_5b2o_mm20_emx1_State-1_REC-hybrid.csv')
del_rec2=pd.read_csv('Delta_Fnnative_State-2_REC-hybrid.csv')
del_rec3=pd.read_csv('Delta_5b2o_mm16_19_emx1_State3_REC-hybrid.csv')


del_ruvc0=pd.read_csv('Delta_5b2omm17-20_emx1_State-0_ruvc-hnh-hybrid.csv')
del_ruvc1=pd.read_csv('Delta_5b2o_mm20_emx1_State-1_ruvc-hnh-hybrid.csv')
del_ruvc2=pd.read_csv('Delta_FnCas9_native_nowat_State-2_ruvc-hnh-hybrid.csv')
del_ruvc3=pd.read_csv('Delta_5b2o_mm16_19_emx1_State3_ruvc-hnh-hybrid.csv')


sp_del_rec0=pd.read_csv('../sp_nodt_files/Delta_5f9r_emx1_mm17-20_rec-hybrid.csv')
sp_del_rec1=pd.read_csv('../sp_nodt_files/Delta_5f9r_emx1_mm20_nowat_rec-hybrid_state1.csv')
sp_del_rec2=pd.read_csv('../sp_nodt_files/Delta_5f9r_emx1_mm20_nowat_rec-hybrid_state2.csv')
sp_del_rec3=pd.read_csv('../sp_nodt_files/Delta_5f9r_mm16_19_nowat_state_3_rec-hybrid.csv')
sp_del_rec4=pd.read_csv('../sp_nodt_files/Delta_5f9r_native_nowat_state_4_rec-hybrid.csv')

sp_del_ruvc0=pd.read_csv('../sp_nodt_files/Delta_Sp_mm17-20_state0_24505-25505.csv')
sp_del_ruvc1=pd.read_csv('../sp_nodt_files/Delta_spmm20_State-1_32000-33000.csv')
sp_del_ruvc2=pd.read_csv('../sp_nodt_files/Delta_spmm20_State-2_49000-50000.csv')
sp_del_ruvc3=pd.read_csv('../sp_nodt_files/Delta_Spmm16_19_state3_29000-30000.csv')
sp_del_ruvc4=pd.read_csv('../sp_nodt_files/DeltaSpnative_State-4_RuvC-HNH-Hybrid.csv')


ri0=list(del_rec0['TOTAL'])
ri1=list(del_rec1['TOTAL'])
ri2=list(del_rec2['TOTAL'])
ri3=list(del_rec3['TOTAL'])




hi0=list(del_ruvc0['TOTAL'])
hi1=list(del_ruvc1['TOTAL'])
hi2=list(del_ruvc2['TOTAL'])
hi3=list(del_ruvc3['TOTAL'])

fn_rec=pd.DataFrame(list(zip(ri0,ri1,ri2,ri3)), columns=['State 0 (mm17-20)', 'State 1 (mm20)', 'State 2 (native)', 'State 3 (mm16_19)'])
fn_ruvc=pd.DataFrame(list(zip(hi0,hi1,hi2,hi3)), columns=['State 0 (mm17-20)', 'State 1 (mm20)', 'State 2 (native)', 'State 3 (mm16_19)'])

ki0=list(sp_del_rec0['TOTAL'])
ki1=list(sp_del_rec1['TOTAL'])
ki2=list(sp_del_rec2['TOTAL'])
ki3=list(sp_del_rec3['TOTAL'])
ki4=list(sp_del_rec4['TOTAL'])

wi0=list(sp_del_ruvc0['TOTAL'])
wi1=list(sp_del_ruvc1['TOTAL'])
wi2=list(sp_del_ruvc2['TOTAL'])
wi3=list(sp_del_ruvc3['TOTAL'])
wi4=list(sp_del_ruvc4['TOTAL'])

sp_rec=pd.DataFrame(list(zip(ki0,ki1,ki2,ki3,ki4)), columns=['State 0 (mm17-20)', 'State 1 (mm20)', 'State 2 (mm20)', 'State 3 (mm16_19)','State 4 (native)'])
sp_ruvc=pd.DataFrame(list(zip(wi0,wi1,wi2,wi3,wi4)), columns=['State 0 (mm17-20)', 'State 1 (mm20)', 'State 2 (mm20)', 'State 3 (mm16_19)','State 4 (native)'])

fn_del_rec=list([ri0+ri1+ri2+ri3])
fn_del_ruvc=list([hi0+hi1+hi2+hi3])

sp_del_rec=list([ki0+ki1+ki2+ki3+ki4])
sp_del_ruvc=list([wi0+wi1+wi2+wi3+wi4])

# %%
eel_sp_rec=pd.concat([sp_del_rec0['EEL'],sp_del_rec1['EEL'],sp_del_rec2['EEL'],sp_del_rec3['EEL'],sp_del_rec4['EEL']], axis=1)
eel_sp_rec.columns=['State 0','State 1','State 2','State 3','State 4']
vdw_sp_rec=pd.concat([sp_del_rec0['VDWAALS'],sp_del_rec1['VDWAALS'],sp_del_rec2['VDWAALS'],sp_del_rec3['VDWAALS'],sp_del_rec4['VDWAALS']], axis=1)
vdw_sp_rec.columns=['State 0','State 1','State 2','State 3','State 4']
egb_sp_rec=pd.concat([sp_del_rec0['EGB'],sp_del_rec1['EGB'],sp_del_rec2['EGB'],sp_del_rec3['EGB'],sp_del_rec4['EGB']], axis=1)
egb_sp_rec.columns=['State 0','State 1','State 2','State 3','State 4']
esurf_sp_rec=pd.concat([sp_del_rec0['ESURF'],sp_del_rec1['ESURF'],sp_del_rec2['ESURF'],sp_del_rec3['ESURF'],sp_del_rec4['ESURF']], axis=1)
esurf_sp_rec.columns=['State 0','State 1','State 2','State 3','State 4']
eel_sp_rec.head()
# Out:
#    State 0  State 1  State 2  State 3  State 4
# 0   -82.79   -35.33   -76.57   -19.50   -25.66
# 1   -68.53   -20.51   -83.95   -31.97   -19.02
# 2   -93.77   -34.25   -79.97   -15.45   -13.18
# 3   -87.23   -20.50   -79.58   -33.52   -14.12
# 4   -73.68   -19.54   -82.85   -11.21   -15.81

# %%
eel_sp_ruvc=pd.concat([sp_del_ruvc0['EEL'],sp_del_ruvc1['EEL'],sp_del_ruvc2['EEL'],sp_del_ruvc3['EEL'],sp_del_ruvc4['EEL']], axis=1)
eel_sp_ruvc.columns=['State 0','State 1','State 2','State 3','State 4']
vdw_sp_ruvc=pd.concat([sp_del_ruvc0['VDWAALS'],sp_del_ruvc1['VDWAALS'],sp_del_ruvc2['VDWAALS'],sp_del_ruvc3['VDWAALS'],sp_del_ruvc4['VDWAALS']], axis=1)
vdw_sp_ruvc.columns=['State 0','State 1','State 2','State 3','State 4']
egb_sp_ruvc=pd.concat([sp_del_ruvc0['EGB'],sp_del_ruvc1['EGB'],sp_del_ruvc2['EGB'],sp_del_ruvc3['EGB'],sp_del_ruvc4['EGB']], axis=1)
egb_sp_ruvc.columns=['State 0','State 1','State 2','State 3','State 4']
esurf_sp_ruvc=pd.concat([sp_del_ruvc0['ESURF'],sp_del_ruvc1['ESURF'],sp_del_ruvc2['ESURF'],sp_del_ruvc3['ESURF'],sp_del_ruvc4['ESURF']], axis=1)
esurf_sp_ruvc.columns=['State 0','State 1','State 2','State 3','State 4']
eel_sp_ruvc.head()
# Out:
#    State 0  State 1  State 2  State 3  State 4
# 0  -969.20  -985.37  -955.86  -960.85  -986.26
# 1  -978.03  -982.89  -952.08  -965.61  -994.85
# 2  -970.65  -970.32  -954.01  -956.18  -983.62
# 3  -965.85  -994.63  -959.40  -952.61  -993.26
# 4  -967.30  -990.81  -971.97  -945.58  -985.02

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(sp_rec,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('SpCas9 REC-Hybrid distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)

# for i in range(0, len(combined_df)):
#     plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=2.0)
# plt.tight_layout()
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Sp-states-rec-ele-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(eel_sp_rec,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('SpCas9 REC-Hybrid Electrostatic energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)

# for i in range(0, len(combined_df)):
#     plt.axvline(x=i + 0.5, color='gray', linestyle='--', linewidth=2.0)
# plt.tight_layout()
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Sp-states-rec-ele-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(eel_sp_ruvc,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('SpCas9 RuvC-HNH Hybrid Electrostatic energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Sp-states-nuc-ele-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(egb_sp_rec,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('SpCas9 REC-Hybrid Polar-Solvation (EGB) energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Sp-states-rec-polar-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(egb_sp_ruvc,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('SpCas9 RuvC-HNH Hybrid Polar-Solvation (EGB) energy', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Sp-states-nuc-polar-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(esurf_sp_rec,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('SpCas9 REC-Hybrid Non-polar-Solvation (ESURF) energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Sp-states-rec-non_polar-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(esurf_sp_ruvc,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('SpCas9 RuvC-HNH Hybrid Non-polar-Solvation (ESURF) energy', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Sp-states-nuc-non-polar-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(vdw_sp_rec,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('SpCas9 REC-Hybrid Van Der Waals energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Sp-states-rec-vdw-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(vdw_sp_ruvc,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('SpCas9 RuvC-HNH Hybrid Van Der Waals energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Sp-states-nuc-polar-comp.svg')
plt.show()

# %%
eel_fn_rec=pd.concat([del_rec0['EEL'],del_rec1['EEL'],del_rec2['EEL'],del_rec3['EEL']], axis=1)
eel_fn_rec.columns=['State 0','State 1','State 2','State 3']
vdw_fn_rec=pd.concat([del_rec0['VDWAALS'],del_rec1['VDWAALS'],del_rec2['VDWAALS'],del_rec3['VDWAALS']], axis=1)
vdw_fn_rec.columns=['State 0','State 1','State 2','State 3']
egb_fn_rec=pd.concat([del_rec0['EGB'],del_rec1['EGB'],del_rec2['EGB'],del_rec3['EGB']], axis=1)
egb_fn_rec.columns=['State 0','State 1','State 2','State 3']
esurf_fn_rec=pd.concat([del_rec0['ESURF'],del_rec1['ESURF'],del_rec2['ESURF'],del_rec3['ESURF']], axis=1)
esurf_fn_rec.columns=['State 0','State 1','State 2','State 3']
eel_fn_rec.head()
# Out:
#    State 0  State 1  State 2  State 3
# 0  -793.30  -720.90  -762.83  -821.47
# 1  -794.12  -718.64  -738.83  -829.91
# 2  -790.32  -736.06  -742.22  -817.97
# 3  -787.20  -730.85  -759.35  -824.90
# 4  -801.76  -722.07  -771.85  -845.47

# %%
eel_fn_ruvc=pd.concat([del_ruvc0['EEL'],del_ruvc1['EEL'],del_ruvc2['EEL'],del_ruvc3['EEL']], axis=1)
eel_fn_ruvc.columns=['State 0','State 1','State 2','State 3']
vdw_fn_ruvc=pd.concat([del_ruvc0['VDWAALS'],del_ruvc1['VDWAALS'],del_ruvc2['VDWAALS'],del_ruvc3['VDWAALS']], axis=1)
vdw_fn_ruvc.columns=['State 0','State 1','State 2','State 3']
egb_fn_ruvc=pd.concat([del_ruvc0['EGB'],del_ruvc1['EGB'],del_ruvc2['EGB'],del_ruvc3['EGB']], axis=1)
egb_fn_ruvc.columns=['State 0','State 1','State 2','State 3']
esurf_fn_ruvc=pd.concat([del_ruvc0['ESURF'],del_ruvc1['ESURF'],del_ruvc2['ESURF'],del_ruvc3['ESURF']], axis=1)
esurf_fn_ruvc.columns=['State 0','State 1','State 2','State 3']
eel_fn_ruvc.head()
# Out:
#    State 0  State 1  State 2  State 3
# 0  -123.53  -111.80  -123.81  -136.24
# 1  -117.67  -123.14  -128.18  -131.36
# 2  -114.33  -119.79  -127.85  -129.61
# 3  -114.09  -120.50  -125.87  -135.60
# 4  -115.53  -123.27  -123.50  -133.60

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(eel_fn_rec,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('FnCas9 REC-Hybrid Electrostatic energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fn-states-rec-ele-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(eel_fn_ruvc,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('FnCas9 RuvC-HNH -Hybrid Electrostatic energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fn-states-nuc-ele-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(egb_fn_rec,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('FnCas9 REC-Hybrid Polar-Solvation (EGB) energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fn-states-rec-polar-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(egb_fn_ruvc,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('FnCas9 RuvC-HNH Hybrid Polar-Solvation (EGB) energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fn-states-nuc-polar-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(esurf_fn_rec,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('FnCas9 REC-Hybrid Non-polar-Solvation (ESURF) energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fn-states-rec-non_polar-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(esurf_fn_ruvc,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('FnCas9 RuvC-HNH Hybrid Non-polar-Solvation (ESURF) energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fn-states-nuc-non_polar-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(vdw_fn_rec,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('FnCas9 REC-Hybrid Van Der Waals energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fn-states-rec-vdw-comp.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(vdw_fn_ruvc,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('FnCas9 RuvC-HNH Hybrid Van Der Waals energy distribution', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.yticks(fontsize=12)
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fn-states-nuc-vdw-comp.svg')
plt.show()

# %%
import numpy as np
from scipy.stats import shapiro
from numpy.random import randn
# conduct the  Shapiro-Wilk Test
print(shapiro(sp_del_rec[0]))
print(shapiro(fn_del_rec[0]))
print(shapiro(sp_del_ruvc[0]))
print(shapiro(fn_del_ruvc[0]))
# Out:
# ShapiroResult(statistic=0.9829785227775574, pvalue=9.728731249820745e-17)
# ShapiroResult(statistic=0.9727297425270081, pvalue=4.655237036623134e-19)
# ShapiroResult(statistic=0.9938639402389526, pvalue=1.0170203346149265e-08)
# ShapiroResult(statistic=0.9872042536735535, pvalue=2.2860211987274504e-12)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mannwhitneyu

# Assuming sp_del_rec and fn_del_rec are lists or arrays containing your data

plt.figure(figsize=(7, 5))
sns.kdeplot(sp_del_rec[0], fill=True, color='red', legend=True)
sns.kdeplot(fn_del_rec[0], fill=True, color='blue', legend=True)
plt.xlabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.ylabel('Density', fontsize=16, fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(1)
ax.spines['bottom'].set_linewidth(1)
ax.spines['top'].set_linewidth(1)
ax.spines['right'].set_linewidth(1)
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')

plt.title('REC-Hybrid Binding Energy Distribution', fontweight='bold')
plt.legend(['SpCas9', 'FnCas9'], fontsize=14)
#plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fncas9-SpCas9_REC-Hybrid_B_E_Distribution.svg')
plt.show()

# Mann-Whitney U test
u_stat, p_val = mannwhitneyu(sp_del_rec[0], fn_del_rec[0], alternative='two-sided')
print("U-statistic:", u_stat)
print("P-value:", p_val)
# Out:
# U-statistic: 4706091.0
# P-value: 0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mannwhitneyu

# Assuming sp_del_ruvc and fn_del_ruvc are lists or arrays containing your data

plt.figure(figsize=(7, 5))
sns.kdeplot(sp_del_ruvc[0], fill=True, color='red', legend=True)
sns.kdeplot(fn_del_ruvc[0], fill=True, color='blue', legend=True)
plt.xlabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.ylabel('Density', fontsize=16, fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(1)
ax.spines['bottom'].set_linewidth(1)
ax.spines['top'].set_linewidth(1)
ax.spines['right'].set_linewidth(1)
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')

plt.title('ruvc-Hybrid Binding Energy Distribution', fontweight='bold')
plt.legend(['SpCas9', 'FnCas9'], fontsize=14)
#plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fncas9-SpCas9_ruvc-Hybrid_B_E_Distribution.svg')
plt.show()

# Mann-Whitney U test
u_stat, p_val = mannwhitneyu(sp_del_ruvc[0], fn_del_ruvc[0], alternative='two-sided')
print("U-statistic:", u_stat)
print("P-value:", p_val)
# Out:
# U-statistic: 0.0
# P-value: 0.0

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(fn_rec,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.title('FnCas9 REC-Hybrid Binding Energy', fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
plt.xticks(rotation=10, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fncas9-REC-Hybrid_B_E_boxplot.svg')
plt.show()

# %%
df1_rec=fn_rec.melt()
df1_nuc=fn_ruvc.melt()
df1_nuc.head()
# Out:
#             variable  value
# 0  State 0 (mm17-20) -63.90
# 1  State 0 (mm17-20) -65.21
# 2  State 0 (mm17-20) -62.59
# 3  State 0 (mm17-20) -66.76
# 4  State 0 (mm17-20) -64.36

# %%
df1_rec.head()
# Out:
#             variable   value
# 0  State 0 (mm17-20) -374.86
# 1  State 0 (mm17-20) -366.27
# 2  State 0 (mm17-20) -367.08
# 3  State 0 (mm17-20) -370.69
# 4  State 0 (mm17-20) -373.98

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(fn_ruvc,palette="viridis",linewidth=0.5)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
plt.xticks(rotation=10, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.title('FnCas9 RuvC-HNH-Hybrid Binding Energy', fontweight='bold')
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Fncas9-RuvC-Hybrid_B_E_boxplot.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(sp_rec,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.xticks(rotation=10, fontsize=12)
plt.yticks(fontsize=12)
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
plt.xticks(rotation=10, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.title('SpCas9 REC-Hybrid Binding Energy', fontweight='bold')
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Spcas9-REC-Hybrid_B_E_boxplot.svg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(sp_ruvc,palette="plasma",linewidth=0.7)
plt.ylabel('Energy (kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
ax = plt.gca()
ax.spines['left'].set_linewidth(0.7)
ax.spines['bottom'].set_linewidth(0.7)
ax.spines['top'].set_linewidth(0.7)
ax.spines['right'].set_linewidth(0.7)
plt.xticks(rotation=10, fontsize=14)
plt.yticks(fontsize=12)
# Make the x and y ticks point inward
plt.tick_params(axis='x', direction='in')
plt.tick_params(axis='y', direction='in')
plt.title('SpCas9 RuvC-HNH-Hybrid Binding Energy', fontweight='bold')
plt.savefig('/storage3/gayatrip/figures/mmpbsa/Spcas9-RuvC-Hybrid_B_E_boxplot.svg')
plt.show()

# %%
rec_state0=pd.read_csv('State0_Fn_mm17-20-REC-hybrid.csv')
rec_state1=pd.read_csv('State1_Fnmm20_REC-hybrid.csv')
rec_state2=pd.read_csv('State2_Fn_native_REC-hybrid.csv')
rec_state3=pd.read_csv('State3_Spmm16_19_REC-hybrid.csv')

sp_rec=pd.read_csv('REC_protein_allstates_spcas9.csv')
sp_ruvc=pd.read_csv('RuvC-HNH_protein_allstates_spcas9.csv')

# %%
rec_state0.iloc[:,1:].mean()[:].plot(kind="kde", label="REC-State-0")
rec_state1.iloc[:,1:].mean()[:].plot(kind="kde", label="REC-State-1")
rec_state2.iloc[:,1:].mean()[:].plot(kind="kde", label="REC-State-2")
rec_state3.iloc[:,1:].mean()[:].plot(kind="kde", label="REC-State-3")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
def prot_rec_list(dataframe):
    columns_lc = [col for col in dataframe.columns if col.startswith('L:C:')]
    columns_ra = [col for col in dataframe.columns if col.startswith('R:A:')]

    mean_na = dataframe[columns_lc].mean()
    mean_prot = dataframe[columns_ra].mean()
    stddev_na = dataframe[columns_lc].std()
    stddev_prot = dataframe[columns_ra].std()

    mean_na.index = [col.replace('L:C:', '') for col in mean_na.index]
    stddev_na.index = [col.replace('L:C:', '') for col in stddev_na.index]

    mean_prot.index = [col.replace('R:A:', '') for col in mean_prot.index]
    stddev_prot.index = [col.replace('R:A:', '') for col in stddev_prot.index]
    
    return list(mean_prot.values)


def prot_ruvc_hnh_list(dataframe):
    columns_lc = [col for col in dataframe.columns if col.startswith('L:')]
    columns_ra = [col for col in dataframe.columns if col.startswith('R:')]

    mean_na = dataframe[columns_lc].mean()
    mean_prot = dataframe[columns_ra].mean()
    stddev_na = dataframe[columns_lc].std()
    stddev_prot = dataframe[columns_ra].std()

    mean_na.index = [col.replace('L:E:', '') for col in mean_na.index]
    mean_na.index = [col.replace('L:F:', '') for col in mean_na.index]
    stddev_na.index = [col.replace('L:E:', '') for col in stddev_na.index]
    stddev_na.index = [col.replace('L:F:', '') for col in stddev_na.index]

    mean_prot.index = [col.replace('R:B:', '') for col in mean_prot.index]
    stddev_prot.index = [col.replace('R:B:', '') for col in stddev_prot.index]
    mean_prot.index = [col.replace('R:C:', '') for col in mean_prot.index]
    stddev_prot.index = [col.replace('R:C:', '') for col in stddev_prot.index]
    mean_prot.index = [col.replace('R:D:', '') for col in mean_prot.index]
    stddev_prot.index = [col.replace('R:D:', '') for col in stddev_prot.index]

    
    return list(mean_prot.values)

rec0=prot_rec_list(rec_state0)
rec1=prot_rec_list(rec_state1)
rec2=prot_rec_list(rec_state2)
rec3=prot_rec_list(rec_state3)

df_rec_prot=pd.DataFrame(list(zip(rec0,rec1,rec2,rec3)), columns=['Rec_State0', 'Rec_State1','Rec_State2','Rec_State3'])
df_rec_prot.head()
# Out:
#    Rec_State0  Rec_State1  Rec_State2  Rec_State3
# 0    -3.59418    -3.74400    -3.74072    -3.54672
# 1    -3.27396    -3.52508    -3.08104    -3.11256
# 2    -1.85974    -2.03588    -2.04652    -1.93850
# 3    -5.97992    -5.96618    -3.41730    -7.38560
# 4    -2.78902    -1.74784    -3.75196    -4.45226

# %%
plt.figure(figsize=(10, 4))
sns.violinplot(df_rec_prot,palette="viridis",linewidth=0.7)
plt.ylabel('Energy (Kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.kdeplot(df_rec_prot,palette="viridis",fill=True)
plt.ylabel('Energy (Kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
plt.show()

# %%
df_ruvc_prot.head()
# Out:
#    RuvC-HNH_State0  RuvC-HNH_State1  RuvC-HNH_State2  RuvC-HNH_State3
# 0         -4.65154         -0.21998         -2.53872         -2.64194
# 1         -1.62318         -2.75090         -5.02758         -4.91316
# 2         -1.55914         -2.29618         -1.61316         -1.50260
# 3         -1.99690         -1.09336         -1.50024         -1.53444
# 4         -4.46494         -2.90526         -3.31362         -0.68374

# %%
sp_rec.head()

li1=list(sp_rec['Rec_State0'])
li2=list(sp_rec['Rec_State1'])
li3=list(sp_rec['Rec_State2'])
li4=list(sp_rec['Rec_State3'])

pi1=list(sp_ruvc['RuvC-HNH_State0'])
pi2=list(sp_ruvc['RuvC-HNH_State1'])
pi3=list(sp_ruvc['RuvC-HNH_State2'])
pi4=list(sp_ruvc['RuvC-HNH_State3'])

sp_rec2=list([li1+li2+li3+li4])
sp_ruvc2=list([pi1+pi2+pi3+pi4])

# %%
li1=list(df_rec_prot['Rec_State0'])
li2=list(df_rec_prot['Rec_State1'])
li3=list(df_rec_prot['Rec_State2'])
li4=list(df_rec_prot['Rec_State3'])

pi1=list(df_ruvc_prot['RuvC-HNH_State0'])
pi2=list(df_ruvc_prot['RuvC-HNH_State1'])
pi3=list(df_ruvc_prot['RuvC-HNH_State2'])
pi4=list(df_ruvc_prot['RuvC-HNH_State3'])

rec=list([li1+li2+li3+li4])
ruvc=list([pi1+pi2+pi3+pi4])

sns.kdeplot(rec, fill=True, palette='viridis')
sns.kdeplot(ruvc, fill=True, palette='plasma')

z_stat, p_val = z_test_two_distributions(rec[0], sp_rec2[0], alternative='two-sided')
print("Z-statistic:", z_stat)
print("P-value:", p_val)

z_stat, p_val = z_test_two_distributions(ruvc[0], sp_ruvc2[0], alternative='two-sided')
print("Z-statistic:", z_stat)
print("P-value:", p_val)

print(np.percentile(rec[0],5))
print(np.percentile(ruvc[0],5))
# Out:
# Z-statistic: 1.6711406237799102
# P-value: 0.09469390496576713
# Z-statistic: 0.5525712566114643
# P-value: 0.5805570286501383
# -5.133704999999999
# -4.821593

# %%
plt.figure(figsize=(10, 4))
sns.violinplot(df_ruvc_prot,palette="viridis",linewidth=0.5)
plt.ylabel('Energy (Kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.xticks(rotation=10, fontsize=14)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.kdeplot(df_ruvc_prot,palette="viridis",fill=True)
plt.ylabel('Energy (Kcal/mol)', fontsize=16, fontweight='bold')
plt.xlabel('Systems', fontsize=16, fontweight='bold')
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=12)
plt.show()

# %%
def find_imp_residues_rec(dataframe):
    df=dataframe.iloc[:,1:].median().reset_index()
    df.columns=['Residue','Energy']
    filtered_df = df[df['Energy'] < -5.14]
    values_from_B = filtered_df['Residue']
    print(values_from_B)
    
def find_imp_residues_ruvc_hnh(dataframe):
    df=dataframe.iloc[:,1:].median().reset_index()
    df.columns=['Residue','Energy']
    filtered_df = df[df['Energy'] < -4.82]
    values_from_B = filtered_df['Residue']
    print(values_from_B)

# %%
find_imp_residues_rec(rec_state0)
find_imp_residues_rec(rec_state1)
find_imp_residues_rec(rec_state2)
find_imp_residues_rec(rec_state3)
# Out:
# 3     R:A:PHE:104
# 28    R:A:ARG:622
# 36    R:A:ARG:721
# 58    R:A:ARG:849
# 66     L:B:G:1626
# 67     L:B:C:1627
# 68     L:B:C:1628
# 69     L:B:G:1629
# 70     L:B:A:1630
# 71     L:B:G:1631
# 77     L:B:A:1639
# 78     L:B:G:1640
# 79     L:B:A:1641
# 80     L:B:A:1642
# 82    L:C:DT:1729
# 83    L:C:DT:1730
# 84    L:C:DC:1731
# 85    L:C:DT:1732
# 86    L:C:DT:1733
# 87    L:C:DC:1734
# 88    L:C:DT:1735
# 93    L:C:DG:1740
# 94    L:C:DG:1741
# 95    L:C:DA:1742
# 96    L:C:DC:1743
# Name: Residue, dtype: object
# 3      R:A:PHE:104
# 20     R:A:ARG:622
# 27     R:A:ARG:721
# 47     R:A:ARG:849
# 56      L:B:C:1627
# 57      L:B:C:1628
# 58      L:B:G:1629
# 59      L:B:A:1630
# 67      L:B:G:1640
# 68      L:B:A:1641
# 69      L:B:A:1642
# 71     L:C:DT:1730
# 72     L:C:DC:1731
# 73     L:C:DT:1732
# 74     L:C:DT:1733
# 75     L:C:DC:1734
# 80     L:C:DG:1740
# 81     L:C:DG:1741
# 83     L:C:DC:1743
# 84     L:C:DT:1744
# 85    L:C:DC3:1745
# ...

# %%
find_imp_residues_ruvc_hnh(ruvc_hnh_state0)
find_imp_residues_ruvc_hnh(ruvc_hnh_state1)
find_imp_residues_ruvc_hnh(ruvc_hnh_state2)
find_imp_residues_ruvc_hnh(ruvc_hnh_state3)
# Out:
# 7    L:E:U5:1623
# Name: Residue, dtype: object
# 8    L:E:U5:1623
# Name: Residue, dtype: object
# 1     R:B:VAL:858
# 8     L:E:G5:1623
# 10     L:E:A:1635
# Name: Residue, dtype: object
# 1     R:B:VAL:858
# 12    L:E:G5:1623
# 16     L:E:A:1635
# Name: Residue, dtype: object

# %%
ruvc_hnh_state0=pd.read_csv('State0_Fn_mm17-20_Ruvc-HNH-Hybrid.csv')
ruvc_hnh_state1=pd.read_csv('State1_Fn_mm20_RuvC-HNH-hybrid.csv')
ruvc_hnh_state2=pd.read_csv('State2_Fn_native_RuvC-HNH-hybrid.csv')
ruvc_hnh_state3=pd.read_csv('State3_Fn_mm16_19_ruvc-hnh-hybrid.csv')

# %%
def plot_mean_with_stddev(dataframe, State,save_filename=None):
    columns_lc = [col for col in dataframe.columns if col.startswith('L:C:')]
    columns_ra = [col for col in dataframe.columns if col.startswith('R:A:')]

    mean_na = dataframe[columns_lc].mean()
    mean_prot = dataframe[columns_ra].mean()
    stddev_na = dataframe[columns_lc].std()
    stddev_prot = dataframe[columns_ra].std()

    mean_na.index = [col.replace('L:C:', '') for col in mean_na.index]
    stddev_na.index = [col.replace('L:C:', '') for col in stddev_na.index]

    mean_prot.index = [col.replace('R:A:', '') for col in mean_prot.index]
    stddev_prot.index = [col.replace('R:A:', '') for col in stddev_prot.index]
    
    plt.figure(figsize=(17, 6))
    # Plot the mean as a bar and the standard deviation as an error bar for 'R:A:' columns
    rec1_patch = mpatches.Patch(color='#FFDBAA', label='REC1 (83-112,308-459)')
    rec2_patch = mpatches.Patch(color='#CECE5A', label='REC2 (113-307)')
    rec3_patch = mpatches.Patch(color='darkgreen', label='REC3 (460-858)')

    for col, mean_val, std_val in zip(mean_prot.index, mean_prot.values, stddev_prot.values):
        column_number = int(col.split(':')[1])
        color = 'darkgreen' if (460 <= column_number <= 858) else ('#CECE5A' if (113 <= column_number <= 307) else '#FFDBAA')
        plt.bar(col, mean_val, yerr=std_val, error_kw={'elinewidth': 1.0, 'capsize': 3}, color=color,edgecolor='black',linewidth=0.5)

    plt.xlabel('Residue', fontsize=16, fontweight='bold')
    plt.ylabel('Energy (Kcal/mol)', fontsize=16, fontweight='bold')
    plt.title(State, fontsize=14, fontweight='bold')
    plt.xticks(rotation=90, fontsize=14)
    plt.yticks(fontsize=12)
    ax = plt.gca()
    ax.spines['left'].set_linewidth(1)
    ax.spines['bottom'].set_linewidth(1)
    ax.spines['top'].set_linewidth(1)
    ax.spines['right'].set_linewidth(1)
    # Make the x and y ticks point inward
    plt.tick_params(axis='x', direction='in')
    plt.tick_params(axis='y', direction='in')

    # Add the legend
    plt.legend(handles=[rec1_patch, rec2_patch, rec3_patch], fontsize=14)
    if save_filename:  # Save the figure if filename is provided
        plt.savefig(save_filename, format='svg', bbox_inches='tight')
    else:
        plt.show()
# Assuming you have a dataframe named 'df' with the specified columns
#

# %%
plot_mean_with_stddev(rec_state0,"State 0",save_filename='fn_rec_state0.svg')
plot_mean_with_stddev(rec_state1,"State 1",save_filename='fn_rec_state1.svg')
plot_mean_with_stddev(rec_state2,"State 2",save_filename='fn_rec_state2.svg')
plot_mean_with_stddev(rec_state3, "State 3",save_filename='fn_rec_state3.svg')

# %%
import pandas as pd
import matplotlib.pyplot as plt



def plot_mean_with_stddev_ruvc(dataframe, State,save_filename=None):
    columns_lc = [col for col in dataframe.columns if col.startswith('L:')]
    columns_ra = [col for col in dataframe.columns if col.startswith('R:')]

    mean_na = dataframe[columns_lc].mean()
    mean_prot = dataframe[columns_ra].mean()
    stddev_na = dataframe[columns_lc].std()
    stddev_prot = dataframe[columns_ra].std()

    mean_na.index = [col.replace('L:E:', '') for col in mean_na.index]
    mean_na.index = [col.replace('L:F:', '') for col in mean_na.index]
    stddev_na.index = [col.replace('L:E:', '') for col in stddev_na.index]
    stddev_na.index = [col.replace('L:F:', '') for col in stddev_na.index]
    
    mean_prot.index = [col.replace('R:A:', '') for col in mean_prot.index]
    stddev_prot.index = [col.replace('R:A:', '') for col in stddev_prot.index]
    mean_prot.index = [col.replace('R:B:', '') for col in mean_prot.index]
    stddev_prot.index = [col.replace('R:B:', '') for col in stddev_prot.index]
    mean_prot.index = [col.replace('R:C:', '') for col in mean_prot.index]
    stddev_prot.index = [col.replace('R:C:', '') for col in stddev_prot.index]
    mean_prot.index = [col.replace('R:D:', '') for col in mean_prot.index]
    stddev_prot.index = [col.replace('R:D:', '') for col in stddev_prot.index]

#     plt.gcf().set_size_inches(10, 4)
#     # Plot the mean as a bar and the standard deviation as an error bar for 'L:C:' columns
#     plt.bar(mean_na.index, mean_na.values, yerr=stddev_na.values, capsize=5)
#     plt.xlabel('Columns')
#     plt.ylabel('Mean Value')
#     plt.title('Mean with Standard Deviation Error Bars for "Nucleotides"')
#     plt.xticks(rotation=45)
#     plt.show()
    #return dataframe[columns_ra]

    plt.figure(figsize=(8, 4))
    # Plot the mean as a bar and the standard deviation as an error bar for 'R:A:' columns
    ruvc_patch = mpatches.Patch(color='#FBA1B7', label='RuvC (1-51,858-899,1088-1224)')
    hnh_patch = mpatches.Patch(color='#F4D160', label='HNH (932-1070)')
    
    for col, mean_val, std_val in zip(mean_prot.index, mean_prot.values, stddev_prot.values):
        column_number = int(col.split(':')[1])
        color = '#F4D160' if (932 <= column_number <= 1070) else '#FBA1B7'
        plt.bar(col, mean_val, yerr=std_val,error_kw={'elinewidth': 1.0, 'capsize': 3}, color=color, edgecolor='black',linewidth=0.5)
    plt.xlabel('Residue', fontsize=16, fontweight='bold')
    plt.ylabel('Energy (Kcal/mol)', fontsize=16, fontweight='bold')
    plt.title(State, fontsize=14, fontweight='bold')
    ax = plt.gca()
    ax.spines['left'].set_linewidth(1)
    ax.spines['bottom'].set_linewidth(1)
    ax.spines['top'].set_linewidth(1)
    ax.spines['right'].set_linewidth(1)
    # Make the x and y ticks point inward
    plt.tick_params(axis='x', direction='in')
    plt.tick_params(axis='y', direction='in')
    plt.xticks(rotation=90, fontsize=14)
    plt.yticks(fontsize=12)
    # Add the legend
    plt.legend(handles=[ruvc_patch, hnh_patch], fontsize=12)
    if save_filename:  # Save the figure if filename is provided
        plt.savefig(save_filename, format='svg', bbox_inches='tight')
    else:
        plt.show()

# %%
# Call the function with 'rec_state1' DataFrame as input
plot_mean_with_stddev_ruvc(ruvc_hnh_state0, "State 0",save_filename='fn_ruvc_hnh_state0.svg') #save_filename='figure.svg'
plot_mean_with_stddev_ruvc(ruvc_hnh_state1,"State 1",save_filename='fn_ruvc_hnh_state1.svg')
plot_mean_with_stddev_ruvc(ruvc_hnh_state2,"State 2",save_filename='fn_ruvc_hnh_state2.svg')
plot_mean_with_stddev_ruvc(ruvc_hnh_state3,"State 3",save_filename='fn_ruvc_hnh_state3.svg')

# %%
ruvc_hnh_state1.head()
# Out:
#    Frames  R:A:LEU:51  R:B:VAL:858  R:B:ASP:859  R:B:GLY:860  R:C:PHE:1041  \
# 0       1       -0.45        -2.70        -2.06        -1.48         -2.29
# 1       2       -0.39        -2.73        -2.49        -1.15         -2.58
# 2       3       -0.45        -2.54        -2.16        -1.19         -2.48
# 3       4       -0.23        -2.51        -2.49        -0.44         -2.82
# 4       5       -0.37        -2.96        -2.26        -1.04         -3.74
#
#    R:C:LYS:1042  R:C:ARG:1047  R:C:SER:1048  L:E:U5:1623  L:E:G:1634  \
# 0         -2.68         -5.03         -0.99        -6.25       -0.42
# 1         -2.50         -4.58         -1.63        -6.26       -0.35
# 2         -2.11         -4.77         -1.15        -5.28       -0.41
# 3         -2.50         -4.11         -1.51        -4.95       -0.40
# 4         -2.50         -5.22         -1.31        -6.14       -0.38
#
#    L:E:A:1635  L:E:A:1636  L:F:DC:1734  L:F:DT:1735  L:F:DT:1744  L:F:DC3:1745
# ...

# %%
columns_lc = [col for col in rec_state0.columns if col.startswith('L:')]
columns_ra = [col for col in rec_state0.columns if col.startswith('R:')]

mean_na = rec_state0[columns_lc].mean()
mean_prot = rec_state0[columns_ra].mean()
stddev_na = rec_state0[columns_lc].std()
stddev_prot = rec_state0[columns_ra].std()

mean_na.index = [col.replace('L:E:', '') for col in mean_na.index]
mean_na.index = [col.replace('L:F:', '') for col in mean_na.index]
stddev_na.index = [col.replace('L:E:', '') for col in stddev_na.index]
stddev_na.index = [col.replace('L:F:', '') for col in stddev_na.index]

mean_prot.index = [col.replace('R:A:', '') for col in mean_prot.index]
stddev_prot.index = [col.replace('R:A:', '') for col in stddev_prot.index]
mean_prot.index = [col.replace('R:B:', '') for col in mean_prot.index]
stddev_prot.index = [col.replace('R:B:', '') for col in stddev_prot.index]
mean_prot.index = [col.replace('R:C:', '') for col in mean_prot.index]
stddev_prot.index = [col.replace('R:C:', '') for col in stddev_prot.index]
mean_prot.index = [col.replace('R:D:', '') for col in mean_prot.index]
stddev_prot.index = [col.replace('R:D:', '') for col in stddev_prot.index]

#     plt.gcf().set_size_inches(10, 4)
#     # Plot the mean as a bar and the standard deviation as an error bar for 'L:C:' columns
#     plt.bar(mean_na.index, mean_na.values, yerr=stddev_na.values, capsize=5)
#     plt.xlabel('Columns')
#     plt.ylabel('Mean Value')
#     plt.title('Mean with Standard Deviation Error Bars for "Nucleotides"')
#     plt.xticks(rotation=45)
#     plt.show()


plt.figure(figsize=(8, 4))
# Plot the mean as a bar and the standard deviation as an error bar for 'R:A:' columns
ruvc_patch = mpatches.Patch(color='#FBA1B7', label='RuvC (1-51,858-899,1088-1224)')
hnh_patch = mpatches.Patch(color='#F4D160', label='HNH (932-1070)')

for col, mean_val, std_val in zip(mean_prot.index, mean_prot.values, stddev_prot.values):
    column_number = int(col.split(':')[1])
    print(columnmean_val)
# Out:
# -3.59418
# -3.27396
# -1.8597399999999997
# -5.97992
# -2.7890199999999994
# -0.86958
# -0.17574
# -2.37966
# 0.030679999999999992
# -1.51466
# -1.03868
# -1.7326599999999999
# -2.7433199999999998
# -1.13522
# -1.2043199999999998
# -1.70764
# -1.5618200000000002
# -0.79206
# -0.57394
# -2.53774
# -2.60726
# -4.503940000000001
# -3.8644
# -3.01784
# -3.6901400000000004
# -1.9942599999999997
# -1.64266
# -0.7902800000000001
# -5.1983999999999995
# -0.42119999999999996
# -2.56316
# -0.6376
# -2.2999
# -1.2838800000000001
# -2.4691199999999998
# -3.2652799999999997
# -5.237360000000001
# -1.3416599999999999
# -3.09242
# -1.92518
# -1.08548
# -2.3968199999999995
# -4.818599999999999
# -4.62152
# -2.7469200000000003
# -1.98584
# -2.93894
# -2.35656
# -2.9607
# -0.50162
# -2.38844
# -1.06954
# -1.4673200000000002
# -2.3183800000000003
# -0.40027999999999997
# -0.5290199999999999
# -1.70486
# -1.38622
# -7.111200000000001
# -1.02066
# -1.0166400000000002
# -2.16178
# -2.47118
# ...
